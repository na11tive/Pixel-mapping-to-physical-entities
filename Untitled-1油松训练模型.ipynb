# %%
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from transformers import SegformerForSemanticSegmentation, SegformerConfig
import os
import numpy as np
from tqdm import tqdm
import json

# 数据集类
class TreeTrunkDataset(Dataset):
    def __init__(self, image_dir, mask_dir, json_dir, transform=None, target_size=(1024, 1024)):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.json_dir = json_dir
        self.transform = transform
        self.target_size = target_size  # 目标尺寸
        self.images = [img for img in os.listdir(image_dir) if img.lower().endswith(('.jpg', '.jpeg', '.png'))]
        self.images = [img for img in self.images if os.path.exists(os.path.join(mask_dir, img.replace(".JPG", ".png").replace(".jpg", ".png").replace(".jpeg", ".png")))]
        self.images = [img for img in self.images if os.path.exists(os.path.join(json_dir, img.replace(".JPG", ".json").replace(".jpg", ".json").replace(".jpeg", ".json")))]

        # 添加调试信息
        if len(self.images) == 0:
            print("未找到匹配的图像、掩码或 JSON 文件，请检查目录和文件扩展名。")
        else:
            print(f"找到 {len(self.images)} 个匹配的图像、掩码和 JSON 文件。")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.images[idx])
        mask_path = os.path.join(self.mask_dir, self.images[idx].replace(".JPG", ".png").replace(".jpg", ".png").replace(".jpeg", ".png"))
        json_path = os.path.join(self.json_dir, self.images[idx].replace(".JPG", ".json").replace(".jpg", ".json").replace(".jpeg", ".json"))
        
        # 读取图像
        image = Image.open(img_path).convert("RGB")  # 使用 Pillow 打开图像
        mask = Image.open(mask_path).convert('L')  # 转换为灰度图像
        mask = np.array(mask)  # 转换为numpy数组
        
        # 读取 JSON 文件
        with open(json_path, 'r') as f:
            json_data = json.load(f)

        # 统一图像和掩码的大小
        image = image.resize(self.target_size)
        mask = Image.fromarray(mask).resize(self.target_size, Image.NEAREST)
        
        # 转换为 Tensor
        if self.transform:
            image = self.transform(image)

        # 确保掩码值在0和1之间
        mask = np.clip(mask, 0, 1)
        mask = torch.tensor(mask, dtype=torch.long)
        
        return image, mask, json_data  # 返回 image, mask 和 json_data

# 自定义 collate_fn，确保每个批次中的数据大小一致
def collate_fn(batch):
    images, masks, json_data = zip(*batch)

    # 将所有图像堆叠成一个批次
    images = torch.stack(images, dim=0)
    
    # 将所有掩码堆叠成一个批次
    masks = torch.stack(masks, dim=0)

    return images, masks

# 设置路径
image_dir = "D:/2024/paper2/model/input_images2/yousong"
mask_dir = "D:/2024/paper2/model/output_masks/yousong"
json_dir = "D:/2024/paper2/model/sorted_JSON/yousong"

# 数据增强与预处理
transform = transforms.Compose([
    transforms.ToTensor(),  # 转换为 Tensor
])

# 数据集和数据加载器
dataset = TreeTrunkDataset(image_dir=image_dir, mask_dir=mask_dir, json_dir=json_dir, transform=transform)

# 检查数据集是否为空
if len(dataset) == 0:
    raise ValueError("数据集为空，请检查图像和掩码文件是否匹配且存在。")

# 使用自定义的 collate_fn 确保每个批次的大小一致
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=collate_fn)

# 初始化模型
config = SegformerConfig()
config.num_labels = 2  # 假设只有背景和前景两类
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SegformerForSemanticSegmentation(config).to(device)

# 定义损失函数和优化器
optimizer = optim.AdamW(model.parameters(), lr=0.0001)

# 自定义中心加权损失
class WeightedCrossEntropyLoss(nn.Module):
    def __init__(self, weight_center=2.0):
        super(WeightedCrossEntropyLoss, self).__init__()
        self.weight_center = weight_center
        self.ce_loss = nn.CrossEntropyLoss(reduction='none')

    def forward(self, inputs, targets):
        # 确保 inputs 和 targets 的维度一致
        if inputs.shape[2:] != targets.shape:
            targets = targets.unsqueeze(1)
            targets = torch.nn.functional.interpolate(targets.float(), size=inputs.shape[2:], mode='nearest').squeeze(1).long()
        
        # 计算基本交叉熵损失
        loss = self.ce_loss(inputs, targets)

        # 中心区域权重：仅对纵向范围中心加权，横向不变
        _, _, h, w = inputs.shape
        y_center, x_center = h // 2, w // 2
        weight_mask = torch.ones_like(targets, dtype=torch.float32)
        weight_mask[y_center - h // 4:y_center + h // 4, :] = self.weight_center  # 仅纵向范围

        # 应用权重
        weighted_loss = loss * weight_mask.to(inputs.device)
        return weighted_loss.mean()

criterion = WeightedCrossEntropyLoss(weight_center=5.0)

# 训练循环
epochs = 130
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    with tqdm(total=len(dataloader), desc=f"Epoch {epoch+1}/{epochs}") as pbar:
        for images, masks in dataloader:  # 加载图像和掩码
            images, masks = images.to(device), masks.to(device)

            # 前向传播
            outputs = model(images).logits
            # 调整输出大小以匹配掩码大小
            outputs = torch.nn.functional.interpolate(outputs, size=(masks.shape[1], masks.shape[2]), mode='bilinear', align_corners=False)

            # 计算损失
            loss = criterion(outputs, masks)

            # 反向传播和优化
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            pbar.update(1)  # 更新 tqdm 进度条
            pbar.set_postfix({"Loss": f"{loss.item():.4f}"})  # 显示当前损失

    print(f"Epoch [{epoch+1}/{epochs}], Loss: {running_loss/len(dataloader):.4f}")

# 保存模型
save_dir = "D:/2024/paper2/model/Model/yousong"
os.makedirs(save_dir, exist_ok=True)

# 保存完整模型
model_save_path = os.path.join(save_dir, "segformer_full_model.pth")
torch.save(model, model_save_path)
print(f"完整模型已保存到 {model_save_path}")

# 保存模型权重
weights_save_path = os.path.join(save_dir, "segformer_weights.pth")
torch.save(model.state_dict(), weights_save_path)
print(f"模型权重已保存到 {weights_save_path}")


# 保存配置文件
config_save_path = os.path.join(save_dir, "config.json")
config.save_pretrained(save_dir)
print(f"配置文件已保存到 {config_save_path}")

# 保存检查点文件
checkpoint_save_path = os.path.join(save_dir, "checkpoint.pth")
torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "config": config.to_dict(),
    "epoch": epochs,
}, checkpoint_save_path)
print(f"检查点文件已保存到 {checkpoint_save_path}")

print("训练完成并保存所有文件！")
# Out:
# 找到 41 个匹配的图像、掩码和 JSON 文件。
# Epoch 1/130: 100%|██████████| 11/11 [11:45<00:00, 64.18s/it, Loss=0.4286]
# Epoch [1/130], Loss: 0.5155
# Epoch 2/130: 100%|██████████| 11/11 [02:45<00:00, 15.08s/it, Loss=0.3442]
# Epoch [2/130], Loss: 0.3924
# Epoch 3/130: 100%|██████████| 11/11 [03:11<00:00, 17.42s/it, Loss=0.2832]
# Epoch [3/130], Loss: 0.3331
# Epoch 4/130: 100%|██████████| 11/11 [03:00<00:00, 16.41s/it, Loss=0.2728]
# Epoch [4/130], Loss: 0.2946
# Epoch 5/130: 100%|██████████| 11/11 [07:53<00:00, 43.04s/it, Loss=0.2694]
# Epoch [5/130], Loss: 0.2696
# Epoch 6/130: 100%|██████████| 11/11 [04:35<00:00, 25.06s/it, Loss=0.2351]
# Epoch [6/130], Loss: 0.2401
# Epoch 7/130: 100%|██████████| 11/11 [02:58<00:00, 16.27s/it, Loss=0.1986]
# Epoch [7/130], Loss: 0.2169
# Epoch 8/130: 100%|██████████| 11/11 [05:29<00:00, 29.98s/it, Loss=0.1803]
# Epoch [8/130], Loss: 0.1991
# Epoch 9/130: 100%|██████████| 11/11 [02:36<00:00, 14.18s/it, Loss=0.1629]
# Epoch [9/130], Loss: 0.1788
# Epoch 10/130: 100%|██████████| 11/11 [02:33<00:00, 13.99s/it, Loss=0.1513]
# Epoch [10/130], Loss: 0.1621
# Epoch 11/130: 100%|██████████| 11/11 [06:58<00:00, 38.04s/it, Loss=0.1304]
# Epoch [11/130], Loss: 0.1479
# Epoch 12/130: 100%|██████████| 11/11 [03:35<00:00, 19.61s/it, Loss=0.1333]
# Epoch [12/130], Loss: 0.1320
# Epoch 13/130: 100%|██████████| 11/11 [04:28<00:00, 24.44s/it, Loss=0.1115]
# Epoch [13/130], Loss: 0.1236
# Epoch 14/130: 100%|██████████| 11/11 [03:13<00:00, 17.56s/it, Loss=0.1301]
# Epoch [14/130], Loss: 0.1140
# Epoch 15/130: 100%|██████████| 11/11 [03:35<00:00, 19.61s/it, Loss=0.1370]
# Epoch [15/130], Loss: 0.1123
# Epoch 16/130: 100%|██████████| 11/11 [03:42<00:00, 20.21s/it, Loss=0.0948]
# Epoch [16/130], Loss: 0.1048
# Epoch 17/130: 100%|██████████| 11/11 [04:05<00:00, 22.31s/it, Loss=0.0986]
# Epoch [17/130], Loss: 0.0994
# Epoch 18/130: 100%|██████████| 11/11 [03:19<00:00, 18.17s/it, Loss=0.0772]
# Epoch [18/130], Loss: 0.0946
# Epoch 19/130: 100%|██████████| 11/11 [04:27<00:00, 24.34s/it, Loss=0.0986]
# Epoch [19/130], Loss: 0.0937
# Epoch 20/130: 100%|██████████| 11/11 [03:51<00:00, 21.08s/it, Loss=0.0813]
# Epoch [20/130], Loss: 0.0893
# Epoch 21/130: 100%|██████████| 11/11 [03:44<00:00, 20.41s/it, Loss=0.0689]
# Epoch [21/130], Loss: 0.0866
# Epoch 22/130: 100%|██████████| 11/11 [07:46<00:00, 42.44s/it, Loss=0.1051]
# Epoch [22/130], Loss: 0.0874
# Epoch 23/130: 100%|██████████| 11/11 [2:16:10<00:00, 742.78s/it, Loss=0.1136]
# Epoch [23/130], Loss: 0.0878
# Epoch 24/130: 100%|██████████| 11/11 [01:20<00:00,  7.35s/it, Loss=0.0886]
# Epoch [24/130], Loss: 0.0847
# Epoch 25/130: 100%|██████████| 11/11 [01:20<00:00,  7.33s/it, Loss=0.1004]
# Epoch [25/130], Loss: 0.0837
# Epoch 26/130: 100%|██████████| 11/11 [01:19<00:00,  7.26s/it, Loss=0.1202]
# Epoch [26/130], Loss: 0.0843
# Epoch 27/130: 100%|██████████| 11/11 [01:19<00:00,  7.24s/it, Loss=0.1004]
# Epoch [27/130], Loss: 0.0801
# Epoch 28/130: 100%|██████████| 11/11 [01:20<00:00,  7.30s/it, Loss=0.1143]
# Epoch [28/130], Loss: 0.0785
# Epoch 29/130: 100%|██████████| 11/11 [01:20<00:00,  7.33s/it, Loss=0.0799]
# Epoch [29/130], Loss: 0.0746
# Epoch 30/130: 100%|██████████| 11/11 [01:16<00:00,  6.99s/it, Loss=0.0672]
# Epoch [30/130], Loss: 0.0726
# Epoch 31/130: 100%|██████████| 11/11 [01:18<00:00,  7.13s/it, Loss=0.0798]
# Epoch [31/130], Loss: 0.0713
# Epoch 32/130: 100%|██████████| 11/11 [01:18<00:00,  7.17s/it, Loss=0.0613]
# Epoch [32/130], Loss: 0.0693
# Epoch 33/130: 100%|██████████| 11/11 [01:18<00:00,  7.17s/it, Loss=0.0410]
# Epoch [33/130], Loss: 0.0658
# Epoch 34/130: 100%|██████████| 11/11 [01:17<00:00,  7.09s/it, Loss=0.0678]
# Epoch [34/130], Loss: 0.0661
# Epoch 35/130: 100%|██████████| 11/11 [01:17<00:00,  7.06s/it, Loss=0.0654]
# Epoch [35/130], Loss: 0.0653
# Epoch 36/130: 100%|██████████| 11/11 [01:17<00:00,  7.08s/it, Loss=0.0713]
# Epoch [36/130], Loss: 0.0645
# Epoch 37/130: 100%|██████████| 11/11 [01:17<00:00,  7.05s/it, Loss=0.0538]
# Epoch [37/130], Loss: 0.0624
# Epoch 38/130: 100%|██████████| 11/11 [01:18<00:00,  7.13s/it, Loss=0.0528]
# Epoch [38/130], Loss: 0.0600
# Epoch 39/130: 100%|██████████| 11/11 [01:18<00:00,  7.17s/it, Loss=0.0425]
# Epoch [39/130], Loss: 0.0582
# Epoch 40/130: 100%|██████████| 11/11 [01:19<00:00,  7.25s/it, Loss=0.0545]
# Epoch [40/130], Loss: 0.0585
# Epoch 41/130: 100%|██████████| 11/11 [01:19<00:00,  7.25s/it, Loss=0.0447]
# Epoch [41/130], Loss: 0.0560
# Epoch 42/130: 100%|██████████| 11/11 [01:18<00:00,  7.11s/it, Loss=0.0613]
# Epoch [42/130], Loss: 0.0569
# Epoch 43/130: 100%|██████████| 11/11 [01:17<00:00,  7.06s/it, Loss=0.0564]
# Epoch [43/130], Loss: 0.0578
# Epoch 44/130: 100%|██████████| 11/11 [01:18<00:00,  7.12s/it, Loss=0.0850]
# Epoch [44/130], Loss: 0.0596
# Epoch 45/130: 100%|██████████| 11/11 [01:18<00:00,  7.11s/it, Loss=0.0574]
# Epoch [45/130], Loss: 0.0560
# Epoch 46/130: 100%|██████████| 11/11 [01:18<00:00,  7.16s/it, Loss=0.0567]
# Epoch [46/130], Loss: 0.0554
# Epoch 47/130: 100%|██████████| 11/11 [01:18<00:00,  7.12s/it, Loss=0.0436]
# Epoch [47/130], Loss: 0.0504
# Epoch 48/130: 100%|██████████| 11/11 [01:19<00:00,  7.25s/it, Loss=0.0357]
# Epoch [48/130], Loss: 0.0483
# Epoch 49/130: 100%|██████████| 11/11 [01:18<00:00,  7.12s/it, Loss=0.0450]
# Epoch [49/130], Loss: 0.0481
# Epoch 50/130: 100%|██████████| 11/11 [01:18<00:00,  7.17s/it, Loss=0.0515]
# Epoch [50/130], Loss: 0.0485
# Epoch 51/130: 100%|██████████| 11/11 [01:19<00:00,  7.22s/it, Loss=0.0329]
# Epoch [51/130], Loss: 0.0446
# Epoch 52/130: 100%|██████████| 11/11 [01:17<00:00,  7.03s/it, Loss=0.0357]
# Epoch [52/130], Loss: 0.0440
# Epoch 53/130: 100%|██████████| 11/11 [01:18<00:00,  7.13s/it, Loss=0.0593]
# Epoch [53/130], Loss: 0.0453
# Epoch 54/130: 100%|██████████| 11/11 [01:19<00:00,  7.26s/it, Loss=0.0429]
# Epoch [54/130], Loss: 0.0428
# Epoch 55/130: 100%|██████████| 11/11 [01:19<00:00,  7.26s/it, Loss=0.0546]
# Epoch [55/130], Loss: 0.0415
# Epoch 56/130: 100%|██████████| 11/11 [01:18<00:00,  7.14s/it, Loss=0.0444]
# Epoch [56/130], Loss: 0.0439
# Epoch 57/130: 100%|██████████| 11/11 [01:19<00:00,  7.27s/it, Loss=0.0310]
# Epoch [57/130], Loss: 0.0417
# Epoch 58/130: 100%|██████████| 11/11 [01:17<00:00,  7.03s/it, Loss=0.0396]
# Epoch [58/130], Loss: 0.0381
# Epoch 59/130: 100%|██████████| 11/11 [01:19<00:00,  7.20s/it, Loss=0.0332]
# Epoch [59/130], Loss: 0.0363
# Epoch 60/130: 100%|██████████| 11/11 [01:19<00:00,  7.20s/it, Loss=0.0375]
# Epoch [60/130], Loss: 0.0376
# Epoch 61/130: 100%|██████████| 11/11 [01:18<00:00,  7.17s/it, Loss=0.0336]
# Epoch [61/130], Loss: 0.0346
# Epoch 62/130: 100%|██████████| 11/11 [01:17<00:00,  7.06s/it, Loss=0.0281]
# Epoch [62/130], Loss: 0.0342
# Epoch 63/130: 100%|██████████| 11/11 [01:18<00:00,  7.11s/it, Loss=0.0505]
# Epoch [63/130], Loss: 0.0363
# Epoch 64/130: 100%|██████████| 11/11 [01:19<00:00,  7.26s/it, Loss=0.0277]
# Epoch [64/130], Loss: 0.0320
# Epoch 65/130: 100%|██████████| 11/11 [01:19<00:00,  7.23s/it, Loss=0.0308]
# Epoch [65/130], Loss: 0.0312
# Epoch 66/130: 100%|██████████| 11/11 [01:19<00:00,  7.25s/it, Loss=0.0340]
# Epoch [66/130], Loss: 0.0305
# Epoch 67/130: 100%|██████████| 11/11 [01:20<00:00,  7.27s/it, Loss=0.0325]
# Epoch [67/130], Loss: 0.0305
# Epoch 68/130: 100%|██████████| 11/11 [01:19<00:00,  7.26s/it, Loss=0.0327]
# Epoch [68/130], Loss: 0.0298
# Epoch 69/130: 100%|██████████| 11/11 [01:18<00:00,  7.12s/it, Loss=0.0310]
# Epoch [69/130], Loss: 0.0281
# Epoch 70/130: 100%|██████████| 11/11 [01:19<00:00,  7.26s/it, Loss=0.0263]
# Epoch [70/130], Loss: 0.0281
# Epoch 71/130: 100%|██████████| 11/11 [01:18<00:00,  7.13s/it, Loss=0.0194]
# Epoch [71/130], Loss: 0.0285
# Epoch 72/130: 100%|██████████| 11/11 [01:18<00:00,  7.13s/it, Loss=0.0247]
# Epoch [72/130], Loss: 0.0269
# Epoch 73/130: 100%|██████████| 11/11 [01:18<00:00,  7.16s/it, Loss=0.0305]
# Epoch [73/130], Loss: 0.0271
# Epoch 74/130: 100%|██████████| 11/11 [01:18<00:00,  7.12s/it, Loss=0.0263]
# Epoch [74/130], Loss: 0.0254
# Epoch 75/130: 100%|██████████| 11/11 [01:18<00:00,  7.13s/it, Loss=0.0251]
# Epoch [75/130], Loss: 0.0247
# Epoch 76/130: 100%|██████████| 11/11 [01:19<00:00,  7.20s/it, Loss=0.0317]
# Epoch [76/130], Loss: 0.0252
# Epoch 77/130: 100%|██████████| 11/11 [01:18<00:00,  7.17s/it, Loss=0.0206]
# Epoch [77/130], Loss: 0.0235
# Epoch 78/130: 100%|██████████| 11/11 [01:19<00:00,  7.22s/it, Loss=0.0224]
# Epoch [78/130], Loss: 0.0222
# Epoch 79/130: 100%|██████████| 11/11 [01:19<00:00,  7.23s/it, Loss=0.0220]
# Epoch [79/130], Loss: 0.0221
# Epoch 80/130: 100%|██████████| 11/11 [01:17<00:00,  7.01s/it, Loss=0.0175]
# Epoch [80/130], Loss: 0.0221
# Epoch 81/130: 100%|██████████| 11/11 [01:18<00:00,  7.16s/it, Loss=0.0188]
# Epoch [81/130], Loss: 0.0224
# Epoch 82/130: 100%|██████████| 11/11 [01:18<00:00,  7.12s/it, Loss=0.0187]
# Epoch [82/130], Loss: 0.0208
# Epoch 83/130: 100%|██████████| 11/11 [01:19<00:00,  7.25s/it, Loss=0.0201]
# Epoch [83/130], Loss: 0.0207
# Epoch 84/130: 100%|██████████| 11/11 [01:18<00:00,  7.13s/it, Loss=0.0233]
# Epoch [84/130], Loss: 0.0215
# Epoch 85/130: 100%|██████████| 11/11 [01:19<00:00,  7.23s/it, Loss=0.0166]
# Epoch [85/130], Loss: 0.0233
# Epoch 86/130: 100%|██████████| 11/11 [01:19<00:00,  7.18s/it, Loss=0.0188]
# Epoch [86/130], Loss: 0.0205
# Epoch 87/130: 100%|██████████| 11/11 [01:18<00:00,  7.12s/it, Loss=0.0223]
# Epoch [87/130], Loss: 0.0212
# Epoch 88/130: 100%|██████████| 11/11 [01:19<00:00,  7.26s/it, Loss=0.0158]
# Epoch [88/130], Loss: 0.0197
# Epoch 89/130: 100%|██████████| 11/11 [01:19<00:00,  7.21s/it, Loss=0.0159]
# Epoch [89/130], Loss: 0.0191
# Epoch 90/130: 100%|██████████| 11/11 [01:18<00:00,  7.18s/it, Loss=0.0198]
# Epoch [90/130], Loss: 0.0187
# Epoch 91/130: 100%|██████████| 11/11 [01:17<00:00,  7.05s/it, Loss=0.0161]
# Epoch [91/130], Loss: 0.0181
# Epoch 92/130: 100%|██████████| 11/11 [01:17<00:00,  7.03s/it, Loss=0.0186]
# Epoch [92/130], Loss: 0.0189
# Epoch 93/130: 100%|██████████| 11/11 [01:19<00:00,  7.26s/it, Loss=0.0211]
# Epoch [93/130], Loss: 0.0184
# Epoch 94/130: 100%|██████████| 11/11 [01:19<00:00,  7.26s/it, Loss=0.0201]
# Epoch [94/130], Loss: 0.0176
# Epoch 95/130: 100%|██████████| 11/11 [01:16<00:00,  7.00s/it, Loss=0.0291]
# Epoch [95/130], Loss: 0.0178
# Epoch 96/130: 100%|██████████| 11/11 [01:18<00:00,  7.12s/it, Loss=0.0151]
# Epoch [96/130], Loss: 0.0173
# Epoch 97/130: 100%|██████████| 11/11 [01:19<00:00,  7.24s/it, Loss=0.0229]
# Epoch [97/130], Loss: 0.0177
# Epoch 98/130: 100%|██████████| 11/11 [01:19<00:00,  7.23s/it, Loss=0.0198]
# Epoch [98/130], Loss: 0.0183
# Epoch 99/130: 100%|██████████| 11/11 [01:18<00:00,  7.10s/it, Loss=0.0152]
# Epoch [99/130], Loss: 0.0164
# Epoch 100/130: 100%|██████████| 11/11 [01:19<00:00,  7.19s/it, Loss=0.0130]
# Epoch [100/130], Loss: 0.0161
# Epoch 101/130: 100%|██████████| 11/11 [01:19<00:00,  7.19s/it, Loss=0.0161]
# Epoch [101/130], Loss: 0.0155
# Epoch 102/130: 100%|██████████| 11/11 [01:19<00:00,  7.26s/it, Loss=0.0117]
# Epoch [102/130], Loss: 0.0147
# Epoch 103/130: 100%|██████████| 11/11 [01:18<00:00,  7.12s/it, Loss=0.0170]
# Epoch [103/130], Loss: 0.0164
# Epoch 104/130: 100%|██████████| 11/11 [01:18<00:00,  7.13s/it, Loss=0.0192]
# Epoch [104/130], Loss: 0.0151
# Epoch 105/130: 100%|██████████| 11/11 [01:18<00:00,  7.15s/it, Loss=0.0139]
# Epoch [105/130], Loss: 0.0160
# Epoch 106/130: 100%|██████████| 11/11 [01:18<00:00,  7.13s/it, Loss=0.0147]
# Epoch [106/130], Loss: 0.0154
# Epoch 107/130: 100%|██████████| 11/11 [01:18<00:00,  7.13s/it, Loss=0.0122]
# Epoch [107/130], Loss: 0.0143
# Epoch 108/130: 100%|██████████| 11/11 [01:19<00:00,  7.25s/it, Loss=0.0094]
# Epoch [108/130], Loss: 0.0142
# Epoch 109/130: 100%|██████████| 11/11 [01:17<00:00,  7.01s/it, Loss=0.0196]
# Epoch [109/130], Loss: 0.0140
# Epoch 110/130: 100%|██████████| 11/11 [01:19<00:00,  7.25s/it, Loss=0.0134]
# Epoch [110/130], Loss: 0.0145
# Epoch 111/130: 100%|██████████| 11/11 [01:18<00:00,  7.14s/it, Loss=0.0118]
# Epoch [111/130], Loss: 0.0136
# Epoch 112/130: 100%|██████████| 11/11 [01:18<00:00,  7.17s/it, Loss=0.0114]
# Epoch [112/130], Loss: 0.0129
# Epoch 113/130: 100%|██████████| 11/11 [01:19<00:00,  7.23s/it, Loss=0.0101]
# Epoch [113/130], Loss: 0.0130
# Epoch 114/130: 100%|██████████| 11/11 [01:18<00:00,  7.18s/it, Loss=0.0139]
# Epoch [114/130], Loss: 0.0126
# Epoch 115/130: 100%|██████████| 11/11 [01:18<00:00,  7.17s/it, Loss=0.0120]
# Epoch [115/130], Loss: 0.0134
# Epoch 116/130: 100%|██████████| 11/11 [01:19<00:00,  7.27s/it, Loss=0.0134]
# Epoch [116/130], Loss: 0.0138
# Epoch 117/130: 100%|██████████| 11/11 [01:18<00:00,  7.13s/it, Loss=0.0129]
# Epoch [117/130], Loss: 0.0140
# Epoch 118/130: 100%|██████████| 11/11 [01:18<00:00,  7.17s/it, Loss=0.0136]
# Epoch [118/130], Loss: 0.0140
# Epoch 119/130: 100%|██████████| 11/11 [01:18<00:00,  7.15s/it, Loss=0.0128]
# Epoch [119/130], Loss: 0.0128
# Epoch 120/130: 100%|██████████| 11/11 [01:18<00:00,  7.14s/it, Loss=0.0159]
# Epoch [120/130], Loss: 0.0137
# Epoch 121/130: 100%|██████████| 11/11 [01:19<00:00,  7.26s/it, Loss=0.0137]
# Epoch [121/130], Loss: 0.0122
# Epoch 122/130: 100%|██████████| 11/11 [01:18<00:00,  7.13s/it, Loss=0.0112]
# Epoch [122/130], Loss: 0.0125
# Epoch 123/130: 100%|██████████| 11/11 [01:18<00:00,  7.12s/it, Loss=0.0157]
# Epoch [123/130], Loss: 0.0130
# Epoch 124/130: 100%|██████████| 11/11 [01:19<00:00,  7.20s/it, Loss=0.0155]
# Epoch [124/130], Loss: 0.0121
# Epoch 125/130: 100%|██████████| 11/11 [01:16<00:00,  6.99s/it, Loss=0.0142]
# Epoch [125/130], Loss: 0.0123
# Epoch 126/130: 100%|██████████| 11/11 [01:17<00:00,  7.09s/it, Loss=0.0116]
# Epoch [126/130], Loss: 0.0115
# Epoch 127/130: 100%|██████████| 11/11 [01:17<00:00,  7.06s/it, Loss=0.0116]
# Epoch [127/130], Loss: 0.0107
# Epoch 128/130: 100%|██████████| 11/11 [01:18<00:00,  7.12s/it, Loss=0.0115]
# Epoch [128/130], Loss: 0.0109
# Epoch 129/130: 100%|██████████| 11/11 [01:18<00:00,  7.17s/it, Loss=0.0135]
# Epoch [129/130], Loss: 0.0110
# Epoch 130/130: 100%|██████████| 11/11 [01:19<00:00,  7.22s/it, Loss=0.0118]
# Epoch [130/130], Loss: 0.0110
# 完整模型已保存到 D:/2024/paper2/model/Model/yousong\segformer_full_model.pth
# 模型权重已保存到 D:/2024/paper2/model/Model/yousong\segformer_weights.pth
# 配置文件已保存到 D:/2024/paper2/model/Model/yousong\config.json
# 检查点文件已保存到 D:/2024/paper2/model/Model/yousong\checkpoint.pth
# 训练完成并保存所有文件！
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %%
import torch
import os
from PIL import Image
from torchvision import transforms
from transformers import SegformerForSemanticSegmentation
import numpy as np

# 设置路径
image_dir = "D:/2024/paper2/model/test/yousong"  # 验证图像文件夹
output_mask_dir = "D:/2024/paper2/model/test_masks/yousong"  # 输出掩码文件夹
model_dir = "D:/2024/paper2/model/Model/yousong"  # 模型文件夹

# 加载完整模型
model_path = os.path.join(model_dir, "segformer_full_model.pth")
model = torch.load(model_path)  # 直接加载完整模型
model.eval()  # 设置为评估模式

# 数据预处理（与训练时相同）
transform = transforms.Compose([
    transforms.ToTensor(),  # 转换为 Tensor
])

# 创建输出文件夹（如果不存在）
os.makedirs(output_mask_dir, exist_ok=True)

# 验证集图像文件名
image_filenames = [f for f in os.listdir(image_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# 推理过程
with torch.no_grad():  # 在推理时不需要计算梯度
    for filename in image_filenames:
        img_path = os.path.join(image_dir, filename)
        
        # 读取图像
        image = Image.open(img_path).convert("RGB")
        
        # 保存原始尺寸
        original_size = image.size
        
        # 统一尺寸（假设训练时输入尺寸是1024x1024）
        target_size = (1024, 1024)  # 如果你的验证图像不是1024x1024，可能需要调整此处
        image_resized = image.resize(target_size)

        # 进行预处理
        image_tensor = transform(image_resized).unsqueeze(0).to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))

        # 模型推理
        outputs = model(image_tensor).logits

        # 获取预测的类别标签（背景=0, 树干=1）
        predicted_mask = torch.argmax(outputs, dim=1).squeeze(0).cpu().numpy().astype(np.uint8)

        # 将输出的掩码转换为 0 和 255（黑色背景，白色树干）
        predicted_mask = predicted_mask * 255  # 0 -> 0, 1 -> 255

        # 将预测掩码调整回原始输入图像的大小
        predicted_mask_resized = Image.fromarray(predicted_mask)
        predicted_mask_resized = predicted_mask_resized.resize(original_size, Image.NEAREST)

        # 保存掩码图像
        mask_filename = os.path.join(output_mask_dir, filename.replace(".jpg", ".png").replace(".jpeg", ".png").replace(".png", ".png"))
        predicted_mask_resized.save(mask_filename)

        print(f"Saved mask for {filename} to {mask_filename}")

print("推理完成，所有掩码已保存！")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_22060\1640051395.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path)  # 直接加载完整模型
# Saved mask for 01169980032000_01.jpg to D:/2024/paper2/model/test_masks/yousong\01169980032000_01.png
# Saved mask for 01169980032000_04.jpg to D:/2024/paper2/model/test_masks/yousong\01169980032000_04.png
# Saved mask for 01169980032000_05.jpg to D:/2024/paper2/model/test_masks/yousong\01169980032000_05.png
# Saved mask for 11030020009000_01.jpg to D:/2024/paper2/model/test_masks/yousong\11030020009000_01.png
# Saved mask for 11030020009000_02.jpg to D:/2024/paper2/model/test_masks/yousong\11030020009000_02.png
# Saved mask for 11030020009000_03.jpg to D:/2024/paper2/model/test_masks/yousong\11030020009000_03.png
# Saved mask for 11070070012000_01.jpg to D:/2024/paper2/model/test_masks/yousong\11070070012000_01.png
# Saved mask for 11070070012000_02.jpg to D:/2024/paper2/model/test_masks/yousong\11070070012000_02.png
# Saved mask for 11070070012000_03.jpg to D:/2024/paper2/model/test_masks/yousong\11070070012000_03.png
# Saved mask for 11070070012000_04.jpg to D:/2024/paper2/model/test_masks/yousong\11070070012000_04.png
# Saved mask for 11070070012000_05.jpg to D:/2024/paper2/model/test_masks/yousong\11070070012000_05.png
# Saved mask for 11070070050000_01.jpg to D:/2024/paper2/model/test_masks/yousong\11070070050000_01.png
# Saved mask for 11070070050000_02.jpg to D:/2024/paper2/model/test_masks/yousong\11070070050000_02.png
# Saved mask for 11070070050000_03.jpg to D:/2024/paper2/model/test_masks/yousong\11070070050000_03.png
# Saved mask for 11070070050000_04.jpg to D:/2024/paper2/model/test_masks/yousong\11070070050000_04.png
# Saved mask for 11070070050000_05.jpg to D:/2024/paper2/model/test_masks/yousong\11070070050000_05.png
# Saved mask for 11080070027001_01.jpg to D:/2024/paper2/model/test_masks/yousong\11080070027001_01.png
# Saved mask for 11080070027001_05.jpg to D:/2024/paper2/model/test_masks/yousong\11080070027001_05.png
# Saved mask for 13055070018000_01.jpg to D:/2024/paper2/model/test_masks/yousong\13055070018000_01.png
# Saved mask for 13055070018000_02.jpg to D:/2024/paper2/model/test_masks/yousong\13055070018000_02.png
# Saved mask for 13055070018000_03.jpg to D:/2024/paper2/model/test_masks/yousong\13055070018000_03.png
# Saved mask for 13055070018000_04.jpg to D:/2024/paper2/model/test_masks/yousong\13055070018000_04.png
# Saved mask for 13060010211000_01.jpg to D:/2024/paper2/model/test_masks/yousong\13060010211000_01.png
# Saved mask for 13060010211000_02.jpg to D:/2024/paper2/model/test_masks/yousong\13060010211000_02.png
# Saved mask for 13060010211000_03.jpg to D:/2024/paper2/model/test_masks/yousong\13060010211000_03.png
# Saved mask for 13060010211000_05.jpg to D:/2024/paper2/model/test_masks/yousong\13060010211000_05.png
# Saved mask for 13060010215000_01.jpg to D:/2024/paper2/model/test_masks/yousong\13060010215000_01.png
# Saved mask for 13060010215000_03.jpg to D:/2024/paper2/model/test_masks/yousong\13060010215000_03.png
# Saved mask for 14020110026001_01.jpg to D:/2024/paper2/model/test_masks/yousong\14020110026001_01.png
# Saved mask for 14020110026001_02.jpg to D:/2024/paper2/model/test_masks/yousong\14020110026001_02.png
# Saved mask for 14020110026001_04.jpg to D:/2024/paper2/model/test_masks/yousong\14020110026001_04.png
# Saved mask for 14020110026001_05.jpg to D:/2024/paper2/model/test_masks/yousong\14020110026001_05.png
# Saved mask for 14040270110000_01.jpg to D:/2024/paper2/model/test_masks/yousong\14040270110000_01.png
# Saved mask for 14040270110000_02.jpg to D:/2024/paper2/model/test_masks/yousong\14040270110000_02.png
# Saved mask for 14040270110000_03.jpg to D:/2024/paper2/model/test_masks/yousong\14040270110000_03.png
# Saved mask for 14040270110000_04.jpg to D:/2024/paper2/model/test_masks/yousong\14040270110000_04.png
# Saved mask for 14040270110000_05.jpg to D:/2024/paper2/model/test_masks/yousong\14040270110000_05.png
# Saved mask for 16020010079001_02.jpg to D:/2024/paper2/model/test_masks/yousong\16020010079001_02.png
# Saved mask for 16020050142000_01.jpg to D:/2024/paper2/model/test_masks/yousong\16020050142000_01.png
# Saved mask for 16020050142000_02.jpg to D:/2024/paper2/model/test_masks/yousong\16020050142000_02.png
# Saved mask for 16020050142000_03.jpg to D:/2024/paper2/model/test_masks/yousong\16020050142000_03.png
# Saved mask for 16020050142000_04.jpg to D:/2024/paper2/model/test_masks/yousong\16020050142000_04.png
# Saved mask for 16020080426002_01.jpg to D:/2024/paper2/model/test_masks/yousong\16020080426002_01.png
# Saved mask for 16020080426002_02.jpg to D:/2024/paper2/model/test_masks/yousong\16020080426002_02.png
# Saved mask for 16020080426002_03.jpg to D:/2024/paper2/model/test_masks/yousong\16020080426002_03.png
# Saved mask for 16020080426002_04.jpg to D:/2024/paper2/model/test_masks/yousong\16020080426002_04.png
# Saved mask for 16020220002002_01.jpg to D:/2024/paper2/model/test_masks/yousong\16020220002002_01.png
# Saved mask for 16020220002002_02.jpg to D:/2024/paper2/model/test_masks/yousong\16020220002002_02.png
# Saved mask for 16020220002002_03.jpg to D:/2024/paper2/model/test_masks/yousong\16020220002002_03.png
# Saved mask for 16020220002002_04.jpg to D:/2024/paper2/model/test_masks/yousong\16020220002002_04.png
# Saved mask for 16020220002002_05.jpg to D:/2024/paper2/model/test_masks/yousong\16020220002002_05.png
# Saved mask for 16020220080000_01.jpg to D:/2024/paper2/model/test_masks/yousong\16020220080000_01.png
# Saved mask for 16020220080000_02.jpg to D:/2024/paper2/model/test_masks/yousong\16020220080000_02.png
# Saved mask for 16020220080000_04.jpg to D:/2024/paper2/model/test_masks/yousong\16020220080000_04.png
# Saved mask for 16020220080000_05.jpg to D:/2024/paper2/model/test_masks/yousong\16020220080000_05.png
# Saved mask for 16020250076000_01.jpg to D:/2024/paper2/model/test_masks/yousong\16020250076000_01.png
# Saved mask for 16020250076000_02.jpg to D:/2024/paper2/model/test_masks/yousong\16020250076000_02.png
# Saved mask for 16020250076000_03.jpg to D:/2024/paper2/model/test_masks/yousong\16020250076000_03.png
# Saved mask for 16020250076000_04.jpg to D:/2024/paper2/model/test_masks/yousong\16020250076000_04.png
# Saved mask for 16020250076000_05.jpg to D:/2024/paper2/model/test_masks/yousong\16020250076000_05.png
# Saved mask for 16020250195000_01.jpg to D:/2024/paper2/model/test_masks/yousong\16020250195000_01.png
# Saved mask for 16020250195000_02.jpg to D:/2024/paper2/model/test_masks/yousong\16020250195000_02.png
# Saved mask for 16020250195000_03.jpg to D:/2024/paper2/model/test_masks/yousong\16020250195000_03.png
# Saved mask for 16020250195000_04.jpg to D:/2024/paper2/model/test_masks/yousong\16020250195000_04.png
# Saved mask for 16020250195000_05.jpg to D:/2024/paper2/model/test_masks/yousong\16020250195000_05.png
# Saved mask for 16030130005015_01.jpg to D:/2024/paper2/model/test_masks/yousong\16030130005015_01.png
# Saved mask for 16030130005015_02.jpg to D:/2024/paper2/model/test_masks/yousong\16030130005015_02.png
# Saved mask for 16030130005015_03.jpg to D:/2024/paper2/model/test_masks/yousong\16030130005015_03.png
# Saved mask for 16030130005015_04.jpg to D:/2024/paper2/model/test_masks/yousong\16030130005015_04.png
# Saved mask for 16030130005015_05.jpg to D:/2024/paper2/model/test_masks/yousong\16030130005015_05.png
# Saved mask for 16030140141000_01.jpg to D:/2024/paper2/model/test_masks/yousong\16030140141000_01.png
# Saved mask for 16030140141000_02.jpg to D:/2024/paper2/model/test_masks/yousong\16030140141000_02.png
# Saved mask for 16030140141000_04.jpg to D:/2024/paper2/model/test_masks/yousong\16030140141000_04.png
# Saved mask for 16030140141000_05.jpg to D:/2024/paper2/model/test_masks/yousong\16030140141000_05.png
# Saved mask for 1604002011000_01.jpg to D:/2024/paper2/model/test_masks/yousong\1604002011000_01.png
# Saved mask for 1604002011000_02.jpg to D:/2024/paper2/model/test_masks/yousong\1604002011000_02.png
# Saved mask for 1604002011000_04.jpg to D:/2024/paper2/model/test_masks/yousong\1604002011000_04.png
# Saved mask for 1604002011000_05.jpg to D:/2024/paper2/model/test_masks/yousong\1604002011000_05.png
# Saved mask for 16040050006000_01.jpg to D:/2024/paper2/model/test_masks/yousong\16040050006000_01.png
# Saved mask for 16040050006000_04.jpg to D:/2024/paper2/model/test_masks/yousong\16040050006000_04.png
# Saved mask for 16040050006000_05.jpg to D:/2024/paper2/model/test_masks/yousong\16040050006000_05.png
# Saved mask for 16040050038014_02.jpg to D:/2024/paper2/model/test_masks/yousong\16040050038014_02.png
# Saved mask for 16040050038014_03.jpg to D:/2024/paper2/model/test_masks/yousong\16040050038014_03.png
# Saved mask for 16040050038014_04.jpg to D:/2024/paper2/model/test_masks/yousong\16040050038014_04.png
# Saved mask for 16040050038014_05.jpg to D:/2024/paper2/model/test_masks/yousong\16040050038014_05.png
# Saved mask for 17110050064001_01.jpg to D:/2024/paper2/model/test_masks/yousong\17110050064001_01.png
# Saved mask for 17110050064001_03.jpg to D:/2024/paper2/model/test_masks/yousong\17110050064001_03.png
# Saved mask for 17110050064001_04.jpg to D:/2024/paper2/model/test_masks/yousong\17110050064001_04.png
# Saved mask for 17110050080001_04.jpg to D:/2024/paper2/model/test_masks/yousong\17110050080001_04.png
# Saved mask for 17110050080001_05.jpg to D:/2024/paper2/model/test_masks/yousong\17110050080001_05.png
# Saved mask for 28060150034000_02.jpg to D:/2024/paper2/model/test_masks/yousong\28060150034000_02.png
# Saved mask for 28060150034000_04.jpg to D:/2024/paper2/model/test_masks/yousong\28060150034000_04.png
# Saved mask for 28060160009000_02.jpg to D:/2024/paper2/model/test_masks/yousong\28060160009000_02.png
# Saved mask for 28060170033000_01.jpg to D:/2024/paper2/model/test_masks/yousong\28060170033000_01.png
# Saved mask for 28060170033000_03.jpg to D:/2024/paper2/model/test_masks/yousong\28060170033000_03.png
# Saved mask for 28060170033000_04.jpg to D:/2024/paper2/model/test_masks/yousong\28060170033000_04.png
# Saved mask for 28060170033000_05.jpg to D:/2024/paper2/model/test_masks/yousong\28060170033000_05.png
# Saved mask for 28060210011004_01.jpg to D:/2024/paper2/model/test_masks/yousong\28060210011004_01.png
# Saved mask for 28060210011004_02.jpg to D:/2024/paper2/model/test_masks/yousong\28060210011004_02.png
# Saved mask for 28060210011004_03.jpg to D:/2024/paper2/model/test_masks/yousong\28060210011004_03.png
# Saved mask for 28060210011004_04.jpg to D:/2024/paper2/model/test_masks/yousong\28060210011004_04.png
# Saved mask for 28060210011004_05.jpg to D:/2024/paper2/model/test_masks/yousong\28060210011004_05.png
# Saved mask for 28060210029000_01.jpg to D:/2024/paper2/model/test_masks/yousong\28060210029000_01.png
# Saved mask for 28060210029000_03.jpg to D:/2024/paper2/model/test_masks/yousong\28060210029000_03.png
# Saved mask for 28060210029000_05.jpg to D:/2024/paper2/model/test_masks/yousong\28060210029000_05.png
# Saved mask for 28060220002000_01.jpg to D:/2024/paper2/model/test_masks/yousong\28060220002000_01.png
# Saved mask for 28060220002000_02.jpg to D:/2024/paper2/model/test_masks/yousong\28060220002000_02.png
# Saved mask for 28060270004000_05.jpg to D:/2024/paper2/model/test_masks/yousong\28060270004000_05.png
# Saved mask for 28060270044001_01.jpg to D:/2024/paper2/model/test_masks/yousong\28060270044001_01.png
# Saved mask for 28060270118000_04.jpg to D:/2024/paper2/model/test_masks/yousong\28060270118000_04.png
# Saved mask for 28060340023000_05.jpg to D:/2024/paper2/model/test_masks/yousong\28060340023000_05.png
# Saved mask for 28060340033000_01.jpg to D:/2024/paper2/model/test_masks/yousong\28060340033000_01.png
# Saved mask for 28060340033000_02.jpg to D:/2024/paper2/model/test_masks/yousong\28060340033000_02.png
# Saved mask for 28060340033000_03.jpg to D:/2024/paper2/model/test_masks/yousong\28060340033000_03.png
# Saved mask for 28060340033000_04.jpg to D:/2024/paper2/model/test_masks/yousong\28060340033000_04.png
# Saved mask for 28060340033000_05.jpg to D:/2024/paper2/model/test_masks/yousong\28060340033000_05.png
# Saved mask for 28060340072000_01.jpg to D:/2024/paper2/model/test_masks/yousong\28060340072000_01.png
# Saved mask for 28060340081000_01.jpg to D:/2024/paper2/model/test_masks/yousong\28060340081000_01.png
# Saved mask for 28080020019000_01.jpg to D:/2024/paper2/model/test_masks/yousong\28080020019000_01.png
# Saved mask for 28080020019000_02.jpg to D:/2024/paper2/model/test_masks/yousong\28080020019000_02.png
# Saved mask for 28080020019000_03.jpg to D:/2024/paper2/model/test_masks/yousong\28080020019000_03.png
# Saved mask for 28080020019000_04.jpg to D:/2024/paper2/model/test_masks/yousong\28080020019000_04.png
# Saved mask for 28080020019000_05.jpg to D:/2024/paper2/model/test_masks/yousong\28080020019000_05.png
# Saved mask for 28080090006000_02.jpg to D:/2024/paper2/model/test_masks/yousong\28080090006000_02.png
# Saved mask for 28080090006000_03.jpg to D:/2024/paper2/model/test_masks/yousong\28080090006000_03.png
# Saved mask for 28230010011000_01.jpg to D:/2024/paper2/model/test_masks/yousong\28230010011000_01.png
# Saved mask for 28230010011000_03.jpg to D:/2024/paper2/model/test_masks/yousong\28230010011000_03.png
# Saved mask for 28230010011000_04.jpg to D:/2024/paper2/model/test_masks/yousong\28230010011000_04.png
# Saved mask for 28230010011000_05.jpg to D:/2024/paper2/model/test_masks/yousong\28230010011000_05.png
# Saved mask for 28230010032000_02.jpg to D:/2024/paper2/model/test_masks/yousong\28230010032000_02.png
# Saved mask for 28230010032000_03.jpg to D:/2024/paper2/model/test_masks/yousong\28230010032000_03.png
# Saved mask for 28230010032000_04.jpg to D:/2024/paper2/model/test_masks/yousong\28230010032000_04.png
# Saved mask for 28230010032000_05.jpg to D:/2024/paper2/model/test_masks/yousong\28230010032000_05.png
# Saved mask for 28230050001000_01.jpg to D:/2024/paper2/model/test_masks/yousong\28230050001000_01.png
# Saved mask for 28230050001000_02.jpg to D:/2024/paper2/model/test_masks/yousong\28230050001000_02.png
# Saved mask for 28230060003000_01.jpg to D:/2024/paper2/model/test_masks/yousong\28230060003000_01.png
# Saved mask for 28230060003000_02.jpg to D:/2024/paper2/model/test_masks/yousong\28230060003000_02.png
# Saved mask for 28230060003000_04.jpg to D:/2024/paper2/model/test_masks/yousong\28230060003000_04.png
# Saved mask for 28230060006000_01.jpg to D:/2024/paper2/model/test_masks/yousong\28230060006000_01.png
# Saved mask for 28230060006000_02.jpg to D:/2024/paper2/model/test_masks/yousong\28230060006000_02.png
# Saved mask for 28230060006000_05.jpg to D:/2024/paper2/model/test_masks/yousong\28230060006000_05.png
# Saved mask for 29030230023000_01.jpg to D:/2024/paper2/model/test_masks/yousong\29030230023000_01.png
# Saved mask for 29030230023000_02.jpg to D:/2024/paper2/model/test_masks/yousong\29030230023000_02.png
# Saved mask for 29030230023000_04.jpg to D:/2024/paper2/model/test_masks/yousong\29030230023000_04.png
# Saved mask for 29050100017005_02.jpg to D:/2024/paper2/model/test_masks/yousong\29050100017005_02.png
# Saved mask for 29080100011000_01.jpg to D:/2024/paper2/model/test_masks/yousong\29080100011000_01.png
# Saved mask for 29080100011000_02.jpg to D:/2024/paper2/model/test_masks/yousong\29080100011000_02.png
# Saved mask for 29080100011000_03.jpg to D:/2024/paper2/model/test_masks/yousong\29080100011000_03.png
# Saved mask for 29080100011000_04.jpg to D:/2024/paper2/model/test_masks/yousong\29080100011000_04.png
# Saved mask for 29080100011000_05.jpg to D:/2024/paper2/model/test_masks/yousong\29080100011000_05.png
# Saved mask for 29140020016000_01.jpg to D:/2024/paper2/model/test_masks/yousong\29140020016000_01.png
# Saved mask for 29140020016000_03.jpg to D:/2024/paper2/model/test_masks/yousong\29140020016000_03.png
# Saved mask for 29140020016000_04.jpg to D:/2024/paper2/model/test_masks/yousong\29140020016000_04.png
# Saved mask for 29140020016000_05.jpg to D:/2024/paper2/model/test_masks/yousong\29140020016000_05.png
# Saved mask for 29140030013001_03.jpg to D:/2024/paper2/model/test_masks/yousong\29140030013001_03.png
# Saved mask for 29140030013001_05.jpg to D:/2024/paper2/model/test_masks/yousong\29140030013001_05.png
# Saved mask for 29140030034000_01.jpg to D:/2024/paper2/model/test_masks/yousong\29140030034000_01.png
# Saved mask for 29140030034000_02.jpg to D:/2024/paper2/model/test_masks/yousong\29140030034000_02.png
# Saved mask for 29140030034000_03.jpg to D:/2024/paper2/model/test_masks/yousong\29140030034000_03.png
# Saved mask for 29140030034000_04.jpg to D:/2024/paper2/model/test_masks/yousong\29140030034000_04.png
# Saved mask for 29140030034000_05.jpg to D:/2024/paper2/model/test_masks/yousong\29140030034000_05.png
# Saved mask for 29140110001000_05.jpg to D:/2024/paper2/model/test_masks/yousong\29140110001000_05.png
# Saved mask for 29140110093000_01.jpg to D:/2024/paper2/model/test_masks/yousong\29140110093000_01.png
# Saved mask for 29140110093000_02.jpg to D:/2024/paper2/model/test_masks/yousong\29140110093000_02.png
# Saved mask for 29140110093000_03.jpg to D:/2024/paper2/model/test_masks/yousong\29140110093000_03.png
# Saved mask for 29140110093000_04.jpg to D:/2024/paper2/model/test_masks/yousong\29140110093000_04.png
# Saved mask for 29140110093000_05.jpg to D:/2024/paper2/model/test_masks/yousong\29140110093000_05.png
# Saved mask for 29140170008000_01.jpg to D:/2024/paper2/model/test_masks/yousong\29140170008000_01.png
# Saved mask for 29140170008000_02.jpg to D:/2024/paper2/model/test_masks/yousong\29140170008000_02.png
# Saved mask for 29140170008000_03.jpg to D:/2024/paper2/model/test_masks/yousong\29140170008000_03.png
# Saved mask for C005_01.jpg to D:/2024/paper2/model/test_masks/yousong\C005_01.png
# Saved mask for C020_01.jpg to D:/2024/paper2/model/test_masks/yousong\C020_01.png
# Saved mask for C020_02.jpg to D:/2024/paper2/model/test_masks/yousong\C020_02.png
# Saved mask for C020_03.jpg to D:/2024/paper2/model/test_masks/yousong\C020_03.png
# Saved mask for C020_05.jpg to D:/2024/paper2/model/test_masks/yousong\C020_05.png
# Saved mask for C035_03.jpg to D:/2024/paper2/model/test_masks/yousong\C035_03.png
# Saved mask for C035_04.jpg to D:/2024/paper2/model/test_masks/yousong\C035_04.png
# 推理完成，所有掩码已保存！

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# 设置路径
image_dir = "D:/2024/paper2/model/test/yousong"  # 验证图像文件夹
mask_dir = "D:/2024/paper2/model/test_masks/yousong"  # 单通道掩码文件夹
output_dir = "D:/2024/paper2/model/test_comparison/yousong"  # 输出图片文件夹

# 创建输出文件夹（如果不存在）
os.makedirs(output_dir, exist_ok=True)

# 获取图像文件名
image_filenames = [f for f in os.listdir(image_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# 处理每个图像
for filename in image_filenames:
    # 构造图像路径和掩码路径
    img_path = os.path.join(image_dir, filename)
    mask_path = os.path.join(mask_dir, filename.replace(".jpg", ".png").replace(".jpeg", ".png").replace(".png", ".png"))

    # 读取验证图像和掩码图像
    image = Image.open(img_path).convert("RGB")  # 读取并转换为 RGB 图像
    mask = Image.open(mask_path).convert("L")  # 读取掩码并转换为灰度图像（L 模式）

    # 将掩码图像转换为 numpy 数组（0 表示背景，255 表示树干）
    mask_array = np.array(mask)

    # 将掩码值转换为 0 或 1（0 -> 背景，1 -> 树干）
    mask_binary = (mask_array > 127).astype(int)  # 将大于127的像素值转为 1，小于等于127的为 0

    # 将原始图像和掩码图像叠加
    image_array = np.array(image)

    # 使用掩码区域将原始图像覆盖成不同的颜色（比如将树干区域用红色标出）
    # 红色区域表示模型预测的树干区域
    image_with_mask = image_array.copy()
    image_with_mask[mask_binary == 1] = [255, 0, 0]  # 将树干区域标记为红色 [255, 0, 0]

    # 将原始图像与掩码图像并排显示
    # 设置高分辨率图像
    fig, axes = plt.subplots(1, 2, figsize=(16, 8), dpi=200)  # 设置更大的图像大小和更高的 DPI

    # 显示原始图像
    axes[0].imshow(image)
    axes[0].set_title("Original Image")
    axes[0].axis("off")

    # 显示叠加图像
    axes[1].imshow(image_with_mask)
    axes[1].set_title("Image with Predicted Mask")
    axes[1].axis("off")

    # 保存结果图像
    comparison_filename = os.path.join(output_dir, filename.replace(".jpg", "_comparison.png").replace(".jpeg", "_comparison.png").replace(".png", "_comparison.png"))
    plt.savefig(comparison_filename, dpi=200)  # 保存为高分辨率图像
    plt.close()

    print(f"Saved comparison image for {filename} to {comparison_filename}")

print("所有比较图像已保存！")
# Out:
# Saved comparison image for 01169980032000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\01169980032000_01_comparison_comparison.png
# Saved comparison image for 01169980032000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\01169980032000_04_comparison_comparison.png
# Saved comparison image for 01169980032000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\01169980032000_05_comparison_comparison.png
# Saved comparison image for 11030020009000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\11030020009000_01_comparison_comparison.png
# Saved comparison image for 11030020009000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\11030020009000_02_comparison_comparison.png
# Saved comparison image for 11030020009000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\11030020009000_03_comparison_comparison.png
# Saved comparison image for 11070070012000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\11070070012000_01_comparison_comparison.png
# Saved comparison image for 11070070012000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\11070070012000_02_comparison_comparison.png
# Saved comparison image for 11070070012000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\11070070012000_03_comparison_comparison.png
# Saved comparison image for 11070070012000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\11070070012000_04_comparison_comparison.png
# Saved comparison image for 11070070012000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\11070070012000_05_comparison_comparison.png
# Saved comparison image for 11070070050000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\11070070050000_01_comparison_comparison.png
# Saved comparison image for 11070070050000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\11070070050000_02_comparison_comparison.png
# Saved comparison image for 11070070050000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\11070070050000_03_comparison_comparison.png
# Saved comparison image for 11070070050000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\11070070050000_04_comparison_comparison.png
# Saved comparison image for 11070070050000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\11070070050000_05_comparison_comparison.png
# Saved comparison image for 11080070027001_01.jpg to D:/2024/paper2/model/test_comparison/yousong\11080070027001_01_comparison_comparison.png
# Saved comparison image for 11080070027001_05.jpg to D:/2024/paper2/model/test_comparison/yousong\11080070027001_05_comparison_comparison.png
# Saved comparison image for 13055070018000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\13055070018000_01_comparison_comparison.png
# Saved comparison image for 13055070018000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\13055070018000_02_comparison_comparison.png
# Saved comparison image for 13055070018000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\13055070018000_03_comparison_comparison.png
# Saved comparison image for 13055070018000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\13055070018000_04_comparison_comparison.png
# Saved comparison image for 13060010211000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\13060010211000_01_comparison_comparison.png
# Saved comparison image for 13060010211000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\13060010211000_02_comparison_comparison.png
# Saved comparison image for 13060010211000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\13060010211000_03_comparison_comparison.png
# Saved comparison image for 13060010211000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\13060010211000_05_comparison_comparison.png
# Saved comparison image for 13060010215000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\13060010215000_01_comparison_comparison.png
# Saved comparison image for 13060010215000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\13060010215000_03_comparison_comparison.png
# Saved comparison image for 14020110026001_01.jpg to D:/2024/paper2/model/test_comparison/yousong\14020110026001_01_comparison_comparison.png
# Saved comparison image for 14020110026001_02.jpg to D:/2024/paper2/model/test_comparison/yousong\14020110026001_02_comparison_comparison.png
# Saved comparison image for 14020110026001_04.jpg to D:/2024/paper2/model/test_comparison/yousong\14020110026001_04_comparison_comparison.png
# Saved comparison image for 14020110026001_05.jpg to D:/2024/paper2/model/test_comparison/yousong\14020110026001_05_comparison_comparison.png
# Saved comparison image for 14040270110000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\14040270110000_01_comparison_comparison.png
# Saved comparison image for 14040270110000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\14040270110000_02_comparison_comparison.png
# Saved comparison image for 14040270110000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\14040270110000_03_comparison_comparison.png
# Saved comparison image for 14040270110000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\14040270110000_04_comparison_comparison.png
# Saved comparison image for 14040270110000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\14040270110000_05_comparison_comparison.png
# Saved comparison image for 16020010079001_02.jpg to D:/2024/paper2/model/test_comparison/yousong\16020010079001_02_comparison_comparison.png
# Saved comparison image for 16020050142000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\16020050142000_01_comparison_comparison.png
# Saved comparison image for 16020050142000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\16020050142000_02_comparison_comparison.png
# Saved comparison image for 16020050142000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\16020050142000_03_comparison_comparison.png
# Saved comparison image for 16020050142000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\16020050142000_04_comparison_comparison.png
# Saved comparison image for 16020080426002_01.jpg to D:/2024/paper2/model/test_comparison/yousong\16020080426002_01_comparison_comparison.png
# Saved comparison image for 16020080426002_02.jpg to D:/2024/paper2/model/test_comparison/yousong\16020080426002_02_comparison_comparison.png
# Saved comparison image for 16020080426002_03.jpg to D:/2024/paper2/model/test_comparison/yousong\16020080426002_03_comparison_comparison.png
# Saved comparison image for 16020080426002_04.jpg to D:/2024/paper2/model/test_comparison/yousong\16020080426002_04_comparison_comparison.png
# Saved comparison image for 16020220002002_01.jpg to D:/2024/paper2/model/test_comparison/yousong\16020220002002_01_comparison_comparison.png
# Saved comparison image for 16020220002002_02.jpg to D:/2024/paper2/model/test_comparison/yousong\16020220002002_02_comparison_comparison.png
# Saved comparison image for 16020220002002_03.jpg to D:/2024/paper2/model/test_comparison/yousong\16020220002002_03_comparison_comparison.png
# Saved comparison image for 16020220002002_04.jpg to D:/2024/paper2/model/test_comparison/yousong\16020220002002_04_comparison_comparison.png
# Saved comparison image for 16020220002002_05.jpg to D:/2024/paper2/model/test_comparison/yousong\16020220002002_05_comparison_comparison.png
# Saved comparison image for 16020220080000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\16020220080000_01_comparison_comparison.png
# Saved comparison image for 16020220080000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\16020220080000_02_comparison_comparison.png
# Saved comparison image for 16020220080000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\16020220080000_04_comparison_comparison.png
# Saved comparison image for 16020220080000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\16020220080000_05_comparison_comparison.png
# Saved comparison image for 16020250076000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\16020250076000_01_comparison_comparison.png
# Saved comparison image for 16020250076000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\16020250076000_02_comparison_comparison.png
# Saved comparison image for 16020250076000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\16020250076000_03_comparison_comparison.png
# Saved comparison image for 16020250076000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\16020250076000_04_comparison_comparison.png
# Saved comparison image for 16020250076000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\16020250076000_05_comparison_comparison.png
# Saved comparison image for 16020250195000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\16020250195000_01_comparison_comparison.png
# Saved comparison image for 16020250195000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\16020250195000_02_comparison_comparison.png
# Saved comparison image for 16020250195000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\16020250195000_03_comparison_comparison.png
# Saved comparison image for 16020250195000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\16020250195000_04_comparison_comparison.png
# Saved comparison image for 16020250195000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\16020250195000_05_comparison_comparison.png
# Saved comparison image for 16030130005015_01.jpg to D:/2024/paper2/model/test_comparison/yousong\16030130005015_01_comparison_comparison.png
# Saved comparison image for 16030130005015_02.jpg to D:/2024/paper2/model/test_comparison/yousong\16030130005015_02_comparison_comparison.png
# Saved comparison image for 16030130005015_03.jpg to D:/2024/paper2/model/test_comparison/yousong\16030130005015_03_comparison_comparison.png
# Saved comparison image for 16030130005015_04.jpg to D:/2024/paper2/model/test_comparison/yousong\16030130005015_04_comparison_comparison.png
# Saved comparison image for 16030130005015_05.jpg to D:/2024/paper2/model/test_comparison/yousong\16030130005015_05_comparison_comparison.png
# Saved comparison image for 16030140141000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\16030140141000_01_comparison_comparison.png
# Saved comparison image for 16030140141000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\16030140141000_02_comparison_comparison.png
# Saved comparison image for 16030140141000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\16030140141000_04_comparison_comparison.png
# Saved comparison image for 16030140141000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\16030140141000_05_comparison_comparison.png
# Saved comparison image for 1604002011000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\1604002011000_01_comparison_comparison.png
# Saved comparison image for 1604002011000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\1604002011000_02_comparison_comparison.png
# Saved comparison image for 1604002011000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\1604002011000_04_comparison_comparison.png
# Saved comparison image for 1604002011000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\1604002011000_05_comparison_comparison.png
# Saved comparison image for 16040050006000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\16040050006000_01_comparison_comparison.png
# Saved comparison image for 16040050006000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\16040050006000_04_comparison_comparison.png
# Saved comparison image for 16040050006000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\16040050006000_05_comparison_comparison.png
# Saved comparison image for 16040050038014_02.jpg to D:/2024/paper2/model/test_comparison/yousong\16040050038014_02_comparison_comparison.png
# Saved comparison image for 16040050038014_03.jpg to D:/2024/paper2/model/test_comparison/yousong\16040050038014_03_comparison_comparison.png
# Saved comparison image for 16040050038014_04.jpg to D:/2024/paper2/model/test_comparison/yousong\16040050038014_04_comparison_comparison.png
# Saved comparison image for 16040050038014_05.jpg to D:/2024/paper2/model/test_comparison/yousong\16040050038014_05_comparison_comparison.png
# Saved comparison image for 17110050064001_01.jpg to D:/2024/paper2/model/test_comparison/yousong\17110050064001_01_comparison_comparison.png
# Saved comparison image for 17110050064001_03.jpg to D:/2024/paper2/model/test_comparison/yousong\17110050064001_03_comparison_comparison.png
# Saved comparison image for 17110050064001_04.jpg to D:/2024/paper2/model/test_comparison/yousong\17110050064001_04_comparison_comparison.png
# Saved comparison image for 17110050080001_04.jpg to D:/2024/paper2/model/test_comparison/yousong\17110050080001_04_comparison_comparison.png
# Saved comparison image for 17110050080001_05.jpg to D:/2024/paper2/model/test_comparison/yousong\17110050080001_05_comparison_comparison.png
# Saved comparison image for 28060150034000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\28060150034000_02_comparison_comparison.png
# Saved comparison image for 28060150034000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\28060150034000_04_comparison_comparison.png
# Saved comparison image for 28060160009000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\28060160009000_02_comparison_comparison.png
# Saved comparison image for 28060170033000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\28060170033000_01_comparison_comparison.png
# Saved comparison image for 28060170033000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\28060170033000_03_comparison_comparison.png
# Saved comparison image for 28060170033000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\28060170033000_04_comparison_comparison.png
# Saved comparison image for 28060170033000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\28060170033000_05_comparison_comparison.png
# Saved comparison image for 28060210011004_01.jpg to D:/2024/paper2/model/test_comparison/yousong\28060210011004_01_comparison_comparison.png
# Saved comparison image for 28060210011004_02.jpg to D:/2024/paper2/model/test_comparison/yousong\28060210011004_02_comparison_comparison.png
# Saved comparison image for 28060210011004_03.jpg to D:/2024/paper2/model/test_comparison/yousong\28060210011004_03_comparison_comparison.png
# Saved comparison image for 28060210011004_04.jpg to D:/2024/paper2/model/test_comparison/yousong\28060210011004_04_comparison_comparison.png
# Saved comparison image for 28060210011004_05.jpg to D:/2024/paper2/model/test_comparison/yousong\28060210011004_05_comparison_comparison.png
# Saved comparison image for 28060210029000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\28060210029000_01_comparison_comparison.png
# Saved comparison image for 28060210029000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\28060210029000_03_comparison_comparison.png
# Saved comparison image for 28060210029000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\28060210029000_05_comparison_comparison.png
# Saved comparison image for 28060220002000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\28060220002000_01_comparison_comparison.png
# Saved comparison image for 28060220002000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\28060220002000_02_comparison_comparison.png
# Saved comparison image for 28060270004000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\28060270004000_05_comparison_comparison.png
# Saved comparison image for 28060270044001_01.jpg to D:/2024/paper2/model/test_comparison/yousong\28060270044001_01_comparison_comparison.png
# Saved comparison image for 28060270118000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\28060270118000_04_comparison_comparison.png
# Saved comparison image for 28060340023000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\28060340023000_05_comparison_comparison.png
# Saved comparison image for 28060340033000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\28060340033000_01_comparison_comparison.png
# Saved comparison image for 28060340033000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\28060340033000_02_comparison_comparison.png
# Saved comparison image for 28060340033000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\28060340033000_03_comparison_comparison.png
# Saved comparison image for 28060340033000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\28060340033000_04_comparison_comparison.png
# Saved comparison image for 28060340033000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\28060340033000_05_comparison_comparison.png
# Saved comparison image for 28060340072000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\28060340072000_01_comparison_comparison.png
# Saved comparison image for 28060340081000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\28060340081000_01_comparison_comparison.png
# Saved comparison image for 28080020019000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\28080020019000_01_comparison_comparison.png
# Saved comparison image for 28080020019000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\28080020019000_02_comparison_comparison.png
# Saved comparison image for 28080020019000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\28080020019000_03_comparison_comparison.png
# Saved comparison image for 28080020019000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\28080020019000_04_comparison_comparison.png
# Saved comparison image for 28080020019000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\28080020019000_05_comparison_comparison.png
# Saved comparison image for 28080090006000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\28080090006000_02_comparison_comparison.png
# Saved comparison image for 28080090006000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\28080090006000_03_comparison_comparison.png
# Saved comparison image for 28230010011000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\28230010011000_01_comparison_comparison.png
# Saved comparison image for 28230010011000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\28230010011000_03_comparison_comparison.png
# Saved comparison image for 28230010011000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\28230010011000_04_comparison_comparison.png
# Saved comparison image for 28230010011000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\28230010011000_05_comparison_comparison.png
# Saved comparison image for 28230010032000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\28230010032000_02_comparison_comparison.png
# Saved comparison image for 28230010032000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\28230010032000_03_comparison_comparison.png
# Saved comparison image for 28230010032000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\28230010032000_04_comparison_comparison.png
# Saved comparison image for 28230010032000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\28230010032000_05_comparison_comparison.png
# Saved comparison image for 28230050001000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\28230050001000_01_comparison_comparison.png
# Saved comparison image for 28230050001000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\28230050001000_02_comparison_comparison.png
# Saved comparison image for 28230060003000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\28230060003000_01_comparison_comparison.png
# Saved comparison image for 28230060003000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\28230060003000_02_comparison_comparison.png
# Saved comparison image for 28230060003000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\28230060003000_04_comparison_comparison.png
# Saved comparison image for 28230060006000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\28230060006000_01_comparison_comparison.png
# Saved comparison image for 28230060006000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\28230060006000_02_comparison_comparison.png
# Saved comparison image for 28230060006000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\28230060006000_05_comparison_comparison.png
# Saved comparison image for 29030230023000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\29030230023000_01_comparison_comparison.png
# Saved comparison image for 29030230023000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\29030230023000_02_comparison_comparison.png
# Saved comparison image for 29030230023000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\29030230023000_04_comparison_comparison.png
# Saved comparison image for 29050100017005_02.jpg to D:/2024/paper2/model/test_comparison/yousong\29050100017005_02_comparison_comparison.png
# Saved comparison image for 29080100011000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\29080100011000_01_comparison_comparison.png
# Saved comparison image for 29080100011000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\29080100011000_02_comparison_comparison.png
# Saved comparison image for 29080100011000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\29080100011000_03_comparison_comparison.png
# Saved comparison image for 29080100011000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\29080100011000_04_comparison_comparison.png
# Saved comparison image for 29080100011000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\29080100011000_05_comparison_comparison.png
# Saved comparison image for 29140020016000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\29140020016000_01_comparison_comparison.png
# Saved comparison image for 29140020016000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\29140020016000_03_comparison_comparison.png
# Saved comparison image for 29140020016000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\29140020016000_04_comparison_comparison.png
# Saved comparison image for 29140020016000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\29140020016000_05_comparison_comparison.png
# Saved comparison image for 29140030013001_03.jpg to D:/2024/paper2/model/test_comparison/yousong\29140030013001_03_comparison_comparison.png
# Saved comparison image for 29140030013001_05.jpg to D:/2024/paper2/model/test_comparison/yousong\29140030013001_05_comparison_comparison.png
# Saved comparison image for 29140030034000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\29140030034000_01_comparison_comparison.png
# Saved comparison image for 29140030034000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\29140030034000_02_comparison_comparison.png
# Saved comparison image for 29140030034000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\29140030034000_03_comparison_comparison.png
# Saved comparison image for 29140030034000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\29140030034000_04_comparison_comparison.png
# Saved comparison image for 29140030034000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\29140030034000_05_comparison_comparison.png
# Saved comparison image for 29140110001000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\29140110001000_05_comparison_comparison.png
# Saved comparison image for 29140110093000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\29140110093000_01_comparison_comparison.png
# Saved comparison image for 29140110093000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\29140110093000_02_comparison_comparison.png
# Saved comparison image for 29140110093000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\29140110093000_03_comparison_comparison.png
# Saved comparison image for 29140110093000_04.jpg to D:/2024/paper2/model/test_comparison/yousong\29140110093000_04_comparison_comparison.png
# Saved comparison image for 29140110093000_05.jpg to D:/2024/paper2/model/test_comparison/yousong\29140110093000_05_comparison_comparison.png
# Saved comparison image for 29140170008000_01.jpg to D:/2024/paper2/model/test_comparison/yousong\29140170008000_01_comparison_comparison.png
# Saved comparison image for 29140170008000_02.jpg to D:/2024/paper2/model/test_comparison/yousong\29140170008000_02_comparison_comparison.png
# Saved comparison image for 29140170008000_03.jpg to D:/2024/paper2/model/test_comparison/yousong\29140170008000_03_comparison_comparison.png
# Saved comparison image for C005_01.jpg to D:/2024/paper2/model/test_comparison/yousong\C005_01_comparison_comparison.png
# Saved comparison image for C020_01.jpg to D:/2024/paper2/model/test_comparison/yousong\C020_01_comparison_comparison.png
# Saved comparison image for C020_02.jpg to D:/2024/paper2/model/test_comparison/yousong\C020_02_comparison_comparison.png
# Saved comparison image for C020_03.jpg to D:/2024/paper2/model/test_comparison/yousong\C020_03_comparison_comparison.png
# Saved comparison image for C020_05.jpg to D:/2024/paper2/model/test_comparison/yousong\C020_05_comparison_comparison.png
# Saved comparison image for C035_03.jpg to D:/2024/paper2/model/test_comparison/yousong\C035_03_comparison_comparison.png
# Saved comparison image for C035_04.jpg to D:/2024/paper2/model/test_comparison/yousong\C035_04_comparison_comparison.png
# 所有比较图像已保存！
