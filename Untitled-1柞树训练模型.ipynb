# %%
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from transformers import SegformerForSemanticSegmentation, SegformerConfig
import os
import numpy as np
from tqdm import tqdm
import json

# 数据集类
class TreeTrunkDataset(Dataset):
    def __init__(self, image_dir, mask_dir, json_dir, transform=None, target_size=(1024, 1024)):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.json_dir = json_dir
        self.transform = transform
        self.target_size = target_size  # 目标尺寸
        self.images = [img for img in os.listdir(image_dir) if img.lower().endswith(('.jpg', '.jpeg', '.png'))]
        self.images = [img for img in self.images if os.path.exists(os.path.join(mask_dir, img.replace(".JPG", ".png").replace(".jpg", ".png").replace(".jpeg", ".png")))]
        self.images = [img for img in self.images if os.path.exists(os.path.join(json_dir, img.replace(".JPG", ".json").replace(".jpg", ".json").replace(".jpeg", ".json")))]

        # 添加调试信息
        if len(self.images) == 0:
            print("未找到匹配的图像、掩码或 JSON 文件，请检查目录和文件扩展名。")
        else:
            print(f"找到 {len(self.images)} 个匹配的图像、掩码和 JSON 文件。")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.images[idx])
        mask_path = os.path.join(self.mask_dir, self.images[idx].replace(".JPG", ".png").replace(".jpg", ".png").replace(".jpeg", ".png"))
        json_path = os.path.join(self.json_dir, self.images[idx].replace(".JPG", ".json").replace(".jpg", ".json").replace(".jpeg", ".json"))
        
        # 读取图像
        image = Image.open(img_path).convert("RGB")  # 使用 Pillow 打开图像
        mask = Image.open(mask_path).convert('L')  # 转换为灰度图像
        mask = np.array(mask)  # 转换为numpy数组
        
        # 读取 JSON 文件
        with open(json_path, 'r') as f:
            json_data = json.load(f)

        # 统一图像和掩码的大小
        image = image.resize(self.target_size)
        mask = Image.fromarray(mask).resize(self.target_size, Image.NEAREST)
        
        # 转换为 Tensor
        if self.transform:
            image = self.transform(image)

        # 确保掩码值在0和1之间
        mask = np.clip(mask, 0, 1)
        mask = torch.tensor(mask, dtype=torch.long)
        
        return image, mask, json_data  # 返回 image, mask 和 json_data

# 自定义 collate_fn，确保每个批次中的数据大小一致
def collate_fn(batch):
    images, masks, json_data = zip(*batch)

    # 将所有图像堆叠成一个批次
    images = torch.stack(images, dim=0)
    
    # 将所有掩码堆叠成一个批次
    masks = torch.stack(masks, dim=0)

    return images, masks

# 设置路径
image_dir = "D:/2024/paper2/model/input_images2/zuoshu"
mask_dir = "D:/2024/paper2/model/output_masks/zuoshu"
json_dir = "D:/2024/paper2/model/sorted_JSON/zuoshu"

# 数据增强与预处理
transform = transforms.Compose([
    transforms.ToTensor(),  # 转换为 Tensor
])

# 数据集和数据加载器
dataset = TreeTrunkDataset(image_dir=image_dir, mask_dir=mask_dir, json_dir=json_dir, transform=transform)

# 检查数据集是否为空
if len(dataset) == 0:
    raise ValueError("数据集为空，请检查图像和掩码文件是否匹配且存在。")

# 使用自定义的 collate_fn 确保每个批次的大小一致
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=collate_fn)

# 初始化模型
config = SegformerConfig()
config.num_labels = 2  # 假设只有背景和前景两类
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SegformerForSemanticSegmentation(config).to(device)

# 定义损失函数和优化器
optimizer = optim.AdamW(model.parameters(), lr=0.0001)

# 自定义中心加权损失
class WeightedCrossEntropyLoss(nn.Module):
    def __init__(self, weight_center=2.0):
        super(WeightedCrossEntropyLoss, self).__init__()
        self.weight_center = weight_center
        self.ce_loss = nn.CrossEntropyLoss(reduction='none')

    def forward(self, inputs, targets):
        # 确保 inputs 和 targets 的维度一致
        if inputs.shape[2:] != targets.shape:
            targets = targets.unsqueeze(1)
            targets = torch.nn.functional.interpolate(targets.float(), size=inputs.shape[2:], mode='nearest').squeeze(1).long()
        
        # 计算基本交叉熵损失
        loss = self.ce_loss(inputs, targets)

        # 中心区域权重：仅对纵向范围中心加权，横向不变
        _, _, h, w = inputs.shape
        y_center, x_center = h // 2, w // 2
        weight_mask = torch.ones_like(targets, dtype=torch.float32)
        weight_mask[y_center - h // 4:y_center + h // 4, :] = self.weight_center  # 仅纵向范围

        # 应用权重
        weighted_loss = loss * weight_mask.to(inputs.device)
        return weighted_loss.mean()

criterion = WeightedCrossEntropyLoss(weight_center=5.0)

# 训练循环
epochs = 130
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    with tqdm(total=len(dataloader), desc=f"Epoch {epoch+1}/{epochs}") as pbar:
        for images, masks in dataloader:  # 加载图像和掩码
            images, masks = images.to(device), masks.to(device)

            # 前向传播
            outputs = model(images).logits
            # 调整输出大小以匹配掩码大小
            outputs = torch.nn.functional.interpolate(outputs, size=(masks.shape[1], masks.shape[2]), mode='bilinear', align_corners=False)

            # 计算损失
            loss = criterion(outputs, masks)

            # 反向传播和优化
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            pbar.update(1)  # 更新 tqdm 进度条
            pbar.set_postfix({"Loss": f"{loss.item():.4f}"})  # 显示当前损失

    print(f"Epoch [{epoch+1}/{epochs}], Loss: {running_loss/len(dataloader):.4f}")

# 保存模型
save_dir = "D:/2024/paper2/model/Model/zuoshu"
os.makedirs(save_dir, exist_ok=True)

# 保存完整模型
model_save_path = os.path.join(save_dir, "segformer_full_model.pth")
torch.save(model, model_save_path)
print(f"完整模型已保存到 {model_save_path}")

# 保存模型权重
weights_save_path = os.path.join(save_dir, "segformer_weights.pth")
torch.save(model.state_dict(), weights_save_path)
print(f"模型权重已保存到 {weights_save_path}")


# 保存配置文件
config_save_path = os.path.join(save_dir, "config.json")
config.save_pretrained(save_dir)
print(f"配置文件已保存到 {config_save_path}")

# 保存检查点文件
checkpoint_save_path = os.path.join(save_dir, "checkpoint.pth")
torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "config": config.to_dict(),
    "epoch": epochs,
}, checkpoint_save_path)
print(f"检查点文件已保存到 {checkpoint_save_path}")

print("训练完成并保存所有文件！")
# Out:
# 找到 59 个匹配的图像、掩码和 JSON 文件。
# Epoch 1/130: 100%|██████████| 15/15 [03:50<00:00, 15.35s/it, Loss=0.3984]
# Epoch [1/130], Loss: 0.5289
# Epoch 2/130: 100%|██████████| 15/15 [03:02<00:00, 12.19s/it, Loss=0.3124]
# Epoch [2/130], Loss: 0.3592
# Epoch 3/130: 100%|██████████| 15/15 [1:30:24<00:00, 361.62s/it, Loss=0.2836]
# Epoch [3/130], Loss: 0.3089
# Epoch 4/130: 100%|██████████| 15/15 [08:58<00:00, 35.93s/it, Loss=0.2245]
# Epoch [4/130], Loss: 0.2553
# Epoch 5/130: 100%|██████████| 15/15 [02:59<00:00, 11.96s/it, Loss=0.2078]
# Epoch [5/130], Loss: 0.2250
# Epoch 6/130: 100%|██████████| 15/15 [02:28<00:00,  9.88s/it, Loss=0.1761]
# Epoch [6/130], Loss: 0.1982
# Epoch 7/130: 100%|██████████| 15/15 [02:19<00:00,  9.31s/it, Loss=0.1802]
# Epoch [7/130], Loss: 0.1777
# Epoch 8/130: 100%|██████████| 15/15 [02:23<00:00,  9.56s/it, Loss=0.1922]
# Epoch [8/130], Loss: 0.1593
# Epoch 9/130: 100%|██████████| 15/15 [02:22<00:00,  9.52s/it, Loss=0.1249]
# Epoch [9/130], Loss: 0.1432
# Epoch 10/130: 100%|██████████| 15/15 [02:22<00:00,  9.49s/it, Loss=0.1400]
# Epoch [10/130], Loss: 0.1338
# Epoch 11/130: 100%|██████████| 15/15 [02:13<00:00,  8.93s/it, Loss=0.1184]
# Epoch [11/130], Loss: 0.1180
# Epoch 12/130: 100%|██████████| 15/15 [02:24<00:00,  9.61s/it, Loss=0.1387]
# Epoch [12/130], Loss: 0.1199
# Epoch 13/130: 100%|██████████| 15/15 [02:14<00:00,  8.96s/it, Loss=0.0871]
# Epoch [13/130], Loss: 0.1058
# Epoch 14/130: 100%|██████████| 15/15 [02:19<00:00,  9.28s/it, Loss=0.0812]
# Epoch [14/130], Loss: 0.0987
# Epoch 15/130: 100%|██████████| 15/15 [02:12<00:00,  8.82s/it, Loss=0.0750]
# Epoch [15/130], Loss: 0.0930
# Epoch 16/130: 100%|██████████| 15/15 [02:29<00:00,  9.99s/it, Loss=0.1313]
# Epoch [16/130], Loss: 0.0990
# Epoch 17/130: 100%|██████████| 15/15 [02:20<00:00,  9.40s/it, Loss=0.0900]
# Epoch [17/130], Loss: 0.0957
# Epoch 18/130: 100%|██████████| 15/15 [02:23<00:00,  9.57s/it, Loss=0.0977]
# Epoch [18/130], Loss: 0.0857
# Epoch 19/130: 100%|██████████| 15/15 [02:22<00:00,  9.53s/it, Loss=0.0788]
# Epoch [19/130], Loss: 0.0832
# Epoch 20/130: 100%|██████████| 15/15 [02:25<00:00,  9.70s/it, Loss=0.0707]
# Epoch [20/130], Loss: 0.0764
# Epoch 21/130: 100%|██████████| 15/15 [02:21<00:00,  9.41s/it, Loss=0.0714]
# Epoch [21/130], Loss: 0.0774
# Epoch 22/130: 100%|██████████| 15/15 [02:27<00:00,  9.84s/it, Loss=0.0676]
# Epoch [22/130], Loss: 0.0747
# Epoch 23/130: 100%|██████████| 15/15 [02:23<00:00,  9.57s/it, Loss=0.0800]
# Epoch [23/130], Loss: 0.0728
# Epoch 24/130: 100%|██████████| 15/15 [02:31<00:00, 10.09s/it, Loss=0.0729]
# Epoch [24/130], Loss: 0.0721
# Epoch 25/130: 100%|██████████| 15/15 [02:17<00:00,  9.19s/it, Loss=0.0758]
# Epoch [25/130], Loss: 0.0706
# Epoch 26/130: 100%|██████████| 15/15 [02:19<00:00,  9.33s/it, Loss=0.0582]
# Epoch [26/130], Loss: 0.0688
# Epoch 27/130: 100%|██████████| 15/15 [02:17<00:00,  9.15s/it, Loss=0.0663]
# Epoch [27/130], Loss: 0.0680
# Epoch 28/130: 100%|██████████| 15/15 [03:19<00:00, 13.27s/it, Loss=0.0648]
# Epoch [28/130], Loss: 0.0647
# Epoch 29/130: 100%|██████████| 15/15 [03:52<00:00, 15.47s/it, Loss=0.0618]
# Epoch [29/130], Loss: 0.0659
# Epoch 30/130: 100%|██████████| 15/15 [03:50<00:00, 15.36s/it, Loss=0.0681]
# Epoch [30/130], Loss: 0.0638
# Epoch 31/130: 100%|██████████| 15/15 [05:08<00:00, 20.59s/it, Loss=0.0784]
# Epoch [31/130], Loss: 0.0646
# Epoch 32/130: 100%|██████████| 15/15 [04:29<00:00, 18.00s/it, Loss=0.0732]
# Epoch [32/130], Loss: 0.0614
# Epoch 33/130: 100%|██████████| 15/15 [02:56<00:00, 11.78s/it, Loss=0.0587]
# Epoch [33/130], Loss: 0.0606
# Epoch 34/130: 100%|██████████| 15/15 [01:18<00:00,  5.25s/it, Loss=0.0638]
# Epoch [34/130], Loss: 0.0598
# Epoch 35/130: 100%|██████████| 15/15 [01:14<00:00,  4.99s/it, Loss=0.0538]
# Epoch [35/130], Loss: 0.0578
# Epoch 36/130: 100%|██████████| 15/15 [01:19<00:00,  5.29s/it, Loss=0.0598]
# Epoch [36/130], Loss: 0.0570
# Epoch 37/130: 100%|██████████| 15/15 [01:16<00:00,  5.12s/it, Loss=0.0685]
# Epoch [37/130], Loss: 0.0568
# Epoch 38/130: 100%|██████████| 15/15 [01:20<00:00,  5.35s/it, Loss=0.0474]
# Epoch [38/130], Loss: 0.0551
# Epoch 39/130: 100%|██████████| 15/15 [01:15<00:00,  5.01s/it, Loss=0.0601]
# Epoch [39/130], Loss: 0.0546
# Epoch 40/130: 100%|██████████| 15/15 [01:18<00:00,  5.24s/it, Loss=0.0547]
# Epoch [40/130], Loss: 0.0542
# Epoch 41/130: 100%|██████████| 15/15 [01:14<00:00,  4.99s/it, Loss=0.0473]
# Epoch [41/130], Loss: 0.0530
# Epoch 42/130: 100%|██████████| 15/15 [01:18<00:00,  5.25s/it, Loss=0.0538]
# Epoch [42/130], Loss: 0.0517
# Epoch 43/130: 100%|██████████| 15/15 [01:15<00:00,  5.02s/it, Loss=0.0586]
# Epoch [43/130], Loss: 0.0511
# Epoch 44/130: 100%|██████████| 15/15 [01:18<00:00,  5.26s/it, Loss=0.0654]
# Epoch [44/130], Loss: 0.0509
# Epoch 45/130: 100%|██████████| 15/15 [01:14<00:00,  4.99s/it, Loss=0.0595]
# Epoch [45/130], Loss: 0.0492
# Epoch 46/130: 100%|██████████| 15/15 [01:18<00:00,  5.24s/it, Loss=0.0452]
# Epoch 69/130: 100%|██████████| 15/15 [02:05<00:00,  8.36s/it, Loss=0.0241]
# Epoch [69/130], Loss: 0.0238
# Epoch 70/130: 100%|██████████| 15/15 [02:11<00:00,  8.75s/it, Loss=0.0227]
# Epoch [70/130], Loss: 0.0226
# Epoch 71/130: 100%|██████████| 15/15 [02:05<00:00,  8.36s/it, Loss=0.0199]
# Epoch [71/130], Loss: 0.0222
# Epoch 72/130: 100%|██████████| 15/15 [02:11<00:00,  8.80s/it, Loss=0.0201]
# Epoch [72/130], Loss: 0.0213
# Epoch 73/130: 100%|██████████| 15/15 [02:05<00:00,  8.37s/it, Loss=0.0216]
# Epoch [73/130], Loss: 0.0217
# Epoch 74/130: 100%|██████████| 15/15 [02:13<00:00,  8.91s/it, Loss=0.0263]
# Epoch [74/130], Loss: 0.0216
# Epoch 75/130: 100%|██████████| 15/15 [02:10<00:00,  8.70s/it, Loss=0.0211]
# Epoch [75/130], Loss: 0.0222
# Epoch 76/130: 100%|██████████| 15/15 [02:15<00:00,  9.01s/it, Loss=0.0193]
# Epoch [76/130], Loss: 0.0211
# Epoch 77/130: 100%|██████████| 15/15 [02:10<00:00,  8.71s/it, Loss=0.0227]
# Epoch [77/130], Loss: 0.0192
# Epoch 78/130: 100%|██████████| 15/15 [02:16<00:00,  9.13s/it, Loss=0.0184]
# Epoch [78/130], Loss: 0.0182
# Epoch 79/130: 100%|██████████| 15/15 [02:07<00:00,  8.47s/it, Loss=0.0179]
# Epoch [79/130], Loss: 0.0182
# Epoch 80/130: 100%|██████████| 15/15 [02:15<00:00,  9.05s/it, Loss=0.0205]
# Epoch [80/130], Loss: 0.0173
# Epoch 81/130: 100%|██████████| 15/15 [02:10<00:00,  8.71s/it, Loss=0.0161]
# Epoch [81/130], Loss: 0.0170
# Epoch 82/130: 100%|██████████| 15/15 [02:18<00:00,  9.22s/it, Loss=0.0213]
# Epoch [82/130], Loss: 0.0166
# Epoch 83/130: 100%|██████████| 15/15 [03:08<00:00, 12.56s/it, Loss=0.0201]
# Epoch [83/130], Loss: 0.0164
# Epoch 84/130: 100%|██████████| 15/15 [03:32<00:00, 14.18s/it, Loss=0.0176]
# Epoch [84/130], Loss: 0.0159
# Epoch 85/130: 100%|██████████| 15/15 [02:59<00:00, 11.97s/it, Loss=0.0172]
# Epoch [85/130], Loss: 0.0155
# Epoch 86/130: 100%|██████████| 15/15 [03:06<00:00, 12.44s/it, Loss=0.0149]
# Epoch [86/130], Loss: 0.0152
# Epoch 87/130: 100%|██████████| 15/15 [03:17<00:00, 13.16s/it, Loss=0.0162]
# Epoch [87/130], Loss: 0.0148
# Epoch 88/130: 100%|██████████| 15/15 [03:06<00:00, 12.41s/it, Loss=0.0147]
# Epoch [88/130], Loss: 0.0144
# Epoch 89/130: 100%|██████████| 15/15 [03:36<00:00, 14.45s/it, Loss=0.0141]
# Epoch [89/130], Loss: 0.0146
# Epoch 90/130: 100%|██████████| 15/15 [03:52<00:00, 15.50s/it, Loss=0.0143]
# Epoch [90/130], Loss: 0.0146
# Epoch 91/130: 100%|██████████| 15/15 [03:38<00:00, 14.58s/it, Loss=0.0164]
# Epoch [91/130], Loss: 0.0145
# Epoch 92/130: 100%|██████████| 15/15 [03:49<00:00, 15.30s/it, Loss=0.0132]
# Epoch [92/130], Loss: 0.0137
# Epoch 93/130: 100%|██████████| 15/15 [03:47<00:00, 15.14s/it, Loss=0.0118]
# Epoch [93/130], Loss: 0.0135
# Epoch 94/130: 100%|██████████| 15/15 [03:53<00:00, 15.58s/it, Loss=0.0122]
# Epoch [94/130], Loss: 0.0136
# Epoch 95/130: 100%|██████████| 15/15 [03:36<00:00, 14.46s/it, Loss=0.0120]
# Epoch [95/130], Loss: 0.0130
# Epoch 96/130: 100%|██████████| 15/15 [03:41<00:00, 14.74s/it, Loss=0.0140]
# Epoch [96/130], Loss: 0.0129
# Epoch 97/130: 100%|██████████| 15/15 [02:57<00:00, 11.81s/it, Loss=0.0112]
# Epoch [97/130], Loss: 0.0130
# Epoch 98/130: 100%|██████████| 15/15 [03:19<00:00, 13.30s/it, Loss=0.0145]
# Epoch [98/130], Loss: 0.0124
# Epoch 99/130: 100%|██████████| 15/15 [02:58<00:00, 11.93s/it, Loss=0.0112]
# Epoch [99/130], Loss: 0.0122
# Epoch 100/130: 100%|██████████| 15/15 [03:12<00:00, 12.86s/it, Loss=0.0104]
# Epoch [100/130], Loss: 0.0118
# Epoch 101/130: 100%|██████████| 15/15 [02:56<00:00, 11.75s/it, Loss=0.0113]
# Epoch [101/130], Loss: 0.0116
# Epoch 102/130: 100%|██████████| 15/15 [03:06<00:00, 12.45s/it, Loss=0.0116]
# Epoch [102/130], Loss: 0.0114
# Epoch 103/130: 100%|██████████| 15/15 [02:50<00:00, 11.37s/it, Loss=0.0106]
# Epoch [103/130], Loss: 0.0113
# Epoch 104/130: 100%|██████████| 15/15 [02:57<00:00, 11.84s/it, Loss=0.0097]
# Epoch [104/130], Loss: 0.0112
# Epoch 105/130: 100%|██████████| 15/15 [02:56<00:00, 11.76s/it, Loss=0.0126]
# Epoch [105/130], Loss: 0.0113
# Epoch 106/130: 100%|██████████| 15/15 [03:24<00:00, 13.61s/it, Loss=0.0114]
# Epoch [106/130], Loss: 0.0107
# Epoch 107/130: 100%|██████████| 15/15 [03:01<00:00, 12.12s/it, Loss=0.0127]
# Epoch [107/130], Loss: 0.0104
# Epoch 108/130: 100%|██████████| 15/15 [03:06<00:00, 12.40s/it, Loss=0.0102]
# Epoch [108/130], Loss: 0.0102
# Epoch 109/130: 100%|██████████| 15/15 [03:15<00:00, 13.04s/it, Loss=0.0095]
# Epoch [109/130], Loss: 0.0105
# Epoch 110/130: 100%|██████████| 15/15 [03:03<00:00, 12.20s/it, Loss=0.0107]
# Epoch [110/130], Loss: 0.0105
# Epoch 111/130: 100%|██████████| 15/15 [03:14<00:00, 12.96s/it, Loss=0.0119]
# Epoch [111/130], Loss: 0.0106
# Epoch 112/130: 100%|██████████| 15/15 [03:09<00:00, 12.66s/it, Loss=0.0090]
# Epoch [112/130], Loss: 0.0106
# Epoch 113/130: 100%|██████████| 15/15 [02:51<00:00, 11.45s/it, Loss=0.0104]
# Epoch [113/130], Loss: 0.0106
# Epoch 114/130: 100%|██████████| 15/15 [03:23<00:00, 13.59s/it, Loss=0.0087]
# Epoch [114/130], Loss: 0.0102
# Epoch 115/130: 100%|██████████| 15/15 [03:27<00:00, 13.86s/it, Loss=0.0066]
# Epoch [115/130], Loss: 0.0100
# Epoch 116/130: 100%|██████████| 15/15 [02:40<00:00, 10.73s/it, Loss=0.0092]
# Epoch [116/130], Loss: 0.0094
# Epoch 117/130: 100%|██████████| 15/15 [02:36<00:00, 10.45s/it, Loss=0.0084]
# Epoch [117/130], Loss: 0.0098
# Epoch 118/130: 100%|██████████| 15/15 [02:45<00:00, 11.01s/it, Loss=0.0096]
# Epoch [118/130], Loss: 0.0094
# Epoch 119/130: 100%|██████████| 15/15 [02:36<00:00, 10.45s/it, Loss=0.0077]
# Epoch [119/130], Loss: 0.0090
# Epoch 120/130: 100%|██████████| 15/15 [02:45<00:00, 11.07s/it, Loss=0.0071]
# Epoch [120/130], Loss: 0.0090
# Epoch 121/130: 100%|██████████| 15/15 [02:40<00:00, 10.71s/it, Loss=0.0083]
# Epoch [121/130], Loss: 0.0092
# Epoch 122/130: 100%|██████████| 15/15 [02:57<00:00, 11.81s/it, Loss=0.0089]
# Epoch [122/130], Loss: 0.0087
# Epoch 123/130: 100%|██████████| 15/15 [02:33<00:00, 10.25s/it, Loss=0.0092]
# Epoch [123/130], Loss: 0.0089
# Epoch 124/130: 100%|██████████| 15/15 [02:44<00:00, 10.94s/it, Loss=0.0085]
# Epoch [124/130], Loss: 0.0087
# Epoch 125/130: 100%|██████████| 15/15 [02:38<00:00, 10.58s/it, Loss=0.0062]
# Epoch [125/130], Loss: 0.0084
# Epoch 126/130: 100%|██████████| 15/15 [02:46<00:00, 11.13s/it, Loss=0.0106]
# Epoch [126/130], Loss: 0.0084
# Epoch 127/130: 100%|██████████| 15/15 [02:42<00:00, 10.83s/it, Loss=0.0074]
# Epoch [127/130], Loss: 0.0085
# Epoch 128/130: 100%|██████████| 15/15 [02:51<00:00, 11.42s/it, Loss=0.0101]
# Epoch [128/130], Loss: 0.0082
# Epoch 129/130: 100%|██████████| 15/15 [03:04<00:00, 12.29s/it, Loss=0.0099]
# Epoch [129/130], Loss: 0.0079
# Epoch 130/130: 100%|██████████| 15/15 [03:13<00:00, 12.90s/it, Loss=0.0069]
# Epoch [130/130], Loss: 0.0080
# 完整模型已保存到 D:/2024/paper2/model/Model/zuoshu\segformer_full_model.pth
# 模型权重已保存到 D:/2024/paper2/model/Model/zuoshu\segformer_weights.pth
# 配置文件已保存到 D:/2024/paper2/model/Model/zuoshu\config.json
# 检查点文件已保存到 D:/2024/paper2/model/Model/zuoshu\checkpoint.pth
# 训练完成并保存所有文件！

# %%
import torch
import os
from PIL import Image
from torchvision import transforms
from transformers import SegformerForSemanticSegmentation
import numpy as np

# 设置路径
image_dir = "D:/2024/paper2/model/test/zuoshu1"  # 验证图像文件夹
output_mask_dir = "D:/2024/paper2/model/test_masks/zuoshu"  # 输出掩码文件夹
model_dir = "D:/2024/paper2/model/Model/zuoshu"  # 模型文件夹

# 加载完整模型
model_path = os.path.join(model_dir, "segformer_full_model.pth")
model = torch.load(model_path)  # 直接加载完整模型
model.eval()  # 设置为评估模式

# 数据预处理（与训练时相同）
transform = transforms.Compose([
    transforms.ToTensor(),  # 转换为 Tensor
])

# 创建输出文件夹（如果不存在）
os.makedirs(output_mask_dir, exist_ok=True)

# 验证集图像文件名
image_filenames = [f for f in os.listdir(image_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# 推理过程
with torch.no_grad():  # 在推理时不需要计算梯度
    for filename in image_filenames:
        img_path = os.path.join(image_dir, filename)
        
        # 读取图像
        image = Image.open(img_path).convert("RGB")
        
        # 保存原始尺寸
        original_size = image.size
        
        # 统一尺寸（假设训练时输入尺寸是1024x1024）
        target_size = (1024, 1024)  # 如果你的验证图像不是1024x1024，可能需要调整此处
        image_resized = image.resize(target_size)

        # 进行预处理
        image_tensor = transform(image_resized).unsqueeze(0).to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))

        # 模型推理
        outputs = model(image_tensor).logits

        # 获取预测的类别标签（背景=0, 树干=1）
        predicted_mask = torch.argmax(outputs, dim=1).squeeze(0).cpu().numpy().astype(np.uint8)

        # 将输出的掩码转换为 0 和 255（黑色背景，白色树干）
        predicted_mask = predicted_mask * 255  # 0 -> 0, 1 -> 255

        # 将预测掩码调整回原始输入图像的大小
        predicted_mask_resized = Image.fromarray(predicted_mask)
        predicted_mask_resized = predicted_mask_resized.resize(original_size, Image.NEAREST)

        # 保存掩码图像
        mask_filename = os.path.join(output_mask_dir, filename.replace(".jpg", ".png").replace(".jpeg", ".png").replace(".png", ".png"))
        predicted_mask_resized.save(mask_filename)

        print(f"Saved mask for {filename} to {mask_filename}")

print("推理完成，所有掩码已保存！")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_24944\3575736288.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path)  # 直接加载完整模型
# Saved mask for 16015010094000_04.jpg to D:/2024/paper2/model/test_masks/zuoshu\16015010094000_04.png
# Saved mask for 16015010094000_05.jpg to D:/2024/paper2/model/test_masks/zuoshu\16015010094000_05.png
# Saved mask for 16015010100000_01.jpg to D:/2024/paper2/model/test_masks/zuoshu\16015010100000_01.png
# Saved mask for 16015010100000_02.jpg to D:/2024/paper2/model/test_masks/zuoshu\16015010100000_02.png
# Saved mask for 16015010100000_05.jpg to D:/2024/paper2/model/test_masks/zuoshu\16015010100000_05.png
# Saved mask for 16020010036000_01.jpg to D:/2024/paper2/model/test_masks/zuoshu\16020010036000_01.png
# Saved mask for 16020010036000_02.jpg to D:/2024/paper2/model/test_masks/zuoshu\16020010036000_02.png
# Saved mask for 16020010036000_03.jpg to D:/2024/paper2/model/test_masks/zuoshu\16020010036000_03.png
# Saved mask for 16020010036000_04.jpg to D:/2024/paper2/model/test_masks/zuoshu\16020010036000_04.png
# Saved mask for 16020010053000_01.jpg to D:/2024/paper2/model/test_masks/zuoshu\16020010053000_01.png
# Saved mask for 16020010053000_02.jpg to D:/2024/paper2/model/test_masks/zuoshu\16020010053000_02.png
# Saved mask for 29150180042000_02.jpg to D:/2024/paper2/model/test_masks/zuoshu\29150180042000_02.png
# Saved mask for 29150180042000_03.jpg to D:/2024/paper2/model/test_masks/zuoshu\29150180042000_03.png
# Saved mask for 29150180042000_04.jpg to D:/2024/paper2/model/test_masks/zuoshu\29150180042000_04.png
# Saved mask for 29150180042000_05.jpg to D:/2024/paper2/model/test_masks/zuoshu\29150180042000_05.png
# Saved mask for 29150260015000_01.jpg to D:/2024/paper2/model/test_masks/zuoshu\29150260015000_01.png
# Saved mask for 29150260015000_02.jpg to D:/2024/paper2/model/test_masks/zuoshu\29150260015000_02.png
# Saved mask for 29150260015000_03.jpg to D:/2024/paper2/model/test_masks/zuoshu\29150260015000_03.png
# Saved mask for 29150260015000_04.jpg to D:/2024/paper2/model/test_masks/zuoshu\29150260015000_04.png
# Saved mask for 29150260015000_05.jpg to D:/2024/paper2/model/test_masks/zuoshu\29150260015000_05.png
# Saved mask for 29150260021001_01.jpg to D:/2024/paper2/model/test_masks/zuoshu\29150260021001_01.png
# Saved mask for 29150260021001_02.jpg to D:/2024/paper2/model/test_masks/zuoshu\29150260021001_02.png
# Saved mask for 29150260021001_03.jpg to D:/2024/paper2/model/test_masks/zuoshu\29150260021001_03.png
# Saved mask for 29150260021001_04.jpg to D:/2024/paper2/model/test_masks/zuoshu\29150260021001_04.png
# Saved mask for 29150260021001_05.jpg to D:/2024/paper2/model/test_masks/zuoshu\29150260021001_05.png
# Saved mask for C013_04.jpg to D:/2024/paper2/model/test_masks/zuoshu\C013_04.png
# Saved mask for C014_01.jpg to D:/2024/paper2/model/test_masks/zuoshu\C014_01.png
# Saved mask for C014_03.jpg to D:/2024/paper2/model/test_masks/zuoshu\C014_03.png
# Saved mask for C014_05.jpg to D:/2024/paper2/model/test_masks/zuoshu\C014_05.png
# Saved mask for C016_01.jpg to D:/2024/paper2/model/test_masks/zuoshu\C016_01.png
# Saved mask for C016_02.jpg to D:/2024/paper2/model/test_masks/zuoshu\C016_02.png
# Saved mask for C016_03.jpg to D:/2024/paper2/model/test_masks/zuoshu\C016_03.png
# Saved mask for C016_05.jpg to D:/2024/paper2/model/test_masks/zuoshu\C016_05.png
# Saved mask for D008_01.jpg to D:/2024/paper2/model/test_masks/zuoshu\D008_01.png
# Saved mask for D008_02.jpg to D:/2024/paper2/model/test_masks/zuoshu\D008_02.png
# Saved mask for D008_03.jpg to D:/2024/paper2/model/test_masks/zuoshu\D008_03.png
# Saved mask for D008_04.jpg to D:/2024/paper2/model/test_masks/zuoshu\D008_04.png
# Saved mask for D008_05.jpg to D:/2024/paper2/model/test_masks/zuoshu\D008_05.png
# 推理完成，所有掩码已保存！

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# 设置路径
image_dir = "D:/2024/paper2/model/test/zuoshu"  # 验证图像文件夹
mask_dir = "D:/2024/paper2/model/test_masks/zuoshu"  # 单通道掩码文件夹
output_dir = "D:/2024/paper2/model/test_comparison/zuoshu"  # 输出图片文件夹

# 创建输出文件夹（如果不存在）
os.makedirs(output_dir, exist_ok=True)

# 获取图像文件名
image_filenames = [f for f in os.listdir(image_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# 处理每个图像
for filename in image_filenames:
    # 构造图像路径和掩码路径
    img_path = os.path.join(image_dir, filename)
    mask_path = os.path.join(mask_dir, filename.replace(".jpg", ".png").replace(".jpeg", ".png").replace(".png", ".png"))

    # 读取验证图像和掩码图像
    image = Image.open(img_path).convert("RGB")  # 读取并转换为 RGB 图像
    mask = Image.open(mask_path).convert("L")  # 读取掩码并转换为灰度图像（L 模式）

    # 将掩码图像转换为 numpy 数组（0 表示背景，255 表示树干）
    mask_array = np.array(mask)

    # 将掩码值转换为 0 或 1（0 -> 背景，1 -> 树干）
    mask_binary = (mask_array > 127).astype(int)  # 将大于127的像素值转为 1，小于等于127的为 0

    # 将原始图像和掩码图像叠加
    image_array = np.array(image)

    # 使用掩码区域将原始图像覆盖成不同的颜色（比如将树干区域用红色标出）
    # 红色区域表示模型预测的树干区域
    image_with_mask = image_array.copy()
    image_with_mask[mask_binary == 1] = [255, 0, 0]  # 将树干区域标记为红色 [255, 0, 0]

    # 将原始图像与掩码图像并排显示
    # 设置高分辨率图像
    fig, axes = plt.subplots(1, 2, figsize=(16, 8), dpi=200)  # 设置更大的图像大小和更高的 DPI

    # 显示原始图像
    axes[0].imshow(image)
    axes[0].set_title("Original Image")
    axes[0].axis("off")

    # 显示叠加图像
    axes[1].imshow(image_with_mask)
    axes[1].set_title("Image with Predicted Mask")
    axes[1].axis("off")

    # 保存结果图像
    comparison_filename = os.path.join(output_dir, filename.replace(".jpg", "_comparison.png").replace(".jpeg", "_comparison.png").replace(".png", "_comparison.png"))
    plt.savefig(comparison_filename, dpi=200)  # 保存为高分辨率图像
    plt.close()

    print(f"Saved comparison image for {filename} to {comparison_filename}")

print("所有比较图像已保存！")
# Out:
# Saved comparison image for 09080040006000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080040006000_04_comparison_comparison.png
# Saved comparison image for 09080040006000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080040006000_05_comparison_comparison.png
# Saved comparison image for 09080080006000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080080006000_01_comparison_comparison.png
# Saved comparison image for 09080080006000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080080006000_02_comparison_comparison.png
# Saved comparison image for 09080080006000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080080006000_03_comparison_comparison.png
# Saved comparison image for 09080080006000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080080006000_05_comparison_comparison.png
# Saved comparison image for 09080080019000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080080019000_03_comparison_comparison.png
# Saved comparison image for 09080080019000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080080019000_04_comparison_comparison.png
# Saved comparison image for 09080080019000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080080019000_05_comparison_comparison.png
# Saved comparison image for 09080080020000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080080020000_03_comparison_comparison.png
# Saved comparison image for 09080080020000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080080020000_04_comparison_comparison.png
# Saved comparison image for 09080090011000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080090011000_03_comparison_comparison.png
# Saved comparison image for 09080090011000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080090011000_05_comparison_comparison.png
# Saved comparison image for 09080110008000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080110008000_02_comparison_comparison.png
# Saved comparison image for 09080110008000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080110008000_03_comparison_comparison.png
# Saved comparison image for 09080110008000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080110008000_04_comparison_comparison.png
# Saved comparison image for 09080110008000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080110008000_05_comparison_comparison.png
# Saved comparison image for 09080110011000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080110011000_01_comparison_comparison.png
# Saved comparison image for 09080110011000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080110011000_03_comparison_comparison.png
# Saved comparison image for 09080110015000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080110015000_01_comparison_comparison.png
# Saved comparison image for 09080110015000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080110015000_02_comparison_comparison.png
# Saved comparison image for 09080110015000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080110015000_03_comparison_comparison.png
# Saved comparison image for 09080120003000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080120003000_01_comparison_comparison.png
# Saved comparison image for 09080120003000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080120003000_02_comparison_comparison.png
# Saved comparison image for 09080120003000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080120003000_03_comparison_comparison.png
# Saved comparison image for 09080120003000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080120003000_04_comparison_comparison.png
# Saved comparison image for 09080120012000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080120012000_01_comparison_comparison.png
# Saved comparison image for 09080120012000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080120012000_04_comparison_comparison.png
# Saved comparison image for 09080120012000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080120012000_05_comparison_comparison.png
# Saved comparison image for 09080120031000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080120031000_03_comparison_comparison.png
# Saved comparison image for 09080120031000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080120031000_04_comparison_comparison.png
# Saved comparison image for 09080120033000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080120033000_01_comparison_comparison.png
# Saved comparison image for 09080120033000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080120033000_02_comparison_comparison.png
# Saved comparison image for 09080120033000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080120033000_04_comparison_comparison.png
# Saved comparison image for 09080120033000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\09080120033000_05_comparison_comparison.png
# Saved comparison image for 16010090095000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010090095000_01_comparison_comparison.png
# Saved comparison image for 16010090095000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010090095000_02_comparison_comparison.png
# Saved comparison image for 16010090095000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010090095000_03_comparison_comparison.png
# Saved comparison image for 16010090095000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010090095000_04_comparison_comparison.png
# Saved comparison image for 16010090095000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010090095000_05_comparison_comparison.png
# Saved comparison image for 16010100095000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010100095000_01_comparison_comparison.png
# Saved comparison image for 16010100095000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010100095000_02_comparison_comparison.png
# Saved comparison image for 16010100095000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010100095000_03_comparison_comparison.png
# Saved comparison image for 16010100095000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010100095000_04_comparison_comparison.png
# Saved comparison image for 16010100095000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010100095000_05_comparison_comparison.png
# Saved comparison image for 16010100107000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010100107000_01_comparison_comparison.png
# Saved comparison image for 16010100107000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010100107000_05_comparison_comparison.png
# Saved comparison image for 16010100146000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010100146000_01_comparison_comparison.png
# Saved comparison image for 16010100146000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010100146000_03_comparison_comparison.png
# Saved comparison image for 16010100146000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010100146000_04_comparison_comparison.png
# Saved comparison image for 16010100254000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010100254000_01_comparison_comparison.png
# Saved comparison image for 16010100254000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010100254000_02_comparison_comparison.png
# Saved comparison image for 16010100254000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010100254000_03_comparison_comparison.png
# Saved comparison image for 16010100254000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010100254000_04_comparison_comparison.png
# Saved comparison image for 16010100254000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16010100254000_05_comparison_comparison.png
# Saved comparison image for 16011020187000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16011020187000_01_comparison_comparison.png
# Saved comparison image for 16011020187001_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16011020187001_03_comparison_comparison.png
# Saved comparison image for 16011020187001_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16011020187001_04_comparison_comparison.png
# Saved comparison image for 16011020187001_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16011020187001_05_comparison_comparison.png
# Saved comparison image for 16015010094000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16015010094000_04_comparison_comparison.png
# Saved comparison image for 16015010094000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16015010094000_05_comparison_comparison.png
# Saved comparison image for 16015010100000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16015010100000_01_comparison_comparison.png
# Saved comparison image for 16015010100000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16015010100000_02_comparison_comparison.png
# Saved comparison image for 16015010100000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16015010100000_05_comparison_comparison.png
# Saved comparison image for 16020010036000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010036000_01_comparison_comparison.png
# Saved comparison image for 16020010036000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010036000_02_comparison_comparison.png
# Saved comparison image for 16020010036000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010036000_03_comparison_comparison.png
# Saved comparison image for 16020010036000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010036000_04_comparison_comparison.png
# Saved comparison image for 16020010053000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010053000_01_comparison_comparison.png
# Saved comparison image for 16020010053000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010053000_02_comparison_comparison.png
# Saved comparison image for 16020010053000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010053000_03_comparison_comparison.png
# Saved comparison image for 16020010053000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010053000_04_comparison_comparison.png
# Saved comparison image for 16020010053000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010053000_05_comparison_comparison.png
# Saved comparison image for 16020010068000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010068000_01_comparison_comparison.png
# Saved comparison image for 16020010068000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010068000_02_comparison_comparison.png
# Saved comparison image for 16020010068000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010068000_03_comparison_comparison.png
# Saved comparison image for 16020010068000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010068000_04_comparison_comparison.png
# Saved comparison image for 16020010068000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010068000_05_comparison_comparison.png
# Saved comparison image for 16020010068002_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010068002_01_comparison_comparison.png
# Saved comparison image for 16020010068002_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010068002_02_comparison_comparison.png
# Saved comparison image for 16020010068002_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010068002_03_comparison_comparison.png
# Saved comparison image for 16020010068002_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010068002_04_comparison_comparison.png
# Saved comparison image for 16020010068002_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010068002_05_comparison_comparison.png
# Saved comparison image for 16020010079000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010079000_01_comparison_comparison.png
# Saved comparison image for 16020010079000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010079000_02_comparison_comparison.png
# Saved comparison image for 16020010079000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010079000_03_comparison_comparison.png
# Saved comparison image for 16020010079000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010079000_04_comparison_comparison.png
# Saved comparison image for 16020010079000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010079000_05_comparison_comparison.png
# Saved comparison image for 16020010135000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010135000_05_comparison_comparison.png
# Saved comparison image for 16020010198000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010198000_01_comparison_comparison.png
# Saved comparison image for 16020010198000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010198000_02_comparison_comparison.png
# Saved comparison image for 16020010198000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010198000_03_comparison_comparison.png
# Saved comparison image for 16020010198000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010198000_04_comparison_comparison.png
# Saved comparison image for 16020010198000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020010198000_05_comparison_comparison.png
# Saved comparison image for 16020050037000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050037000_02_comparison_comparison.png
# Saved comparison image for 16020050037000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050037000_03_comparison_comparison.png
# Saved comparison image for 16020050037000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050037000_04_comparison_comparison.png
# Saved comparison image for 16020050037000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050037000_05_comparison_comparison.png
# Saved comparison image for 16020050093000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050093000_03_comparison_comparison.png
# Saved comparison image for 16020050093000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050093000_04_comparison_comparison.png
# Saved comparison image for 16020050093000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050093000_05_comparison_comparison.png
# Saved comparison image for 16020050111000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050111000_02_comparison_comparison.png
# Saved comparison image for 16020050111000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050111000_03_comparison_comparison.png
# Saved comparison image for 16020050111000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050111000_04_comparison_comparison.png
# Saved comparison image for 16020050111000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050111000_05_comparison_comparison.png
# Saved comparison image for 16020050125000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050125000_01_comparison_comparison.png
# Saved comparison image for 16020050125000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050125000_02_comparison_comparison.png
# Saved comparison image for 16020050125000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050125000_04_comparison_comparison.png
# Saved comparison image for 16020050125000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050125000_05_comparison_comparison.png
# Saved comparison image for 16020050133000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050133000_01_comparison_comparison.png
# Saved comparison image for 16020050133000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050133000_02_comparison_comparison.png
# Saved comparison image for 16020050133000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050133000_03_comparison_comparison.png
# Saved comparison image for 16020050133000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050133000_05_comparison_comparison.png
# Saved comparison image for 16020050139000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050139000_01_comparison_comparison.png
# Saved comparison image for 16020050139000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050139000_02_comparison_comparison.png
# Saved comparison image for 16020050139000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050139000_03_comparison_comparison.png
# Saved comparison image for 16020050139000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050139000_04_comparison_comparison.png
# Saved comparison image for 16020050139000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020050139000_05_comparison_comparison.png
# Saved comparison image for 16020090241000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020090241000_01_comparison_comparison.png
# Saved comparison image for 16020090241000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020090241000_03_comparison_comparison.png
# Saved comparison image for 16020090286000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020090286000_03_comparison_comparison.png
# Saved comparison image for 16020090286000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16020090286000_05_comparison_comparison.png
# Saved comparison image for 16030010143000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010143000_01_comparison_comparison.png
# Saved comparison image for 16030010143000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010143000_02_comparison_comparison.png
# Saved comparison image for 16030010143000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010143000_03_comparison_comparison.png
# Saved comparison image for 16030010143000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010143000_04_comparison_comparison.png
# Saved comparison image for 16030010143000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010143000_05_comparison_comparison.png
# Saved comparison image for 16030010190002_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010190002_03_comparison_comparison.png
# Saved comparison image for 16030010190002_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010190002_04_comparison_comparison.png
# Saved comparison image for 16030010190002_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010190002_05_comparison_comparison.png
# Saved comparison image for 16030010355000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010355000_01_comparison_comparison.png
# Saved comparison image for 16030010355000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010355000_02_comparison_comparison.png
# Saved comparison image for 16030010355000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010355000_03_comparison_comparison.png
# Saved comparison image for 16030010355000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010355000_04_comparison_comparison.png
# Saved comparison image for 16030010518015_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010518015_01_comparison_comparison.png
# Saved comparison image for 16030010518015_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010518015_02_comparison_comparison.png
# Saved comparison image for 16030010518015_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010518015_03_comparison_comparison.png
# Saved comparison image for 16030010518015_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010518015_04_comparison_comparison.png
# Saved comparison image for 16030010571000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010571000_01_comparison_comparison.png
# Saved comparison image for 16030010571000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010571000_02_comparison_comparison.png
# Saved comparison image for 16030010571000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010571000_03_comparison_comparison.png
# Saved comparison image for 16030010571000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010571000_04_comparison_comparison.png
# Saved comparison image for 16030010571000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010571000_05_comparison_comparison.png
# Saved comparison image for 16030010573000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010573000_01_comparison_comparison.png
# Saved comparison image for 16030010573000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010573000_02_comparison_comparison.png
# Saved comparison image for 16030010573000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010573000_03_comparison_comparison.png
# Saved comparison image for 16030010573000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16030010573000_04_comparison_comparison.png
# Saved comparison image for 16040120044001_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040120044001_01_comparison_comparison.png
# Saved comparison image for 16040120044001_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040120044001_03_comparison_comparison.png
# Saved comparison image for 16040120044001_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040120044001_04_comparison_comparison.png
# Saved comparison image for 16040120044001_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040120044001_05_comparison_comparison.png
# Saved comparison image for 16040120065000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040120065000_01_comparison_comparison.png
# Saved comparison image for 16040120065000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040120065000_04_comparison_comparison.png
# Saved comparison image for 16040120065000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040120065000_05_comparison_comparison.png
# Saved comparison image for 16040120080000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040120080000_01_comparison_comparison.png
# Saved comparison image for 16040120080000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040120080000_02_comparison_comparison.png
# Saved comparison image for 16040120080000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040120080000_03_comparison_comparison.png
# Saved comparison image for 16040120080000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040120080000_04_comparison_comparison.png
# Saved comparison image for 16040120080000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040120080000_05_comparison_comparison.png
# Saved comparison image for 16040150180000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040150180000_01_comparison_comparison.png
# Saved comparison image for 16040150180000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040150180000_02_comparison_comparison.png
# Saved comparison image for 16040150180000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040150180000_03_comparison_comparison.png
# Saved comparison image for 16040150180000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040150180000_04_comparison_comparison.png
# Saved comparison image for 16040150180000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040150180000_05_comparison_comparison.png
# Saved comparison image for 16040230114000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040230114000_01_comparison_comparison.png
# Saved comparison image for 16040230114000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16040230114000_02_comparison_comparison.png
# Saved comparison image for 16050120014000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16050120014000_01_comparison_comparison.png
# Saved comparison image for 16050120014000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16050120014000_04_comparison_comparison.png
# Saved comparison image for 16050120014000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16050120014000_05_comparison_comparison.png
# Saved comparison image for 16050120015000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16050120015000_05_comparison_comparison.png
# Saved comparison image for 16080150024000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16080150024000_01_comparison_comparison.png
# Saved comparison image for 16080150024000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16080150024000_02_comparison_comparison.png
# Saved comparison image for 16080150024000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16080150024000_03_comparison_comparison.png
# Saved comparison image for 16080150024000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16080150024000_04_comparison_comparison.png
# Saved comparison image for 16080150024000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16080150024000_05_comparison_comparison.png
# Saved comparison image for 16090090004003_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16090090004003_04_comparison_comparison.png
# Saved comparison image for 16110040173000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16110040173000_01_comparison_comparison.png
# Saved comparison image for 16110040173000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16110040173000_03_comparison_comparison.png
# Saved comparison image for 16110040173000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16110040173000_04_comparison_comparison.png
# Saved comparison image for 16110040173000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16110040173000_05_comparison_comparison.png
# Saved comparison image for 16110040210002_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16110040210002_01_comparison_comparison.png
# Saved comparison image for 16110040224000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16110040224000_01_comparison_comparison.png
# Saved comparison image for 16110040224000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16110040224000_02_comparison_comparison.png
# Saved comparison image for 16110040224000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\16110040224000_03_comparison_comparison.png
# Saved comparison image for 28030030057000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\28030030057000_01_comparison_comparison.png
# Saved comparison image for 28030030057000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\28030030057000_02_comparison_comparison.png
# Saved comparison image for 28030030057000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\28030030057000_03_comparison_comparison.png
# Saved comparison image for 28030030057000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\28030030057000_04_comparison_comparison.png
# Saved comparison image for 28030030057000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\28030030057000_05_comparison_comparison.png
# Saved comparison image for 28030030122000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\28030030122000_02_comparison_comparison.png
# Saved comparison image for 28030030122000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\28030030122000_03_comparison_comparison.png
# Saved comparison image for 28030030122000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\28030030122000_04_comparison_comparison.png
# Saved comparison image for 28030030122000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\28030030122000_05_comparison_comparison.png
# Saved comparison image for 28060030056000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\28060030056000_01_comparison_comparison.png
# Saved comparison image for 28060030056000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\28060030056000_02_comparison_comparison.png
# Saved comparison image for 28070140045000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\28070140045000_02_comparison_comparison.png
# Saved comparison image for 28070180024000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\28070180024000_03_comparison_comparison.png
# Saved comparison image for 29020110053000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29020110053000_02_comparison_comparison.png
# Saved comparison image for 29020110053000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29020110053000_04_comparison_comparison.png
# Saved comparison image for 29020110053000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29020110053000_05_comparison_comparison.png
# Saved comparison image for 29030080011000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29030080011000_03_comparison_comparison.png
# Saved comparison image for 29030080011000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29030080011000_04_comparison_comparison.png
# Saved comparison image for 29030080011000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29030080011000_05_comparison_comparison.png
# Saved comparison image for 29030080068000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29030080068000_01_comparison_comparison.png
# Saved comparison image for 29030080068000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29030080068000_04_comparison_comparison.png
# Saved comparison image for 29030080068000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29030080068000_05_comparison_comparison.png
# Saved comparison image for 29040010022000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29040010022000_01_comparison_comparison.png
# Saved comparison image for 29040010022000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29040010022000_02_comparison_comparison.png
# Saved comparison image for 29040010022000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29040010022000_03_comparison_comparison.png
# Saved comparison image for 29040010022000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29040010022000_04_comparison_comparison.png
# Saved comparison image for 29040010022000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29040010022000_05_comparison_comparison.png
# Saved comparison image for 29040010085000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29040010085000_03_comparison_comparison.png
# Saved comparison image for 29040010085000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29040010085000_04_comparison_comparison.png
# Saved comparison image for 29040010092000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29040010092000_02_comparison_comparison.png
# Saved comparison image for 29040010092000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29040010092000_03_comparison_comparison.png
# Saved comparison image for 29080290030000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29080290030000_02_comparison_comparison.png
# Saved comparison image for 29080290030000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29080290030000_03_comparison_comparison.png
# Saved comparison image for 29080290030000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29080290030000_04_comparison_comparison.png
# Saved comparison image for 29080290047000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29080290047000_01_comparison_comparison.png
# Saved comparison image for 29080290047000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29080290047000_03_comparison_comparison.png
# Saved comparison image for 29080290047000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29080290047000_04_comparison_comparison.png
# Saved comparison image for 29080290047000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29080290047000_05_comparison_comparison.png
# Saved comparison image for 29090010001001_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29090010001001_02_comparison_comparison.png
# Saved comparison image for 29090010001001_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29090010001001_03_comparison_comparison.png
# Saved comparison image for 29090010001001_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29090010001001_04_comparison_comparison.png
# Saved comparison image for 29090010001001_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29090010001001_05_comparison_comparison.png
# Saved comparison image for 29090140004000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29090140004000_01_comparison_comparison.png
# Saved comparison image for 29090140004000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29090140004000_02_comparison_comparison.png
# Saved comparison image for 29090140004000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29090140004000_03_comparison_comparison.png
# Saved comparison image for 29090140007000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29090140007000_01_comparison_comparison.png
# Saved comparison image for 29090140007000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29090140007000_02_comparison_comparison.png
# Saved comparison image for 29090140007000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29090140007000_03_comparison_comparison.png
# Saved comparison image for 29090140030000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29090140030000_01_comparison_comparison.png
# Saved comparison image for 29090140030000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29090140030000_03_comparison_comparison.png
# Saved comparison image for 29090140030000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29090140030000_04_comparison_comparison.png
# Saved comparison image for 29100020035000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29100020035000_03_comparison_comparison.png
# Saved comparison image for 29100020035000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29100020035000_05_comparison_comparison.png
# Saved comparison image for 29100020042000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29100020042000_01_comparison_comparison.png
# Saved comparison image for 29100020042000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29100020042000_02_comparison_comparison.png
# Saved comparison image for 29100020105000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29100020105000_01_comparison_comparison.png
# Saved comparison image for 29100020105000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29100020105000_02_comparison_comparison.png
# Saved comparison image for 29100020105000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29100020105000_03_comparison_comparison.png
# Saved comparison image for 29100020105000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29100020105000_04_comparison_comparison.png
# Saved comparison image for 29100020105000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29100020105000_05_comparison_comparison.png
# Saved comparison image for 29110020038000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29110020038000_01_comparison_comparison.png
# Saved comparison image for 29110020038000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29110020038000_02_comparison_comparison.png
# Saved comparison image for 29110020038000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29110020038000_04_comparison_comparison.png
# Saved comparison image for 29110020038000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29110020038000_05_comparison_comparison.png
# Saved comparison image for 29140110124000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29140110124000_02_comparison_comparison.png
# Saved comparison image for 29140110124000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29140110124000_04_comparison_comparison.png
# Saved comparison image for 29140110124000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29140110124000_05_comparison_comparison.png
# Saved comparison image for 29150020021000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150020021000_01_comparison_comparison.png
# Saved comparison image for 29150020021000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150020021000_02_comparison_comparison.png
# Saved comparison image for 29150020021000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150020021000_03_comparison_comparison.png
# Saved comparison image for 29150020021000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150020021000_04_comparison_comparison.png
# Saved comparison image for 29150020021000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150020021000_05_comparison_comparison.png
# Saved comparison image for 29150090029000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150090029000_01_comparison_comparison.png
# Saved comparison image for 29150090029000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150090029000_02_comparison_comparison.png
# Saved comparison image for 29150090029000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150090029000_03_comparison_comparison.png
# Saved comparison image for 29150090029000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150090029000_04_comparison_comparison.png
# Saved comparison image for 29150090029000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150090029000_05_comparison_comparison.png
# Saved comparison image for 29150100015000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150100015000_02_comparison_comparison.png
# Saved comparison image for 29150100015000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150100015000_03_comparison_comparison.png
# Saved comparison image for 29150100015000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150100015000_04_comparison_comparison.png
# Saved comparison image for 29150100015000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150100015000_05_comparison_comparison.png
# Saved comparison image for 29150120015000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150120015000_01_comparison_comparison.png
# Saved comparison image for 29150120015000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150120015000_02_comparison_comparison.png
# Saved comparison image for 29150120015000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150120015000_03_comparison_comparison.png
# Saved comparison image for 29150120015000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150120015000_04_comparison_comparison.png
# Saved comparison image for 29150120015000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150120015000_05_comparison_comparison.png
# Saved comparison image for 29150130015000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150130015000_01_comparison_comparison.png
# Saved comparison image for 29150130015000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150130015000_02_comparison_comparison.png
# Saved comparison image for 29150130015000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150130015000_03_comparison_comparison.png
# Saved comparison image for 29150130015000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150130015000_04_comparison_comparison.png
# Saved comparison image for 29150130015000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150130015000_05_comparison_comparison.png
# Saved comparison image for 29150180042000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150180042000_02_comparison_comparison.png
# Saved comparison image for 29150180042000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150180042000_03_comparison_comparison.png
# Saved comparison image for 29150180042000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150180042000_04_comparison_comparison.png
# Saved comparison image for 29150180042000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150180042000_05_comparison_comparison.png
# Saved comparison image for 29150260015000_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150260015000_01_comparison_comparison.png
# Saved comparison image for 29150260015000_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150260015000_02_comparison_comparison.png
# Saved comparison image for 29150260015000_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150260015000_03_comparison_comparison.png
# Saved comparison image for 29150260015000_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150260015000_04_comparison_comparison.png
# Saved comparison image for 29150260015000_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150260015000_05_comparison_comparison.png
# Saved comparison image for 29150260021001_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150260021001_01_comparison_comparison.png
# Saved comparison image for 29150260021001_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150260021001_02_comparison_comparison.png
# Saved comparison image for 29150260021001_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150260021001_03_comparison_comparison.png
# Saved comparison image for 29150260021001_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150260021001_04_comparison_comparison.png
# Saved comparison image for 29150260021001_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\29150260021001_05_comparison_comparison.png
# Saved comparison image for C013_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\C013_04_comparison_comparison.png
# Saved comparison image for C014_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\C014_01_comparison_comparison.png
# Saved comparison image for C014_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\C014_03_comparison_comparison.png
# Saved comparison image for C014_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\C014_05_comparison_comparison.png
# Saved comparison image for C016_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\C016_01_comparison_comparison.png
# Saved comparison image for C016_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\C016_02_comparison_comparison.png
# Saved comparison image for C016_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\C016_03_comparison_comparison.png
# Saved comparison image for C016_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\C016_05_comparison_comparison.png
# Saved comparison image for D008_01.jpg to D:/2024/paper2/model/test_comparison/zuoshu\D008_01_comparison_comparison.png
# Saved comparison image for D008_02.jpg to D:/2024/paper2/model/test_comparison/zuoshu\D008_02_comparison_comparison.png
# Saved comparison image for D008_03.jpg to D:/2024/paper2/model/test_comparison/zuoshu\D008_03_comparison_comparison.png
# Saved comparison image for D008_04.jpg to D:/2024/paper2/model/test_comparison/zuoshu\D008_04_comparison_comparison.png
# Saved comparison image for D008_05.jpg to D:/2024/paper2/model/test_comparison/zuoshu\D008_05_comparison_comparison.png
# 所有比较图像已保存！
