# %%
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from transformers import SegformerForSemanticSegmentation, SegformerConfig
import os
import numpy as np
from tqdm import tqdm
import json

# 数据集类
class TreeTrunkDataset(Dataset):
    def __init__(self, image_dir, mask_dir, json_dir, transform=None, target_size=(1024, 1024)):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.json_dir = json_dir
        self.transform = transform
        self.target_size = target_size  # 目标尺寸
        self.images = [img for img in os.listdir(image_dir) if img.lower().endswith(('.jpg', '.jpeg', '.png'))]
        self.images = [img for img in self.images if os.path.exists(os.path.join(mask_dir, img.replace(".JPG", ".png").replace(".jpg", ".png").replace(".jpeg", ".png")))]
        self.images = [img for img in self.images if os.path.exists(os.path.join(json_dir, img.replace(".JPG", ".json").replace(".jpg", ".json").replace(".jpeg", ".json")))]

        # 添加调试信息
        if len(self.images) == 0:
            print("未找到匹配的图像、掩码或 JSON 文件，请检查目录和文件扩展名。")
        else:
            print(f"找到 {len(self.images)} 个匹配的图像、掩码和 JSON 文件。")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.images[idx])
        mask_path = os.path.join(self.mask_dir, self.images[idx].replace(".JPG", ".png").replace(".jpg", ".png").replace(".jpeg", ".png"))
        json_path = os.path.join(self.json_dir, self.images[idx].replace(".JPG", ".json").replace(".jpg", ".json").replace(".jpeg", ".json"))
        
        # 读取图像
        image = Image.open(img_path).convert("RGB")  # 使用 Pillow 打开图像
        mask = Image.open(mask_path).convert('L')  # 转换为灰度图像
        mask = np.array(mask)  # 转换为numpy数组
        
        # 读取 JSON 文件
        with open(json_path, 'r') as f:
            json_data = json.load(f)

        # 统一图像和掩码的大小
        image = image.resize(self.target_size)
        mask = Image.fromarray(mask).resize(self.target_size, Image.NEAREST)
        
        # 转换为 Tensor
        if self.transform:
            image = self.transform(image)

        # 确保掩码值在0和1之间
        mask = np.clip(mask, 0, 1)
        mask = torch.tensor(mask, dtype=torch.long)
        
        return image, mask, json_data  # 返回 image, mask 和 json_data

# 自定义 collate_fn，确保每个批次中的数据大小一致
def collate_fn(batch):
    images, masks, json_data = zip(*batch)

    # 将所有图像堆叠成一个批次
    images = torch.stack(images, dim=0)
    
    # 将所有掩码堆叠成一个批次
    masks = torch.stack(masks, dim=0)

    return images, masks

# 设置路径
image_dir = "D:/2024/paper2/model/input_images2/huashu"
mask_dir = "D:/2024/paper2/model/output_masks/huashu"
json_dir = "D:/2024/paper2/model/sorted_JSON/huashu"

# 数据增强与预处理
transform = transforms.Compose([
    transforms.ToTensor(),  # 转换为 Tensor
])

# 数据集和数据加载器
dataset = TreeTrunkDataset(image_dir=image_dir, mask_dir=mask_dir, json_dir=json_dir, transform=transform)

# 检查数据集是否为空
if len(dataset) == 0:
    raise ValueError("数据集为空，请检查图像和掩码文件是否匹配且存在。")

# 使用自定义的 collate_fn 确保每个批次的大小一致
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=collate_fn)

# 初始化模型
config = SegformerConfig()
config.num_labels = 2  # 假设只有背景和前景两类
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SegformerForSemanticSegmentation(config).to(device)

# 定义损失函数和优化器
optimizer = optim.AdamW(model.parameters(), lr=0.0001)

# 自定义中心加权损失
class WeightedCrossEntropyLoss(nn.Module):
    def __init__(self, weight_center=2.0):
        super(WeightedCrossEntropyLoss, self).__init__()
        self.weight_center = weight_center
        self.ce_loss = nn.CrossEntropyLoss(reduction='none')

    def forward(self, inputs, targets):
        # 确保 inputs 和 targets 的维度一致
        if inputs.shape[2:] != targets.shape:
            targets = targets.unsqueeze(1)
            targets = torch.nn.functional.interpolate(targets.float(), size=inputs.shape[2:], mode='nearest').squeeze(1).long()
        
        # 计算基本交叉熵损失
        loss = self.ce_loss(inputs, targets)

        # 中心区域权重：仅对纵向范围中心加权，横向不变
        _, _, h, w = inputs.shape
        y_center, x_center = h // 2, w // 2
        weight_mask = torch.ones_like(targets, dtype=torch.float32)
        weight_mask[y_center - h // 4:y_center + h // 4, :] = self.weight_center  # 仅纵向范围

        # 应用权重
        weighted_loss = loss * weight_mask.to(inputs.device)
        return weighted_loss.mean()

criterion = WeightedCrossEntropyLoss(weight_center=5.0)

# 训练循环
epochs = 100
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    with tqdm(total=len(dataloader), desc=f"Epoch {epoch+1}/{epochs}") as pbar:
        for images, masks in dataloader:  # 加载图像和掩码
            images, masks = images.to(device), masks.to(device)

            # 前向传播
            outputs = model(images).logits
            # 调整输出大小以匹配掩码大小
            outputs = torch.nn.functional.interpolate(outputs, size=(masks.shape[1], masks.shape[2]), mode='bilinear', align_corners=False)

            # 计算损失
            loss = criterion(outputs, masks)

            # 反向传播和优化
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            pbar.update(1)  # 更新 tqdm 进度条
            pbar.set_postfix({"Loss": f"{loss.item():.4f}"})  # 显示当前损失

    print(f"Epoch [{epoch+1}/{epochs}], Loss: {running_loss/len(dataloader):.4f}")

# 保存模型
save_dir = "D:/2024/paper2/model/Model/huashu"
os.makedirs(save_dir, exist_ok=True)

# 保存完整模型
model_save_path = os.path.join(save_dir, "segformer_full_model.pth")
torch.save(model, model_save_path)
print(f"完整模型已保存到 {model_save_path}")

# 保存模型权重
weights_save_path = os.path.join(save_dir, "segformer_weights.pth")
torch.save(model.state_dict(), weights_save_path)
print(f"模型权重已保存到 {weights_save_path}")


# 保存配置文件
config_save_path = os.path.join(save_dir, "config.json")
config.save_pretrained(save_dir)
print(f"配置文件已保存到 {config_save_path}")

# 保存检查点文件
checkpoint_save_path = os.path.join(save_dir, "checkpoint.pth")
torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "config": config.to_dict(),
    "epoch": epochs,
}, checkpoint_save_path)
print(f"检查点文件已保存到 {checkpoint_save_path}")

print("训练完成并保存所有文件！")
# Out:
# 找到 124 个匹配的图像、掩码和 JSON 文件。
# Epoch 1/100: 100%|██████████| 31/31 [07:08<00:00, 13.82s/it, Loss=0.3565]
# Epoch [88/100], Loss: 0.0114
# Epoch 89/100: 100%|██████████| 31/31 [02:42<00:00,  5.23s/it, Loss=0.0136]
# Epoch [89/100], Loss: 0.0115
# Epoch 90/100: 100%|██████████| 31/31 [02:42<00:00,  5.23s/it, Loss=0.0111]
# Epoch [90/100], Loss: 0.0119
# Epoch 91/100: 100%|██████████| 31/31 [02:42<00:00,  5.23s/it, Loss=0.0155]
# Epoch [91/100], Loss: 0.0116
# Epoch 92/100: 100%|██████████| 31/31 [02:42<00:00,  5.24s/it, Loss=0.0115]
# Epoch [92/100], Loss: 0.0112
# Epoch 93/100: 100%|██████████| 31/31 [02:41<00:00,  5.22s/it, Loss=0.0184]
# Epoch [93/100], Loss: 0.0122
# Epoch 94/100: 100%|██████████| 31/31 [02:42<00:00,  5.25s/it, Loss=0.0110]
# Epoch [94/100], Loss: 0.0107
# Epoch 95/100: 100%|██████████| 31/31 [02:42<00:00,  5.25s/it, Loss=0.0115]
# Epoch [95/100], Loss: 0.0113
# Epoch 96/100: 100%|██████████| 31/31 [02:42<00:00,  5.25s/it, Loss=0.0103]
# Epoch [96/100], Loss: 0.0113
# Epoch 97/100: 100%|██████████| 31/31 [02:42<00:00,  5.24s/it, Loss=0.0093]
# Epoch [97/100], Loss: 0.0112
# Epoch 98/100: 100%|██████████| 31/31 [02:42<00:00,  5.24s/it, Loss=0.0123]
# Epoch [98/100], Loss: 0.0107
# Epoch 99/100: 100%|██████████| 31/31 [02:42<00:00,  5.25s/it, Loss=0.0082]
# Epoch [99/100], Loss: 0.0104
# Epoch 100/100: 100%|██████████| 31/31 [02:42<00:00,  5.25s/it, Loss=0.0083]
# Epoch [100/100], Loss: 0.0107
# 完整模型已保存到 D:/2024/paper2/model/Model/huashu\segformer_full_model.pth
# 模型权重已保存到 D:/2024/paper2/model/Model/huashu\segformer_weights.pth
# 配置文件已保存到 D:/2024/paper2/model/Model/huashu\config.json
# 检查点文件已保存到 D:/2024/paper2/model/Model/huashu\checkpoint.pth
# 训练完成并保存所有文件！

# %%
import torch
import os
from PIL import Image
from torchvision import transforms
from transformers import SegformerForSemanticSegmentation
import numpy as np

# 设置路径
image_dir = "D:/2024/paper2/model/test/huashu"  # 验证图像文件夹
output_mask_dir = "D:/2024/paper2/model/test_masks/huashu"  # 输出掩码文件夹
model_dir = "D:/2024/paper2/model/Model/huashu"  # 模型文件夹

# 加载完整模型
model_path = os.path.join(model_dir, "segformer_full_model.pth")
model = torch.load(model_path)  # 直接加载完整模型
model.eval()  # 设置为评估模式

# 数据预处理（与训练时相同）
transform = transforms.Compose([
    transforms.ToTensor(),  # 转换为 Tensor
])

# 创建输出文件夹（如果不存在）
os.makedirs(output_mask_dir, exist_ok=True)

# 验证集图像文件名
image_filenames = [f for f in os.listdir(image_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# 推理过程
with torch.no_grad():  # 在推理时不需要计算梯度
    for filename in image_filenames:
        img_path = os.path.join(image_dir, filename)
        
        # 读取图像
        image = Image.open(img_path).convert("RGB")
        
        # 保存原始尺寸
        original_size = image.size
        
        # 统一尺寸（假设训练时输入尺寸是1024x1024）
        target_size = (1024, 1024)  # 如果你的验证图像不是1024x1024，可能需要调整此处
        image_resized = image.resize(target_size)

        # 进行预处理
        image_tensor = transform(image_resized).unsqueeze(0).to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))

        # 模型推理
        outputs = model(image_tensor).logits

        # 获取预测的类别标签（背景=0, 树干=1）
        predicted_mask = torch.argmax(outputs, dim=1).squeeze(0).cpu().numpy().astype(np.uint8)

        # 将输出的掩码转换为 0 和 255（黑色背景，白色树干）
        predicted_mask = predicted_mask * 255  # 0 -> 0, 1 -> 255

        # 将预测掩码调整回原始输入图像的大小
        predicted_mask_resized = Image.fromarray(predicted_mask)
        predicted_mask_resized = predicted_mask_resized.resize(original_size, Image.NEAREST)

        # 保存掩码图像
        mask_filename = os.path.join(output_mask_dir, filename.replace(".jpg", ".png").replace(".jpeg", ".png").replace(".png", ".png"))
        predicted_mask_resized.save(mask_filename)

        print(f"Saved mask for {filename} to {mask_filename}")

print("推理完成，所有掩码已保存！")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_1932\3642464810.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path)  # 直接加载完整模型
# Saved mask for 09010010055000_01.jpg to D:/2024/paper2/model/test_masks/huashu\09010010055000_01.png
# Saved mask for 09010010055000_02.jpg to D:/2024/paper2/model/test_masks/huashu\09010010055000_02.png
# Saved mask for 09010010055000_03.jpg to D:/2024/paper2/model/test_masks/huashu\09010010055000_03.png
# Saved mask for 09010010055000_04.jpg to D:/2024/paper2/model/test_masks/huashu\09010010055000_04.png
# Saved mask for 09010010055000_05.jpg to D:/2024/paper2/model/test_masks/huashu\09010010055000_05.png
# Saved mask for 09010010070000_02.jpg to D:/2024/paper2/model/test_masks/huashu\09010010070000_02.png
# Saved mask for 09010010108000_05.jpg to D:/2024/paper2/model/test_masks/huashu\09010010108000_05.png
# Saved mask for 09010010117000_01.jpg to D:/2024/paper2/model/test_masks/huashu\09010010117000_01.png
# Saved mask for 09010010117000_02.jpg to D:/2024/paper2/model/test_masks/huashu\09010010117000_02.png
# Saved mask for 09010010117000_03.jpg to D:/2024/paper2/model/test_masks/huashu\09010010117000_03.png
# Saved mask for 09010010119000_01.jpg to D:/2024/paper2/model/test_masks/huashu\09010010119000_01.png
# Saved mask for 09010010119000_03.jpg to D:/2024/paper2/model/test_masks/huashu\09010010119000_03.png
# Saved mask for 09010010119000_04.jpg to D:/2024/paper2/model/test_masks/huashu\09010010119000_04.png
# Saved mask for 09010110005000_01.jpg to D:/2024/paper2/model/test_masks/huashu\09010110005000_01.png
# Saved mask for 09010110005000_02.jpg to D:/2024/paper2/model/test_masks/huashu\09010110005000_02.png
# Saved mask for 09010110005000_03.jpg to D:/2024/paper2/model/test_masks/huashu\09010110005000_03.png
# Saved mask for 09010110005000_04.jpg to D:/2024/paper2/model/test_masks/huashu\09010110005000_04.png
# Saved mask for 09010110005000_05.jpg to D:/2024/paper2/model/test_masks/huashu\09010110005000_05.png
# Saved mask for 09010280059000_02.jpg to D:/2024/paper2/model/test_masks/huashu\09010280059000_02.png
# Saved mask for 09010280059000_03.jpg to D:/2024/paper2/model/test_masks/huashu\09010280059000_03.png
# Saved mask for 09010280059000_04.jpg to D:/2024/paper2/model/test_masks/huashu\09010280059000_04.png
# Saved mask for 09010280059000_05.jpg to D:/2024/paper2/model/test_masks/huashu\09010280059000_05.png
# Saved mask for 09010280066000_03.jpg to D:/2024/paper2/model/test_masks/huashu\09010280066000_03.png
# Saved mask for 09010280067000_03.jpg to D:/2024/paper2/model/test_masks/huashu\09010280067000_03.png
# Saved mask for 09010280067000_05.jpg to D:/2024/paper2/model/test_masks/huashu\09010280067000_05.png
# Saved mask for 09010280068000_01.jpg to D:/2024/paper2/model/test_masks/huashu\09010280068000_01.png
# Saved mask for 09010280068000_03.jpg to D:/2024/paper2/model/test_masks/huashu\09010280068000_03.png
# Saved mask for 09010280068000_05.jpg to D:/2024/paper2/model/test_masks/huashu\09010280068000_05.png
# Saved mask for 09010280071000_05.jpg to D:/2024/paper2/model/test_masks/huashu\09010280071000_05.png
# Saved mask for 09010280078000_02.jpg to D:/2024/paper2/model/test_masks/huashu\09010280078000_02.png
# Saved mask for 09010280080001_01.jpg to D:/2024/paper2/model/test_masks/huashu\09010280080001_01.png
# Saved mask for 09010280080001_02.jpg to D:/2024/paper2/model/test_masks/huashu\09010280080001_02.png
# Saved mask for 09010280080001_05.jpg to D:/2024/paper2/model/test_masks/huashu\09010280080001_05.png
# Saved mask for 09010280082000_02.jpg to D:/2024/paper2/model/test_masks/huashu\09010280082000_02.png
# Saved mask for 09010280082000_04.jpg to D:/2024/paper2/model/test_masks/huashu\09010280082000_04.png
# Saved mask for 09010370012000_01.jpg to D:/2024/paper2/model/test_masks/huashu\09010370012000_01.png
# Saved mask for 09010370055000_02.jpg to D:/2024/paper2/model/test_masks/huashu\09010370055000_02.png
# Saved mask for 09010370055000_03.jpg to D:/2024/paper2/model/test_masks/huashu\09010370055000_03.png
# Saved mask for 09010370055000_04.jpg to D:/2024/paper2/model/test_masks/huashu\09010370055000_04.png
# Saved mask for 09010370055000_05.jpg to D:/2024/paper2/model/test_masks/huashu\09010370055000_05.png
# Saved mask for 09010370056000_01.jpg to D:/2024/paper2/model/test_masks/huashu\09010370056000_01.png
# Saved mask for 09010370056000_02.jpg to D:/2024/paper2/model/test_masks/huashu\09010370056000_02.png
# Saved mask for 09010370056000_03.jpg to D:/2024/paper2/model/test_masks/huashu\09010370056000_03.png
# Saved mask for 09030010004000_01.jpg to D:/2024/paper2/model/test_masks/huashu\09030010004000_01.png
# Saved mask for 09030010004000_02.jpg to D:/2024/paper2/model/test_masks/huashu\09030010004000_02.png
# Saved mask for 09030010004000_03.jpg to D:/2024/paper2/model/test_masks/huashu\09030010004000_03.png
# Saved mask for 09030010004000_04.jpg to D:/2024/paper2/model/test_masks/huashu\09030010004000_04.png
# Saved mask for 09030010011000_01.jpg to D:/2024/paper2/model/test_masks/huashu\09030010011000_01.png
# Saved mask for 09030010020000_05.jpg to D:/2024/paper2/model/test_masks/huashu\09030010020000_05.png
# Saved mask for 09030010052000_01.jpg to D:/2024/paper2/model/test_masks/huashu\09030010052000_01.png
# Saved mask for 09030010052000_02.jpg to D:/2024/paper2/model/test_masks/huashu\09030010052000_02.png
# Saved mask for 09030010052000_03.jpg to D:/2024/paper2/model/test_masks/huashu\09030010052000_03.png
# Saved mask for 09030010052000_04.jpg to D:/2024/paper2/model/test_masks/huashu\09030010052000_04.png
# Saved mask for 09030010052000_05.jpg to D:/2024/paper2/model/test_masks/huashu\09030010052000_05.png
# Saved mask for 09030010061000_01.jpg to D:/2024/paper2/model/test_masks/huashu\09030010061000_01.png
# Saved mask for 09030010061000_02.jpg to D:/2024/paper2/model/test_masks/huashu\09030010061000_02.png
# Saved mask for 09030010061000_03.jpg to D:/2024/paper2/model/test_masks/huashu\09030010061000_03.png
# Saved mask for 09030010061000_04.jpg to D:/2024/paper2/model/test_masks/huashu\09030010061000_04.png
# Saved mask for 09100010014000_01.jpg to D:/2024/paper2/model/test_masks/huashu\09100010014000_01.png
# Saved mask for 09100010014000_02.jpg to D:/2024/paper2/model/test_masks/huashu\09100010014000_02.png
# Saved mask for 09100010014000_05.jpg to D:/2024/paper2/model/test_masks/huashu\09100010014000_05.png
# Saved mask for 11020080008000_05.jpg to D:/2024/paper2/model/test_masks/huashu\11020080008000_05.png
# Saved mask for 11020080076000_04.jpg to D:/2024/paper2/model/test_masks/huashu\11020080076000_04.png
# Saved mask for 16010030152002_01.jpg to D:/2024/paper2/model/test_masks/huashu\16010030152002_01.png
# Saved mask for 16010030152002_02.jpg to D:/2024/paper2/model/test_masks/huashu\16010030152002_02.png
# Saved mask for 16010030152002_03.jpg to D:/2024/paper2/model/test_masks/huashu\16010030152002_03.png
# Saved mask for 16010030152002_04.jpg to D:/2024/paper2/model/test_masks/huashu\16010030152002_04.png
# Saved mask for 16010030152002_05.jpg to D:/2024/paper2/model/test_masks/huashu\16010030152002_05.png
# Saved mask for 16010040367001_01.jpg to D:/2024/paper2/model/test_masks/huashu\16010040367001_01.png
# Saved mask for 16010040367001_02.jpg to D:/2024/paper2/model/test_masks/huashu\16010040367001_02.png
# Saved mask for 16010040367001_03.jpg to D:/2024/paper2/model/test_masks/huashu\16010040367001_03.png
# Saved mask for 16010040367001_04.jpg to D:/2024/paper2/model/test_masks/huashu\16010040367001_04.png
# Saved mask for 16010040367001_05.jpg to D:/2024/paper2/model/test_masks/huashu\16010040367001_05.png
# Saved mask for 16010070007000_01.jpg to D:/2024/paper2/model/test_masks/huashu\16010070007000_01.png
# Saved mask for 16010070007000_02.jpg to D:/2024/paper2/model/test_masks/huashu\16010070007000_02.png
# Saved mask for 16010070007000_03.jpg to D:/2024/paper2/model/test_masks/huashu\16010070007000_03.png
# Saved mask for 16010070007000_04.jpg to D:/2024/paper2/model/test_masks/huashu\16010070007000_04.png
# Saved mask for 16010070007000_05.jpg to D:/2024/paper2/model/test_masks/huashu\16010070007000_05.png
# Saved mask for 16010090305003_04.jpg to D:/2024/paper2/model/test_masks/huashu\16010090305003_04.png
# Saved mask for 16010090305003_05.jpg to D:/2024/paper2/model/test_masks/huashu\16010090305003_05.png
# Saved mask for 16010120225000_01.jpg to D:/2024/paper2/model/test_masks/huashu\16010120225000_01.png
# Saved mask for 16010120225000_02.jpg to D:/2024/paper2/model/test_masks/huashu\16010120225000_02.png
# Saved mask for 16010120225000_03.jpg to D:/2024/paper2/model/test_masks/huashu\16010120225000_03.png
# Saved mask for 16010120225000_04.jpg to D:/2024/paper2/model/test_masks/huashu\16010120225000_04.png
# Saved mask for 16010120225000_05.jpg to D:/2024/paper2/model/test_masks/huashu\16010120225000_05.png
# Saved mask for 16011010030002_01.jpg to D:/2024/paper2/model/test_masks/huashu\16011010030002_01.png
# Saved mask for 16011010030002_02.jpg to D:/2024/paper2/model/test_masks/huashu\16011010030002_02.png
# Saved mask for 16011010030002_03.jpg to D:/2024/paper2/model/test_masks/huashu\16011010030002_03.png
# Saved mask for 16011010030002_04.jpg to D:/2024/paper2/model/test_masks/huashu\16011010030002_04.png
# Saved mask for 16011010030002_05.jpg to D:/2024/paper2/model/test_masks/huashu\16011010030002_05.png
# Saved mask for 16011020157003_01.jpg to D:/2024/paper2/model/test_masks/huashu\16011020157003_01.png
# Saved mask for 16011020157003_02.jpg to D:/2024/paper2/model/test_masks/huashu\16011020157003_02.png
# Saved mask for 16011020157003_03.jpg to D:/2024/paper2/model/test_masks/huashu\16011020157003_03.png
# Saved mask for 16011020157003_04.jpg to D:/2024/paper2/model/test_masks/huashu\16011020157003_04.png
# Saved mask for 16011020157003_05.jpg to D:/2024/paper2/model/test_masks/huashu\16011020157003_05.png
# Saved mask for 16015010059000_02.jpg to D:/2024/paper2/model/test_masks/huashu\16015010059000_02.png
# Saved mask for 16015010059000_03.jpg to D:/2024/paper2/model/test_masks/huashu\16015010059000_03.png
# Saved mask for 16015010160000_02.jpg to D:/2024/paper2/model/test_masks/huashu\16015010160000_02.png
# Saved mask for 16015010160000_03.jpg to D:/2024/paper2/model/test_masks/huashu\16015010160000_03.png
# Saved mask for 16015010160000_05.jpg to D:/2024/paper2/model/test_masks/huashu\16015010160000_05.png
# Saved mask for 16015010262002_01.jpg to D:/2024/paper2/model/test_masks/huashu\16015010262002_01.png
# Saved mask for 16015010262002_02.jpg to D:/2024/paper2/model/test_masks/huashu\16015010262002_02.png
# Saved mask for 16015010262002_03.jpg to D:/2024/paper2/model/test_masks/huashu\16015010262002_03.png
# Saved mask for 16015010262002_04.jpg to D:/2024/paper2/model/test_masks/huashu\16015010262002_04.png
# Saved mask for 16015010262002_05.jpg to D:/2024/paper2/model/test_masks/huashu\16015010262002_05.png
# Saved mask for 16015010276002_01.jpg to D:/2024/paper2/model/test_masks/huashu\16015010276002_01.png
# Saved mask for 16015010276002_02.jpg to D:/2024/paper2/model/test_masks/huashu\16015010276002_02.png
# Saved mask for 16015010276002_03.jpg to D:/2024/paper2/model/test_masks/huashu\16015010276002_03.png
# Saved mask for 16015010276002_04.jpg to D:/2024/paper2/model/test_masks/huashu\16015010276002_04.png
# Saved mask for 16015010276002_05.jpg to D:/2024/paper2/model/test_masks/huashu\16015010276002_05.png
# Saved mask for 16020010001000_01.jpg to D:/2024/paper2/model/test_masks/huashu\16020010001000_01.png
# Saved mask for 16020010001000_02.jpg to D:/2024/paper2/model/test_masks/huashu\16020010001000_02.png
# Saved mask for 16020010001000_04.jpg to D:/2024/paper2/model/test_masks/huashu\16020010001000_04.png
# Saved mask for 16020010059001_01.jpg to D:/2024/paper2/model/test_masks/huashu\16020010059001_01.png
# Saved mask for 16020010059001_02.jpg to D:/2024/paper2/model/test_masks/huashu\16020010059001_02.png
# Saved mask for 16020010059001_03.jpg to D:/2024/paper2/model/test_masks/huashu\16020010059001_03.png
# Saved mask for 16020010059001_04.jpg to D:/2024/paper2/model/test_masks/huashu\16020010059001_04.png
# Saved mask for 16020010062000_01.jpg to D:/2024/paper2/model/test_masks/huashu\16020010062000_01.png
# Saved mask for 16020010062000_02.jpg to D:/2024/paper2/model/test_masks/huashu\16020010062000_02.png
# Saved mask for 16020010062000_04.jpg to D:/2024/paper2/model/test_masks/huashu\16020010062000_04.png
# Saved mask for 16020010062000_05.jpg to D:/2024/paper2/model/test_masks/huashu\16020010062000_05.png
# Saved mask for 16020010074000_01.jpg to D:/2024/paper2/model/test_masks/huashu\16020010074000_01.png
# Saved mask for 16020010117000_01.jpg to D:/2024/paper2/model/test_masks/huashu\16020010117000_01.png
# Saved mask for 16020010117000_02.jpg to D:/2024/paper2/model/test_masks/huashu\16020010117000_02.png
# Saved mask for 16020010117000_05.jpg to D:/2024/paper2/model/test_masks/huashu\16020010117000_05.png
# Saved mask for 16020010125000_01.jpg to D:/2024/paper2/model/test_masks/huashu\16020010125000_01.png
# Saved mask for 16020010125000_03.jpg to D:/2024/paper2/model/test_masks/huashu\16020010125000_03.png
# Saved mask for 16020010134000_03.jpg to D:/2024/paper2/model/test_masks/huashu\16020010134000_03.png
# Saved mask for 16020010134000_04.jpg to D:/2024/paper2/model/test_masks/huashu\16020010134000_04.png
# Saved mask for 16020010134000_05.jpg to D:/2024/paper2/model/test_masks/huashu\16020010134000_05.png
# Saved mask for 16040030024001_01.jpg to D:/2024/paper2/model/test_masks/huashu\16040030024001_01.png
# Saved mask for 16040030024001_02.jpg to D:/2024/paper2/model/test_masks/huashu\16040030024001_02.png
# Saved mask for 16040030024001_03.jpg to D:/2024/paper2/model/test_masks/huashu\16040030024001_03.png
# Saved mask for 16040030024001_04.jpg to D:/2024/paper2/model/test_masks/huashu\16040030024001_04.png
# Saved mask for 16040030024001_05.jpg to D:/2024/paper2/model/test_masks/huashu\16040030024001_05.png
# Saved mask for 28200070004000_03.jpg to D:/2024/paper2/model/test_masks/huashu\28200070004000_03.png
# Saved mask for 28200070004000_05.jpg to D:/2024/paper2/model/test_masks/huashu\28200070004000_05.png
# Saved mask for 28200070012000_02.jpg to D:/2024/paper2/model/test_masks/huashu\28200070012000_02.png
# Saved mask for 28200070012000_04.jpg to D:/2024/paper2/model/test_masks/huashu\28200070012000_04.png
# Saved mask for 28200110003000_01.jpg to D:/2024/paper2/model/test_masks/huashu\28200110003000_01.png
# Saved mask for 28200110003000_02.jpg to D:/2024/paper2/model/test_masks/huashu\28200110003000_02.png
# Saved mask for 28200110003000_03.jpg to D:/2024/paper2/model/test_masks/huashu\28200110003000_03.png
# Saved mask for 28200110003000_04.jpg to D:/2024/paper2/model/test_masks/huashu\28200110003000_04.png
# Saved mask for 28200110005000_01.jpg to D:/2024/paper2/model/test_masks/huashu\28200110005000_01.png
# Saved mask for 28200110005000_02.jpg to D:/2024/paper2/model/test_masks/huashu\28200110005000_02.png
# Saved mask for 28200110005000_03.jpg to D:/2024/paper2/model/test_masks/huashu\28200110005000_03.png
# Saved mask for 28200110005000_04.jpg to D:/2024/paper2/model/test_masks/huashu\28200110005000_04.png
# Saved mask for 28200110008000_01.jpg to D:/2024/paper2/model/test_masks/huashu\28200110008000_01.png
# Saved mask for 28200110008000_02.jpg to D:/2024/paper2/model/test_masks/huashu\28200110008000_02.png
# Saved mask for 28200110008000_03.jpg to D:/2024/paper2/model/test_masks/huashu\28200110008000_03.png
# Saved mask for 28200110008000_04.jpg to D:/2024/paper2/model/test_masks/huashu\28200110008000_04.png
# Saved mask for 28200110008000_05.jpg to D:/2024/paper2/model/test_masks/huashu\28200110008000_05.png
# Saved mask for 28200110011000_01.jpg to D:/2024/paper2/model/test_masks/huashu\28200110011000_01.png
# Saved mask for 28200110011000_02.jpg to D:/2024/paper2/model/test_masks/huashu\28200110011000_02.png
# Saved mask for 28200110011000_03.jpg to D:/2024/paper2/model/test_masks/huashu\28200110011000_03.png
# Saved mask for 28200110011000_04.jpg to D:/2024/paper2/model/test_masks/huashu\28200110011000_04.png
# Saved mask for 28200110011000_05.jpg to D:/2024/paper2/model/test_masks/huashu\28200110011000_05.png
# Saved mask for 29020170063006_01.jpg to D:/2024/paper2/model/test_masks/huashu\29020170063006_01.png
# Saved mask for 29020170063006_02.jpg to D:/2024/paper2/model/test_masks/huashu\29020170063006_02.png
# Saved mask for 29020170063006_03.jpg to D:/2024/paper2/model/test_masks/huashu\29020170063006_03.png
# Saved mask for 29020170063006_04.jpg to D:/2024/paper2/model/test_masks/huashu\29020170063006_04.png
# Saved mask for 29020170063006_05.jpg to D:/2024/paper2/model/test_masks/huashu\29020170063006_05.png
# Saved mask for 29020170065019_02.jpg to D:/2024/paper2/model/test_masks/huashu\29020170065019_02.png
# Saved mask for 29020170065019_03.jpg to D:/2024/paper2/model/test_masks/huashu\29020170065019_03.png
# Saved mask for 29020170065019_04.jpg to D:/2024/paper2/model/test_masks/huashu\29020170065019_04.png
# Saved mask for 29020170065019_05.jpg to D:/2024/paper2/model/test_masks/huashu\29020170065019_05.png
# Saved mask for 29020170110001_03.jpg to D:/2024/paper2/model/test_masks/huashu\29020170110001_03.png
# Saved mask for 29060330025000_02.jpg to D:/2024/paper2/model/test_masks/huashu\29060330025000_02.png
# Saved mask for 29060330025000_03.jpg to D:/2024/paper2/model/test_masks/huashu\29060330025000_03.png
# Saved mask for 29060330025000_04.jpg to D:/2024/paper2/model/test_masks/huashu\29060330025000_04.png
# Saved mask for 29060330025000_05.jpg to D:/2024/paper2/model/test_masks/huashu\29060330025000_05.png
# Saved mask for 29080290037000_01.jpg to D:/2024/paper2/model/test_masks/huashu\29080290037000_01.png
# Saved mask for 29080290037000_02.jpg to D:/2024/paper2/model/test_masks/huashu\29080290037000_02.png
# Saved mask for 29080290037000_03.jpg to D:/2024/paper2/model/test_masks/huashu\29080290037000_03.png
# Saved mask for 29080290037000_04.jpg to D:/2024/paper2/model/test_masks/huashu\29080290037000_04.png
# Saved mask for 29080290037000_05.jpg to D:/2024/paper2/model/test_masks/huashu\29080290037000_05.png
# Saved mask for 29080290050000_01.jpg to D:/2024/paper2/model/test_masks/huashu\29080290050000_01.png
# Saved mask for 29080290050000_02.jpg to D:/2024/paper2/model/test_masks/huashu\29080290050000_02.png
# Saved mask for 29080290050000_03.jpg to D:/2024/paper2/model/test_masks/huashu\29080290050000_03.png
# Saved mask for 29080290050000_04.jpg to D:/2024/paper2/model/test_masks/huashu\29080290050000_04.png
# Saved mask for 29080290050000_05.jpg to D:/2024/paper2/model/test_masks/huashu\29080290050000_05.png
# Saved mask for 29080290061000_01.jpg to D:/2024/paper2/model/test_masks/huashu\29080290061000_01.png
# Saved mask for 29080290061000_02.jpg to D:/2024/paper2/model/test_masks/huashu\29080290061000_02.png
# Saved mask for 29080290061000_03.jpg to D:/2024/paper2/model/test_masks/huashu\29080290061000_03.png
# Saved mask for 29080290061000_04.jpg to D:/2024/paper2/model/test_masks/huashu\29080290061000_04.png
# Saved mask for 29080290061000_05.jpg to D:/2024/paper2/model/test_masks/huashu\29080290061000_05.png
# Saved mask for 29090010448010_01.jpg to D:/2024/paper2/model/test_masks/huashu\29090010448010_01.png
# Saved mask for 29090010448010_02.jpg to D:/2024/paper2/model/test_masks/huashu\29090010448010_02.png
# Saved mask for 29090010448010_03.jpg to D:/2024/paper2/model/test_masks/huashu\29090010448010_03.png
# Saved mask for 29090010448010_04.jpg to D:/2024/paper2/model/test_masks/huashu\29090010448010_04.png
# Saved mask for 29090010448010_05.jpg to D:/2024/paper2/model/test_masks/huashu\29090010448010_05.png
# Saved mask for 29090010448014_01.jpg to D:/2024/paper2/model/test_masks/huashu\29090010448014_01.png
# Saved mask for 29090010448014_02.jpg to D:/2024/paper2/model/test_masks/huashu\29090010448014_02.png
# Saved mask for 29090010448014_03.jpg to D:/2024/paper2/model/test_masks/huashu\29090010448014_03.png
# Saved mask for 29090010448014_04.jpg to D:/2024/paper2/model/test_masks/huashu\29090010448014_04.png
# Saved mask for 29090010448014_05.jpg to D:/2024/paper2/model/test_masks/huashu\29090010448014_05.png
# Saved mask for 29140090057004_01.jpg to D:/2024/paper2/model/test_masks/huashu\29140090057004_01.png
# Saved mask for 29140090057004_02.jpg to D:/2024/paper2/model/test_masks/huashu\29140090057004_02.png
# Saved mask for 29140090057004_03.jpg to D:/2024/paper2/model/test_masks/huashu\29140090057004_03.png
# Saved mask for 29140090057004_04.jpg to D:/2024/paper2/model/test_masks/huashu\29140090057004_04.png
# Saved mask for 29140090057004_05.jpg to D:/2024/paper2/model/test_masks/huashu\29140090057004_05.png
# Saved mask for D051_03.jpg to D:/2024/paper2/model/test_masks/huashu\D051_03.png
# Saved mask for D051_05.jpg to D:/2024/paper2/model/test_masks/huashu\D051_05.png
# Saved mask for D052_01.jpg to D:/2024/paper2/model/test_masks/huashu\D052_01.png
# Saved mask for D052_05.jpg to D:/2024/paper2/model/test_masks/huashu\D052_05.png
# Saved mask for D053_01.jpg to D:/2024/paper2/model/test_masks/huashu\D053_01.png
# Saved mask for D053_03.jpg to D:/2024/paper2/model/test_masks/huashu\D053_03.png
# Saved mask for D054_01.jpg to D:/2024/paper2/model/test_masks/huashu\D054_01.png
# Saved mask for D054_02.jpg to D:/2024/paper2/model/test_masks/huashu\D054_02.png
# Saved mask for D054_04.jpg to D:/2024/paper2/model/test_masks/huashu\D054_04.png
# Saved mask for D054_05.jpg to D:/2024/paper2/model/test_masks/huashu\D054_05.png
# Saved mask for D055_01.jpg to D:/2024/paper2/model/test_masks/huashu\D055_01.png
# Saved mask for D055_02.jpg to D:/2024/paper2/model/test_masks/huashu\D055_02.png
# Saved mask for D055_03.jpg to D:/2024/paper2/model/test_masks/huashu\D055_03.png
# Saved mask for D056_04.jpg to D:/2024/paper2/model/test_masks/huashu\D056_04.png
# Saved mask for D056_05.jpg to D:/2024/paper2/model/test_masks/huashu\D056_05.png
# Saved mask for D057_02.jpg to D:/2024/paper2/model/test_masks/huashu\D057_02.png
# Saved mask for D057_03.jpg to D:/2024/paper2/model/test_masks/huashu\D057_03.png
# Saved mask for D057_04.jpg to D:/2024/paper2/model/test_masks/huashu\D057_04.png
# Saved mask for D057_05.jpg to D:/2024/paper2/model/test_masks/huashu\D057_05.png
# Saved mask for G006_01.jpg to D:/2024/paper2/model/test_masks/huashu\G006_01.png
# Saved mask for G006_02.jpg to D:/2024/paper2/model/test_masks/huashu\G006_02.png
# Saved mask for G006_03.jpg to D:/2024/paper2/model/test_masks/huashu\G006_03.png
# Saved mask for G006_04.jpg to D:/2024/paper2/model/test_masks/huashu\G006_04.png
# 推理完成，所有掩码已保存！

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# 设置路径
image_dir = "D:/2024/paper2/model/test/huashu"  # 验证图像文件夹
mask_dir = "D:/2024/paper2/model/test_masks/huashu"  # 单通道掩码文件夹
output_dir = "D:/2024/paper2/model/test_comparison/huashu"  # 输出图片文件夹

# 创建输出文件夹（如果不存在）
os.makedirs(output_dir, exist_ok=True)

# 获取图像文件名
image_filenames = [f for f in os.listdir(image_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# 处理每个图像
for filename in image_filenames:
    # 构造图像路径和掩码路径
    img_path = os.path.join(image_dir, filename)
    mask_path = os.path.join(mask_dir, filename.replace(".jpg", ".png").replace(".jpeg", ".png").replace(".png", ".png"))

    # 读取验证图像和掩码图像
    image = Image.open(img_path).convert("RGB")  # 读取并转换为 RGB 图像
    mask = Image.open(mask_path).convert("L")  # 读取掩码并转换为灰度图像（L 模式）

    # 将掩码图像转换为 numpy 数组（0 表示背景，255 表示树干）
    mask_array = np.array(mask)

    # 将掩码值转换为 0 或 1（0 -> 背景，1 -> 树干）
    mask_binary = (mask_array > 127).astype(int)  # 将大于127的像素值转为 1，小于等于127的为 0

    # 将原始图像和掩码图像叠加
    image_array = np.array(image)

    # 使用掩码区域将原始图像覆盖成不同的颜色（比如将树干区域用红色标出）
    # 红色区域表示模型预测的树干区域
    image_with_mask = image_array.copy()
    image_with_mask[mask_binary == 1] = [255, 0, 0]  # 将树干区域标记为红色 [255, 0, 0]

    # 将原始图像与掩码图像并排显示
    # 设置高分辨率图像
    fig, axes = plt.subplots(1, 2, figsize=(16, 8), dpi=200)  # 设置更大的图像大小和更高的 DPI

    # 显示原始图像
    axes[0].imshow(image)
    axes[0].set_title("Original Image")
    axes[0].axis("off")

    # 显示叠加图像
    axes[1].imshow(image_with_mask)
    axes[1].set_title("Image with Predicted Mask")
    axes[1].axis("off")

    # 保存结果图像
    comparison_filename = os.path.join(output_dir, filename.replace(".jpg", "_comparison.png").replace(".jpeg", "_comparison.png").replace(".png", "_comparison.png"))
    plt.savefig(comparison_filename, dpi=200)  # 保存为高分辨率图像
    plt.close()

    print(f"Saved comparison image for {filename} to {comparison_filename}")

print("所有比较图像已保存！")
# Out:
# Saved comparison image for 09010010055000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010010055000_01_comparison_comparison.png
# Saved comparison image for 09010010055000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010010055000_02_comparison_comparison.png
# Saved comparison image for 09010010055000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09010010055000_03_comparison_comparison.png
# Saved comparison image for 09010010055000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\09010010055000_04_comparison_comparison.png
# Saved comparison image for 09010010055000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09010010055000_05_comparison_comparison.png
# Saved comparison image for 09010010070000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010010070000_02_comparison_comparison.png
# Saved comparison image for 09010010108000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09010010108000_05_comparison_comparison.png
# Saved comparison image for 09010010117000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010010117000_01_comparison_comparison.png
# Saved comparison image for 09010010117000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010010117000_02_comparison_comparison.png
# Saved comparison image for 09010010117000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09010010117000_03_comparison_comparison.png
# Saved comparison image for 09010010119000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010010119000_01_comparison_comparison.png
# Saved comparison image for 09010010119000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09010010119000_03_comparison_comparison.png
# Saved comparison image for 09010010119000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\09010010119000_04_comparison_comparison.png
# Saved comparison image for 09010110005000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010110005000_01_comparison_comparison.png
# Saved comparison image for 09010110005000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010110005000_02_comparison_comparison.png
# Saved comparison image for 09010110005000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09010110005000_03_comparison_comparison.png
# Saved comparison image for 09010110005000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\09010110005000_04_comparison_comparison.png
# Saved comparison image for 09010110005000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09010110005000_05_comparison_comparison.png
# Saved comparison image for 09010110012000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010110012000_02_comparison_comparison.png
# Saved comparison image for 09010200054000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010200054000_01_comparison_comparison.png
# Saved comparison image for 09010200054000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\09010200054000_04_comparison_comparison.png
# Saved comparison image for 09010200055000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010200055000_02_comparison_comparison.png
# Saved comparison image for 09010200055000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09010200055000_03_comparison_comparison.png
# Saved comparison image for 09010200055000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\09010200055000_04_comparison_comparison.png
# Saved comparison image for 09010270029000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010270029000_02_comparison_comparison.png
# Saved comparison image for 09010270029000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09010270029000_03_comparison_comparison.png
# Saved comparison image for 09010270029000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09010270029000_05_comparison_comparison.png
# Saved comparison image for 09010270032000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010270032000_01_comparison_comparison.png
# Saved comparison image for 09010270032000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\09010270032000_04_comparison_comparison.png
# Saved comparison image for 09010270032000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09010270032000_05_comparison_comparison.png
# Saved comparison image for 09010270056000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010270056000_01_comparison_comparison.png
# Saved comparison image for 09010270056000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09010270056000_03_comparison_comparison.png
# Saved comparison image for 09010270056000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\09010270056000_04_comparison_comparison.png
# Saved comparison image for 09010280006000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280006000_01_comparison_comparison.png
# Saved comparison image for 09010280006000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280006000_02_comparison_comparison.png
# Saved comparison image for 09010280006000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280006000_03_comparison_comparison.png
# Saved comparison image for 09010280006000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280006000_04_comparison_comparison.png
# Saved comparison image for 09010280006000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280006000_05_comparison_comparison.png
# Saved comparison image for 09010280019000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280019000_01_comparison_comparison.png
# Saved comparison image for 09010280020000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280020000_01_comparison_comparison.png
# Saved comparison image for 09010280020000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280020000_02_comparison_comparison.png
# Saved comparison image for 09010280032000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280032000_01_comparison_comparison.png
# Saved comparison image for 09010280032000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280032000_02_comparison_comparison.png
# Saved comparison image for 09010280032000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280032000_03_comparison_comparison.png
# Saved comparison image for 09010280032000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280032000_04_comparison_comparison.png
# Saved comparison image for 09010280032000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280032000_05_comparison_comparison.png
# Saved comparison image for 09010280059000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280059000_01_comparison_comparison.png
# Saved comparison image for 09010280059000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280059000_02_comparison_comparison.png
# Saved comparison image for 09010280059000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280059000_03_comparison_comparison.png
# Saved comparison image for 09010280059000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280059000_04_comparison_comparison.png
# Saved comparison image for 09010280059000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280059000_05_comparison_comparison.png
# Saved comparison image for 09010280066000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280066000_03_comparison_comparison.png
# Saved comparison image for 09010280067000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280067000_03_comparison_comparison.png
# Saved comparison image for 09010280067000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280067000_05_comparison_comparison.png
# Saved comparison image for 09010280068000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280068000_01_comparison_comparison.png
# Saved comparison image for 09010280068000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280068000_03_comparison_comparison.png
# Saved comparison image for 09010280068000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280068000_05_comparison_comparison.png
# Saved comparison image for 09010280071000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280071000_05_comparison_comparison.png
# Saved comparison image for 09010280078000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280078000_02_comparison_comparison.png
# Saved comparison image for 09010280080001_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280080001_01_comparison_comparison.png
# Saved comparison image for 09010280080001_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280080001_02_comparison_comparison.png
# Saved comparison image for 09010280080001_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280080001_05_comparison_comparison.png
# Saved comparison image for 09010280082000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280082000_02_comparison_comparison.png
# Saved comparison image for 09010280082000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\09010280082000_04_comparison_comparison.png
# Saved comparison image for 09010370012000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010370012000_01_comparison_comparison.png
# Saved comparison image for 09010370055000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010370055000_02_comparison_comparison.png
# Saved comparison image for 09010370055000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09010370055000_03_comparison_comparison.png
# Saved comparison image for 09010370055000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\09010370055000_04_comparison_comparison.png
# Saved comparison image for 09010370055000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09010370055000_05_comparison_comparison.png
# Saved comparison image for 09010370056000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09010370056000_01_comparison_comparison.png
# Saved comparison image for 09010370056000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09010370056000_02_comparison_comparison.png
# Saved comparison image for 09010370056000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09010370056000_03_comparison_comparison.png
# Saved comparison image for 09030010004000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09030010004000_01_comparison_comparison.png
# Saved comparison image for 09030010004000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09030010004000_02_comparison_comparison.png
# Saved comparison image for 09030010004000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09030010004000_03_comparison_comparison.png
# Saved comparison image for 09030010004000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\09030010004000_04_comparison_comparison.png
# Saved comparison image for 09030010011000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09030010011000_01_comparison_comparison.png
# Saved comparison image for 09030010020000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09030010020000_05_comparison_comparison.png
# Saved comparison image for 09030010052000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09030010052000_01_comparison_comparison.png
# Saved comparison image for 09030010052000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09030010052000_02_comparison_comparison.png
# Saved comparison image for 09030010052000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09030010052000_03_comparison_comparison.png
# Saved comparison image for 09030010052000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\09030010052000_04_comparison_comparison.png
# Saved comparison image for 09030010052000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09030010052000_05_comparison_comparison.png
# Saved comparison image for 09030010061000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09030010061000_01_comparison_comparison.png
# Saved comparison image for 09030010061000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09030010061000_02_comparison_comparison.png
# Saved comparison image for 09030010061000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\09030010061000_03_comparison_comparison.png
# Saved comparison image for 09030010061000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\09030010061000_04_comparison_comparison.png
# Saved comparison image for 09100010014000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\09100010014000_01_comparison_comparison.png
# Saved comparison image for 09100010014000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\09100010014000_02_comparison_comparison.png
# Saved comparison image for 09100010014000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\09100010014000_05_comparison_comparison.png
# Saved comparison image for 11020080008000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\11020080008000_05_comparison_comparison.png
# Saved comparison image for 11020080076000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\11020080076000_04_comparison_comparison.png
# Saved comparison image for 16010030152002_01.jpg to D:/2024/paper2/model/test_comparison/huashu\16010030152002_01_comparison_comparison.png
# Saved comparison image for 16010030152002_02.jpg to D:/2024/paper2/model/test_comparison/huashu\16010030152002_02_comparison_comparison.png
# Saved comparison image for 16010030152002_03.jpg to D:/2024/paper2/model/test_comparison/huashu\16010030152002_03_comparison_comparison.png
# Saved comparison image for 16010030152002_04.jpg to D:/2024/paper2/model/test_comparison/huashu\16010030152002_04_comparison_comparison.png
# Saved comparison image for 16010030152002_05.jpg to D:/2024/paper2/model/test_comparison/huashu\16010030152002_05_comparison_comparison.png
# Saved comparison image for 16010040367001_01.jpg to D:/2024/paper2/model/test_comparison/huashu\16010040367001_01_comparison_comparison.png
# Saved comparison image for 16010040367001_02.jpg to D:/2024/paper2/model/test_comparison/huashu\16010040367001_02_comparison_comparison.png
# Saved comparison image for 16010040367001_03.jpg to D:/2024/paper2/model/test_comparison/huashu\16010040367001_03_comparison_comparison.png
# Saved comparison image for 16010040367001_04.jpg to D:/2024/paper2/model/test_comparison/huashu\16010040367001_04_comparison_comparison.png
# Saved comparison image for 16010040367001_05.jpg to D:/2024/paper2/model/test_comparison/huashu\16010040367001_05_comparison_comparison.png
# Saved comparison image for 16010070007000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\16010070007000_01_comparison_comparison.png
# Saved comparison image for 16010070007000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\16010070007000_02_comparison_comparison.png
# Saved comparison image for 16010070007000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\16010070007000_03_comparison_comparison.png
# Saved comparison image for 16010070007000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\16010070007000_04_comparison_comparison.png
# Saved comparison image for 16010070007000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\16010070007000_05_comparison_comparison.png
# Saved comparison image for 16010090305003_04.jpg to D:/2024/paper2/model/test_comparison/huashu\16010090305003_04_comparison_comparison.png
# Saved comparison image for 16010090305003_05.jpg to D:/2024/paper2/model/test_comparison/huashu\16010090305003_05_comparison_comparison.png
# Saved comparison image for 16010120225000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\16010120225000_01_comparison_comparison.png
# Saved comparison image for 16010120225000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\16010120225000_02_comparison_comparison.png
# Saved comparison image for 16010120225000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\16010120225000_03_comparison_comparison.png
# Saved comparison image for 16010120225000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\16010120225000_04_comparison_comparison.png
# Saved comparison image for 16010120225000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\16010120225000_05_comparison_comparison.png
# Saved comparison image for 16011010030002_01.jpg to D:/2024/paper2/model/test_comparison/huashu\16011010030002_01_comparison_comparison.png
# Saved comparison image for 16011010030002_02.jpg to D:/2024/paper2/model/test_comparison/huashu\16011010030002_02_comparison_comparison.png
# Saved comparison image for 16011010030002_03.jpg to D:/2024/paper2/model/test_comparison/huashu\16011010030002_03_comparison_comparison.png
# Saved comparison image for 16011010030002_04.jpg to D:/2024/paper2/model/test_comparison/huashu\16011010030002_04_comparison_comparison.png
# Saved comparison image for 16011010030002_05.jpg to D:/2024/paper2/model/test_comparison/huashu\16011010030002_05_comparison_comparison.png
# Saved comparison image for 16011020157003_01.jpg to D:/2024/paper2/model/test_comparison/huashu\16011020157003_01_comparison_comparison.png
# Saved comparison image for 16011020157003_02.jpg to D:/2024/paper2/model/test_comparison/huashu\16011020157003_02_comparison_comparison.png
# Saved comparison image for 16011020157003_03.jpg to D:/2024/paper2/model/test_comparison/huashu\16011020157003_03_comparison_comparison.png
# Saved comparison image for 16011020157003_04.jpg to D:/2024/paper2/model/test_comparison/huashu\16011020157003_04_comparison_comparison.png
# Saved comparison image for 16011020157003_05.jpg to D:/2024/paper2/model/test_comparison/huashu\16011020157003_05_comparison_comparison.png
# Saved comparison image for 16015010059000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\16015010059000_02_comparison_comparison.png
# Saved comparison image for 16015010059000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\16015010059000_03_comparison_comparison.png
# Saved comparison image for 16015010160000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\16015010160000_02_comparison_comparison.png
# Saved comparison image for 16015010160000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\16015010160000_03_comparison_comparison.png
# Saved comparison image for 16015010160000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\16015010160000_05_comparison_comparison.png
# Saved comparison image for 16015010262002_01.jpg to D:/2024/paper2/model/test_comparison/huashu\16015010262002_01_comparison_comparison.png
# Saved comparison image for 16015010262002_02.jpg to D:/2024/paper2/model/test_comparison/huashu\16015010262002_02_comparison_comparison.png
# Saved comparison image for 16015010262002_03.jpg to D:/2024/paper2/model/test_comparison/huashu\16015010262002_03_comparison_comparison.png
# Saved comparison image for 16015010262002_04.jpg to D:/2024/paper2/model/test_comparison/huashu\16015010262002_04_comparison_comparison.png
# Saved comparison image for 16015010262002_05.jpg to D:/2024/paper2/model/test_comparison/huashu\16015010262002_05_comparison_comparison.png
# Saved comparison image for 16015010276002_01.jpg to D:/2024/paper2/model/test_comparison/huashu\16015010276002_01_comparison_comparison.png
# Saved comparison image for 16015010276002_02.jpg to D:/2024/paper2/model/test_comparison/huashu\16015010276002_02_comparison_comparison.png
# Saved comparison image for 16015010276002_03.jpg to D:/2024/paper2/model/test_comparison/huashu\16015010276002_03_comparison_comparison.png
# Saved comparison image for 16015010276002_04.jpg to D:/2024/paper2/model/test_comparison/huashu\16015010276002_04_comparison_comparison.png
# Saved comparison image for 16015010276002_05.jpg to D:/2024/paper2/model/test_comparison/huashu\16015010276002_05_comparison_comparison.png
# Saved comparison image for 16020010001000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010001000_01_comparison_comparison.png
# Saved comparison image for 16020010001000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010001000_02_comparison_comparison.png
# Saved comparison image for 16020010001000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010001000_04_comparison_comparison.png
# Saved comparison image for 16020010059001_01.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010059001_01_comparison_comparison.png
# Saved comparison image for 16020010059001_02.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010059001_02_comparison_comparison.png
# Saved comparison image for 16020010059001_03.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010059001_03_comparison_comparison.png
# Saved comparison image for 16020010059001_04.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010059001_04_comparison_comparison.png
# Saved comparison image for 16020010062000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010062000_01_comparison_comparison.png
# Saved comparison image for 16020010062000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010062000_02_comparison_comparison.png
# Saved comparison image for 16020010062000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010062000_04_comparison_comparison.png
# Saved comparison image for 16020010062000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010062000_05_comparison_comparison.png
# Saved comparison image for 16020010074000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010074000_01_comparison_comparison.png
# Saved comparison image for 16020010117000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010117000_01_comparison_comparison.png
# Saved comparison image for 16020010117000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010117000_02_comparison_comparison.png
# Saved comparison image for 16020010117000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010117000_05_comparison_comparison.png
# Saved comparison image for 16020010125000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010125000_01_comparison_comparison.png
# Saved comparison image for 16020010125000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010125000_03_comparison_comparison.png
# Saved comparison image for 16020010134000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010134000_03_comparison_comparison.png
# Saved comparison image for 16020010134000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010134000_04_comparison_comparison.png
# Saved comparison image for 16020010134000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\16020010134000_05_comparison_comparison.png
# Saved comparison image for 16040030024001_01.jpg to D:/2024/paper2/model/test_comparison/huashu\16040030024001_01_comparison_comparison.png
# Saved comparison image for 16040030024001_02.jpg to D:/2024/paper2/model/test_comparison/huashu\16040030024001_02_comparison_comparison.png
# Saved comparison image for 16040030024001_03.jpg to D:/2024/paper2/model/test_comparison/huashu\16040030024001_03_comparison_comparison.png
# Saved comparison image for 16040030024001_04.jpg to D:/2024/paper2/model/test_comparison/huashu\16040030024001_04_comparison_comparison.png
# Saved comparison image for 16040030024001_05.jpg to D:/2024/paper2/model/test_comparison/huashu\16040030024001_05_comparison_comparison.png
# Saved comparison image for 28200070004000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\28200070004000_03_comparison_comparison.png
# Saved comparison image for 28200070004000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\28200070004000_05_comparison_comparison.png
# Saved comparison image for 28200070012000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\28200070012000_02_comparison_comparison.png
# Saved comparison image for 28200070012000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\28200070012000_04_comparison_comparison.png
# Saved comparison image for 28200110003000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110003000_01_comparison_comparison.png
# Saved comparison image for 28200110003000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110003000_02_comparison_comparison.png
# Saved comparison image for 28200110003000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110003000_03_comparison_comparison.png
# Saved comparison image for 28200110003000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110003000_04_comparison_comparison.png
# Saved comparison image for 28200110005000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110005000_01_comparison_comparison.png
# Saved comparison image for 28200110005000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110005000_02_comparison_comparison.png
# Saved comparison image for 28200110005000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110005000_03_comparison_comparison.png
# Saved comparison image for 28200110005000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110005000_04_comparison_comparison.png
# Saved comparison image for 28200110008000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110008000_01_comparison_comparison.png
# Saved comparison image for 28200110008000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110008000_02_comparison_comparison.png
# Saved comparison image for 28200110008000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110008000_03_comparison_comparison.png
# Saved comparison image for 28200110008000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110008000_04_comparison_comparison.png
# Saved comparison image for 28200110008000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110008000_05_comparison_comparison.png
# Saved comparison image for 28200110011000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110011000_01_comparison_comparison.png
# Saved comparison image for 28200110011000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110011000_02_comparison_comparison.png
# Saved comparison image for 28200110011000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110011000_03_comparison_comparison.png
# Saved comparison image for 28200110011000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110011000_04_comparison_comparison.png
# Saved comparison image for 28200110011000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\28200110011000_05_comparison_comparison.png
# Saved comparison image for 29020170063006_01.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170063006_01_comparison_comparison.png
# Saved comparison image for 29020170063006_02.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170063006_02_comparison_comparison.png
# Saved comparison image for 29020170063006_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170063006_03_comparison_comparison.png
# Saved comparison image for 29020170063006_04.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170063006_04_comparison_comparison.png
# Saved comparison image for 29020170063006_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170063006_05_comparison_comparison.png
# Saved comparison image for 29020170065019_02.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170065019_02_comparison_comparison.png
# Saved comparison image for 29020170065019_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170065019_03_comparison_comparison.png
# Saved comparison image for 29020170065019_04.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170065019_04_comparison_comparison.png
# Saved comparison image for 29020170065019_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170065019_05_comparison_comparison.png
# Saved comparison image for 29020170110001_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170110001_03_comparison_comparison.png
# Saved comparison image for 29020170110001_04.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170110001_04_comparison_comparison.png
# Saved comparison image for 29020170110001_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170110001_05_comparison_comparison.png
# Saved comparison image for 29020170131000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170131000_01_comparison_comparison.png
# Saved comparison image for 29020170131000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170131000_02_comparison_comparison.png
# Saved comparison image for 29020170131000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170131000_03_comparison_comparison.png
# Saved comparison image for 29020170131000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170131000_04_comparison_comparison.png
# Saved comparison image for 29020170131000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170131000_05_comparison_comparison.png
# Saved comparison image for 29020170160000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170160000_01_comparison_comparison.png
# Saved comparison image for 29020170160000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170160000_02_comparison_comparison.png
# Saved comparison image for 29020170160000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170160000_03_comparison_comparison.png
# Saved comparison image for 29020170160000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170160000_04_comparison_comparison.png
# Saved comparison image for 29020170160000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170160000_05_comparison_comparison.png
# Saved comparison image for 29020170168003_01.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170168003_01_comparison_comparison.png
# Saved comparison image for 29020170168003_02.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170168003_02_comparison_comparison.png
# Saved comparison image for 29020170168003_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170168003_03_comparison_comparison.png
# Saved comparison image for 29020170168003_04.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170168003_04_comparison_comparison.png
# Saved comparison image for 29020170168003_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170168003_05_comparison_comparison.png
# Saved comparison image for 29020170170000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170170000_01_comparison_comparison.png
# Saved comparison image for 29020170170000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170170000_03_comparison_comparison.png
# Saved comparison image for 29020170170000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170170000_04_comparison_comparison.png
# Saved comparison image for 29020170170000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29020170170000_05_comparison_comparison.png
# Saved comparison image for 29040010005000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\29040010005000_01_comparison_comparison.png
# Saved comparison image for 29040010005000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\29040010005000_02_comparison_comparison.png
# Saved comparison image for 29040010005000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29040010005000_03_comparison_comparison.png
# Saved comparison image for 29040010005000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29040010005000_05_comparison_comparison.png
# Saved comparison image for 29060150077000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\29060150077000_01_comparison_comparison.png
# Saved comparison image for 29060150077000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\29060150077000_02_comparison_comparison.png
# Saved comparison image for 29060150077000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29060150077000_03_comparison_comparison.png
# Saved comparison image for 29060150077000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29060150077000_05_comparison_comparison.png
# Saved comparison image for 29060330025000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\29060330025000_01_comparison_comparison.png
# Saved comparison image for 29060330025000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\29060330025000_02_comparison_comparison.png
# Saved comparison image for 29060330025000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29060330025000_03_comparison_comparison.png
# Saved comparison image for 29060330025000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\29060330025000_04_comparison_comparison.png
# Saved comparison image for 29060330025000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29060330025000_05_comparison_comparison.png
# Saved comparison image for 29080290037000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\29080290037000_01_comparison_comparison.png
# Saved comparison image for 29080290037000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\29080290037000_02_comparison_comparison.png
# Saved comparison image for 29080290037000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29080290037000_03_comparison_comparison.png
# Saved comparison image for 29080290037000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\29080290037000_04_comparison_comparison.png
# Saved comparison image for 29080290037000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29080290037000_05_comparison_comparison.png
# Saved comparison image for 29080290050000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\29080290050000_01_comparison_comparison.png
# Saved comparison image for 29080290050000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\29080290050000_02_comparison_comparison.png
# Saved comparison image for 29080290050000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29080290050000_03_comparison_comparison.png
# Saved comparison image for 29080290050000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\29080290050000_04_comparison_comparison.png
# Saved comparison image for 29080290050000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29080290050000_05_comparison_comparison.png
# Saved comparison image for 29080290061000_01.jpg to D:/2024/paper2/model/test_comparison/huashu\29080290061000_01_comparison_comparison.png
# Saved comparison image for 29080290061000_02.jpg to D:/2024/paper2/model/test_comparison/huashu\29080290061000_02_comparison_comparison.png
# Saved comparison image for 29080290061000_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29080290061000_03_comparison_comparison.png
# Saved comparison image for 29080290061000_04.jpg to D:/2024/paper2/model/test_comparison/huashu\29080290061000_04_comparison_comparison.png
# Saved comparison image for 29080290061000_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29080290061000_05_comparison_comparison.png
# Saved comparison image for 29090010448010_01.jpg to D:/2024/paper2/model/test_comparison/huashu\29090010448010_01_comparison_comparison.png
# Saved comparison image for 29090010448010_02.jpg to D:/2024/paper2/model/test_comparison/huashu\29090010448010_02_comparison_comparison.png
# Saved comparison image for 29090010448010_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29090010448010_03_comparison_comparison.png
# Saved comparison image for 29090010448010_04.jpg to D:/2024/paper2/model/test_comparison/huashu\29090010448010_04_comparison_comparison.png
# Saved comparison image for 29090010448010_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29090010448010_05_comparison_comparison.png
# Saved comparison image for 29090010448014_01.jpg to D:/2024/paper2/model/test_comparison/huashu\29090010448014_01_comparison_comparison.png
# Saved comparison image for 29090010448014_02.jpg to D:/2024/paper2/model/test_comparison/huashu\29090010448014_02_comparison_comparison.png
# Saved comparison image for 29090010448014_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29090010448014_03_comparison_comparison.png
# Saved comparison image for 29090010448014_04.jpg to D:/2024/paper2/model/test_comparison/huashu\29090010448014_04_comparison_comparison.png
# Saved comparison image for 29090010448014_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29090010448014_05_comparison_comparison.png
# Saved comparison image for 29140090057004_01.jpg to D:/2024/paper2/model/test_comparison/huashu\29140090057004_01_comparison_comparison.png
# Saved comparison image for 29140090057004_02.jpg to D:/2024/paper2/model/test_comparison/huashu\29140090057004_02_comparison_comparison.png
# Saved comparison image for 29140090057004_03.jpg to D:/2024/paper2/model/test_comparison/huashu\29140090057004_03_comparison_comparison.png
# Saved comparison image for 29140090057004_04.jpg to D:/2024/paper2/model/test_comparison/huashu\29140090057004_04_comparison_comparison.png
# Saved comparison image for 29140090057004_05.jpg to D:/2024/paper2/model/test_comparison/huashu\29140090057004_05_comparison_comparison.png
# Saved comparison image for D051_03.jpg to D:/2024/paper2/model/test_comparison/huashu\D051_03_comparison_comparison.png
# Saved comparison image for D051_05.jpg to D:/2024/paper2/model/test_comparison/huashu\D051_05_comparison_comparison.png
# Saved comparison image for D052_01.jpg to D:/2024/paper2/model/test_comparison/huashu\D052_01_comparison_comparison.png
# Saved comparison image for D052_05.jpg to D:/2024/paper2/model/test_comparison/huashu\D052_05_comparison_comparison.png
# Saved comparison image for D053_01.jpg to D:/2024/paper2/model/test_comparison/huashu\D053_01_comparison_comparison.png
# Saved comparison image for D053_03.jpg to D:/2024/paper2/model/test_comparison/huashu\D053_03_comparison_comparison.png
# Saved comparison image for D054_01.jpg to D:/2024/paper2/model/test_comparison/huashu\D054_01_comparison_comparison.png
# Saved comparison image for D054_02.jpg to D:/2024/paper2/model/test_comparison/huashu\D054_02_comparison_comparison.png
# Saved comparison image for D054_04.jpg to D:/2024/paper2/model/test_comparison/huashu\D054_04_comparison_comparison.png
# Saved comparison image for D054_05.jpg to D:/2024/paper2/model/test_comparison/huashu\D054_05_comparison_comparison.png
# Saved comparison image for D055_01.jpg to D:/2024/paper2/model/test_comparison/huashu\D055_01_comparison_comparison.png
# Saved comparison image for D055_02.jpg to D:/2024/paper2/model/test_comparison/huashu\D055_02_comparison_comparison.png
# Saved comparison image for D055_03.jpg to D:/2024/paper2/model/test_comparison/huashu\D055_03_comparison_comparison.png
# Saved comparison image for D056_04.jpg to D:/2024/paper2/model/test_comparison/huashu\D056_04_comparison_comparison.png
# Saved comparison image for D056_05.jpg to D:/2024/paper2/model/test_comparison/huashu\D056_05_comparison_comparison.png
# Saved comparison image for D057_02.jpg to D:/2024/paper2/model/test_comparison/huashu\D057_02_comparison_comparison.png
# Saved comparison image for D057_03.jpg to D:/2024/paper2/model/test_comparison/huashu\D057_03_comparison_comparison.png
# Saved comparison image for D057_04.jpg to D:/2024/paper2/model/test_comparison/huashu\D057_04_comparison_comparison.png
# Saved comparison image for D057_05.jpg to D:/2024/paper2/model/test_comparison/huashu\D057_05_comparison_comparison.png
# Saved comparison image for G006_01.jpg to D:/2024/paper2/model/test_comparison/huashu\G006_01_comparison_comparison.png
# Saved comparison image for G006_02.jpg to D:/2024/paper2/model/test_comparison/huashu\G006_02_comparison_comparison.png
# Saved comparison image for G006_03.jpg to D:/2024/paper2/model/test_comparison/huashu\G006_03_comparison_comparison.png
# Saved comparison image for G006_04.jpg to D:/2024/paper2/model/test_comparison/huashu\G006_04_comparison_comparison.png
# 所有比较图像已保存！
