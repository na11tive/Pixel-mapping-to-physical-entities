# %%
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from transformers import SegformerForSemanticSegmentation, SegformerConfig
import os
import numpy as np
from tqdm import tqdm
import json

# 数据集类
class TreeTrunkDataset(Dataset):
    def __init__(self, image_dir, mask_dir, json_dir, transform=None, target_size=(1024, 1024)):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.json_dir = json_dir
        self.transform = transform
        self.target_size = target_size  # 目标尺寸
        self.images = [img for img in os.listdir(image_dir) if img.lower().endswith(('.jpg', '.jpeg', '.png'))]
        self.images = [img for img in self.images if os.path.exists(os.path.join(mask_dir, img.replace(".JPG", ".png").replace(".jpg", ".png").replace(".jpeg", ".png")))]
        self.images = [img for img in self.images if os.path.exists(os.path.join(json_dir, img.replace(".JPG", ".json").replace(".jpg", ".json").replace(".jpeg", ".json")))]

        # 添加调试信息
        if len(self.images) == 0:
            print("未找到匹配的图像、掩码或 JSON 文件，请检查目录和文件扩展名。")
        else:
            print(f"找到 {len(self.images)} 个匹配的图像、掩码和 JSON 文件。")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.images[idx])
        mask_path = os.path.join(self.mask_dir, self.images[idx].replace(".JPG", ".png").replace(".jpg", ".png").replace(".jpeg", ".png"))
        json_path = os.path.join(self.json_dir, self.images[idx].replace(".JPG", ".json").replace(".jpg", ".json").replace(".jpeg", ".json"))
        
        # 读取图像
        image = Image.open(img_path).convert("RGB")  # 使用 Pillow 打开图像
        mask = Image.open(mask_path).convert('L')  # 转换为灰度图像
        mask = np.array(mask)  # 转换为numpy数组
        
        # 读取 JSON 文件
        with open(json_path, 'r') as f:
            json_data = json.load(f)

        # 统一图像和掩码的大小
        image = image.resize(self.target_size)
        mask = Image.fromarray(mask).resize(self.target_size, Image.NEAREST)
        
        # 转换为 Tensor
        if self.transform:
            image = self.transform(image)

        # 确保掩码值在0和1之间
        mask = np.clip(mask, 0, 1)
        mask = torch.tensor(mask, dtype=torch.long)
        
        return image, mask, json_data  # 返回 image, mask 和 json_data

# 自定义 collate_fn，确保每个批次中的数据大小一致
def collate_fn(batch):
    images, masks, json_data = zip(*batch)

    # 将所有图像堆叠成一个批次
    images = torch.stack(images, dim=0)
    
    # 将所有掩码堆叠成一个批次
    masks = torch.stack(masks, dim=0)

    return images, masks

# 设置路径
image_dir = "D:/2024/paper2/model/input_images2/yinxing"
mask_dir = "D:/2024/paper2/model/output_masks/yinxing"
json_dir = "D:/2024/paper2/model/sorted_JSON/yinxing"

# 数据增强与预处理
transform = transforms.Compose([
    transforms.ToTensor(),  # 转换为 Tensor
])

# 数据集和数据加载器
dataset = TreeTrunkDataset(image_dir=image_dir, mask_dir=mask_dir, json_dir=json_dir, transform=transform)

# 检查数据集是否为空
if len(dataset) == 0:
    raise ValueError("数据集为空，请检查图像和掩码文件是否匹配且存在。")

# 使用自定义的 collate_fn 确保每个批次的大小一致
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=collate_fn)

# 初始化模型
config = SegformerConfig()
config.num_labels = 2  # 假设只有背景和前景两类
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SegformerForSemanticSegmentation(config).to(device)

# 定义损失函数和优化器
optimizer = optim.AdamW(model.parameters(), lr=0.0001)

# 自定义中心加权损失
class WeightedCrossEntropyLoss(nn.Module):
    def __init__(self, weight_center=2.0):
        super(WeightedCrossEntropyLoss, self).__init__()
        self.weight_center = weight_center
        self.ce_loss = nn.CrossEntropyLoss(reduction='none')

    def forward(self, inputs, targets):
        # 确保 inputs 和 targets 的维度一致
        if inputs.shape[2:] != targets.shape:
            targets = targets.unsqueeze(1)
            targets = torch.nn.functional.interpolate(targets.float(), size=inputs.shape[2:], mode='nearest').squeeze(1).long()
        
        # 计算基本交叉熵损失
        loss = self.ce_loss(inputs, targets)

        # 中心区域权重：仅对纵向范围中心加权，横向不变
        _, _, h, w = inputs.shape
        y_center, x_center = h // 2, w // 2
        weight_mask = torch.ones_like(targets, dtype=torch.float32)
        weight_mask[y_center - h // 4:y_center + h // 4, :] = self.weight_center  # 仅纵向范围

        # 应用权重
        weighted_loss = loss * weight_mask.to(inputs.device)
        return weighted_loss.mean()

criterion = WeightedCrossEntropyLoss(weight_center=5.0)

# 训练循环
epochs = 130
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    with tqdm(total=len(dataloader), desc=f"Epoch {epoch+1}/{epochs}") as pbar:
        for images, masks in dataloader:  # 加载图像和掩码
            images, masks = images.to(device), masks.to(device)

            # 前向传播
            outputs = model(images).logits
            # 调整输出大小以匹配掩码大小
            outputs = torch.nn.functional.interpolate(outputs, size=(masks.shape[1], masks.shape[2]), mode='bilinear', align_corners=False)

            # 计算损失
            loss = criterion(outputs, masks)

            # 反向传播和优化
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            pbar.update(1)  # 更新 tqdm 进度条
            pbar.set_postfix({"Loss": f"{loss.item():.4f}"})  # 显示当前损失

    print(f"Epoch [{epoch+1}/{epochs}], Loss: {running_loss/len(dataloader):.4f}")

# 保存模型
save_dir = "D:/2024/paper2/model/Model/yinxing"
os.makedirs(save_dir, exist_ok=True)

# 保存完整模型
model_save_path = os.path.join(save_dir, "segformer_full_model.pth")
torch.save(model, model_save_path)
print(f"完整模型已保存到 {model_save_path}")

# 保存模型权重
weights_save_path = os.path.join(save_dir, "segformer_weights.pth")
torch.save(model.state_dict(), weights_save_path)
print(f"模型权重已保存到 {weights_save_path}")


# 保存配置文件
config_save_path = os.path.join(save_dir, "config.json")
config.save_pretrained(save_dir)
print(f"配置文件已保存到 {config_save_path}")

# 保存检查点文件
checkpoint_save_path = os.path.join(save_dir, "checkpoint.pth")
torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "config": config.to_dict(),
    "epoch": epochs,
}, checkpoint_save_path)
print(f"检查点文件已保存到 {checkpoint_save_path}")

print("训练完成并保存所有文件！")
# Out:
# 找到 101 个匹配的图像、掩码和 JSON 文件。
# Epoch 1/130: 100%|██████████| 26/26 [03:20<00:00,  7.72s/it, Loss=0.2734]
# Epoch [1/130], Loss: 0.3708
# Epoch 2/130: 100%|██████████| 26/26 [04:48<00:00, 11.09s/it, Loss=0.2181]
# Epoch [2/130], Loss: 0.2443
# Epoch 3/130: 100%|██████████| 26/26 [04:49<00:00, 11.13s/it, Loss=0.1513]
# Epoch [3/130], Loss: 0.1836
# Epoch 4/130: 100%|██████████| 26/26 [04:36<00:00, 10.65s/it, Loss=0.1798]
# Epoch [4/130], Loss: 0.1542
# Epoch 5/130: 100%|██████████| 26/26 [04:20<00:00, 10.02s/it, Loss=0.1461]
# Epoch [5/130], Loss: 0.1247
# Epoch 6/130: 100%|██████████| 26/26 [05:23<00:00, 12.43s/it, Loss=0.1172]
# Epoch [6/130], Loss: 0.1089
# Epoch 7/130: 100%|██████████| 26/26 [06:38<00:00, 15.31s/it, Loss=0.0887]
# Epoch [7/130], Loss: 0.0944
# Epoch 8/130: 100%|██████████| 26/26 [09:10<00:00, 21.16s/it, Loss=0.1045]
# Epoch [8/130], Loss: 0.0838
# Epoch 9/130: 100%|██████████| 26/26 [07:59<00:00, 18.45s/it, Loss=0.0630]
# Epoch [9/130], Loss: 0.0750
# Epoch 10/130: 100%|██████████| 26/26 [05:20<00:00, 12.33s/it, Loss=0.0615]
# Epoch [10/130], Loss: 0.0711
# Epoch 11/130: 100%|██████████| 26/26 [35:10<00:00, 81.16s/it, Loss=0.0500]
# Epoch [11/130], Loss: 0.0655
# Epoch 12/130: 100%|██████████| 26/26 [09:04<00:00, 20.93s/it, Loss=0.0650]
# Epoch [12/130], Loss: 0.0625
# Epoch 13/130: 100%|██████████| 26/26 [03:54<00:00,  9.03s/it, Loss=0.0617]
# Epoch [13/130], Loss: 0.0602
# Epoch 14/130: 100%|██████████| 26/26 [04:58<00:00, 11.50s/it, Loss=0.0554]
# Epoch [14/130], Loss: 0.0576
# Epoch 15/130: 100%|██████████| 26/26 [04:52<00:00, 11.25s/it, Loss=0.0798]
# Epoch [15/130], Loss: 0.0550
# Epoch 16/130: 100%|██████████| 26/26 [04:58<00:00, 11.48s/it, Loss=0.0455]
# Epoch [16/130], Loss: 0.0524
# Epoch 17/130: 100%|██████████| 26/26 [04:56<00:00, 11.41s/it, Loss=0.0370]
# Epoch [17/130], Loss: 0.0498
# Epoch 18/130: 100%|██████████| 26/26 [05:14<00:00, 12.09s/it, Loss=0.0851]
# Epoch [18/130], Loss: 0.0503
# Epoch 19/130: 100%|██████████| 26/26 [06:11<00:00, 14.30s/it, Loss=0.0638]
# Epoch [19/130], Loss: 0.0479
# Epoch 20/130: 100%|██████████| 26/26 [05:00<00:00, 11.54s/it, Loss=0.0763]
# Epoch [20/130], Loss: 0.0469
# Epoch 21/130: 100%|██████████| 26/26 [04:46<00:00, 11.03s/it, Loss=0.0482]
# Epoch [21/130], Loss: 0.0451
# Epoch 22/130: 100%|██████████| 26/26 [04:42<00:00, 10.85s/it, Loss=0.0558]
# Epoch [22/130], Loss: 0.0434
# Epoch 23/130: 100%|██████████| 26/26 [04:48<00:00, 11.10s/it, Loss=0.0301]
# Epoch [23/130], Loss: 0.0413
# Epoch 24/130: 100%|██████████| 26/26 [04:48<00:00, 11.11s/it, Loss=0.0349]
# Epoch [24/130], Loss: 0.0406
# Epoch 25/130: 100%|██████████| 26/26 [04:47<00:00, 11.04s/it, Loss=0.0567]
# Epoch [25/130], Loss: 0.0408
# Epoch 26/130: 100%|██████████| 26/26 [04:47<00:00, 11.05s/it, Loss=0.0219]
# Epoch [26/130], Loss: 0.0406
# Epoch 27/130: 100%|██████████| 26/26 [04:46<00:00, 11.02s/it, Loss=0.0427]
# Epoch [27/130], Loss: 0.0388
# Epoch 28/130: 100%|██████████| 26/26 [05:29<00:00, 12.69s/it, Loss=0.0681]
# Epoch [28/130], Loss: 0.0378
# Epoch 29/130: 100%|██████████| 26/26 [05:23<00:00, 12.43s/it, Loss=0.0361]
# Epoch [29/130], Loss: 0.0375
# Epoch 30/130: 100%|██████████| 26/26 [05:35<00:00, 12.89s/it, Loss=0.0402]
# Epoch [30/130], Loss: 0.0351
# Epoch 31/130: 100%|██████████| 26/26 [04:48<00:00, 11.09s/it, Loss=0.0288]
# Epoch [31/130], Loss: 0.0342
# Epoch 32/130: 100%|██████████| 26/26 [04:45<00:00, 11.00s/it, Loss=0.0298]
# Epoch [32/130], Loss: 0.0332
# Epoch 33/130: 100%|██████████| 26/26 [05:04<00:00, 11.71s/it, Loss=0.0428]
# Epoch [33/130], Loss: 0.0315
# Epoch 34/130: 100%|██████████| 26/26 [04:53<00:00, 11.28s/it, Loss=0.0238]
# Epoch [34/130], Loss: 0.0324
# Epoch 35/130: 100%|██████████| 26/26 [05:36<00:00, 12.93s/it, Loss=0.0292]
# Epoch [35/130], Loss: 0.0294
# Epoch 36/130: 100%|██████████| 26/26 [06:23<00:00, 14.76s/it, Loss=0.0254]
# Epoch [36/130], Loss: 0.0284
# Epoch 37/130: 100%|██████████| 26/26 [06:36<00:00, 15.23s/it, Loss=0.0294]
# Epoch [37/130], Loss: 0.0284
# Epoch 38/130: 100%|██████████| 26/26 [05:52<00:00, 13.55s/it, Loss=0.0305]
# Epoch [38/130], Loss: 0.0275
# Epoch 39/130: 100%|██████████| 26/26 [06:11<00:00, 14.30s/it, Loss=0.0192]
# Epoch [39/130], Loss: 0.0264
# Epoch 40/130: 100%|██████████| 26/26 [04:58<00:00, 11.48s/it, Loss=0.0272]
# Epoch [40/130], Loss: 0.0250
# Epoch 41/130: 100%|██████████| 26/26 [05:03<00:00, 11.69s/it, Loss=0.0283]
# Epoch [41/130], Loss: 0.0238
# Epoch 42/130: 100%|██████████| 26/26 [05:36<00:00, 12.95s/it, Loss=0.0126]
# Epoch [42/130], Loss: 0.0234
# Epoch 43/130: 100%|██████████| 26/26 [07:08<00:00, 16.50s/it, Loss=0.0290]
# Epoch [43/130], Loss: 0.0227
# Epoch 44/130: 100%|██████████| 26/26 [07:41<00:00, 17.74s/it, Loss=0.0166]
# Epoch [44/130], Loss: 0.0206
# Epoch 45/130: 100%|██████████| 26/26 [04:52<00:00, 11.25s/it, Loss=0.0175]
# Epoch [45/130], Loss: 0.0199
# Epoch 46/130: 100%|██████████| 26/26 [06:46<00:00, 15.65s/it, Loss=0.0236]
# Epoch [46/130], Loss: 0.0196
# Epoch 47/130: 100%|██████████| 26/26 [05:15<00:00, 12.15s/it, Loss=0.0188]
# Epoch [47/130], Loss: 0.0192
# Epoch 48/130: 100%|██████████| 26/26 [04:22<00:00, 10.08s/it, Loss=0.0145]
# Epoch [48/130], Loss: 0.0176
# Epoch 49/130: 100%|██████████| 26/26 [03:58<00:00,  9.16s/it, Loss=0.0213]
# Epoch [49/130], Loss: 0.0181
# Epoch 50/130: 100%|██████████| 26/26 [04:01<00:00,  9.30s/it, Loss=0.0172]
# Epoch [50/130], Loss: 0.0176
# Epoch 51/130: 100%|██████████| 26/26 [04:02<00:00,  9.33s/it, Loss=0.0271]
# Epoch [51/130], Loss: 0.0171
# Epoch 52/130: 100%|██████████| 26/26 [04:14<00:00,  9.80s/it, Loss=0.0198]
# Epoch [52/130], Loss: 0.0158
# Epoch 53/130: 100%|██████████| 26/26 [06:43<00:00, 15.50s/it, Loss=0.0121]
# Epoch [53/130], Loss: 0.0170
# Epoch 54/130: 100%|██████████| 26/26 [05:15<00:00, 12.14s/it, Loss=0.0095]
# Epoch [54/130], Loss: 0.0151
# Epoch 55/130: 100%|██████████| 26/26 [07:58<00:00, 18.41s/it, Loss=0.0148]
# Epoch [55/130], Loss: 0.0139
# Epoch 56/130: 100%|██████████| 26/26 [08:00<00:00, 18.50s/it, Loss=0.0141]
# Epoch [56/130], Loss: 0.0140
# Epoch 57/130: 100%|██████████| 26/26 [06:17<00:00, 14.53s/it, Loss=0.0158]
# Epoch [57/130], Loss: 0.0135
# Epoch 58/130: 100%|██████████| 26/26 [04:43<00:00, 10.92s/it, Loss=0.0095]
# Epoch [58/130], Loss: 0.0136
# Epoch 59/130: 100%|██████████| 26/26 [03:59<00:00,  9.21s/it, Loss=0.0170]
# Epoch [59/130], Loss: 0.0134
# Epoch 60/130: 100%|██████████| 26/26 [03:58<00:00,  9.18s/it, Loss=0.0091]
# Epoch [60/130], Loss: 0.0124
# Epoch 61/130: 100%|██████████| 26/26 [04:07<00:00,  9.52s/it, Loss=0.0085]
# Epoch [61/130], Loss: 0.0124
# Epoch 62/130: 100%|██████████| 26/26 [04:09<00:00,  9.59s/it, Loss=0.0115]
# Epoch [62/130], Loss: 0.0120
# Epoch 63/130: 100%|██████████| 26/26 [04:05<00:00,  9.44s/it, Loss=0.0082]
# Epoch [63/130], Loss: 0.0118
# Epoch 64/130: 100%|██████████| 26/26 [03:58<00:00,  9.19s/it, Loss=0.0131]
# Epoch [64/130], Loss: 0.0115
# Epoch 65/130: 100%|██████████| 26/26 [03:57<00:00,  9.13s/it, Loss=0.0154]
# Epoch [65/130], Loss: 0.0115
# Epoch 66/130: 100%|██████████| 26/26 [03:56<00:00,  9.09s/it, Loss=0.0136]
# Epoch [66/130], Loss: 0.0113
# Epoch 67/130: 100%|██████████| 26/26 [03:58<00:00,  9.17s/it, Loss=0.0159]
# Epoch [67/130], Loss: 0.0112
# Epoch 68/130: 100%|██████████| 26/26 [03:58<00:00,  9.18s/it, Loss=0.0100]
# Epoch [68/130], Loss: 0.0111
# Epoch 69/130: 100%|██████████| 26/26 [04:03<00:00,  9.35s/it, Loss=0.0160]
# Epoch [69/130], Loss: 0.0113
# Epoch 70/130: 100%|██████████| 26/26 [04:02<00:00,  9.34s/it, Loss=0.0119]
# Epoch [70/130], Loss: 0.0113
# Epoch 71/130: 100%|██████████| 26/26 [04:00<00:00,  9.26s/it, Loss=0.0067]
# Epoch [71/130], Loss: 0.0101
# Epoch 72/130: 100%|██████████| 26/26 [04:02<00:00,  9.32s/it, Loss=0.0083]
# Epoch [72/130], Loss: 0.0096
# Epoch 73/130: 100%|██████████| 26/26 [03:56<00:00,  9.11s/it, Loss=0.0064]
# Epoch [73/130], Loss: 0.0097
# Epoch 74/130: 100%|██████████| 26/26 [03:56<00:00,  9.11s/it, Loss=0.0105]
# Epoch [74/130], Loss: 0.0096
# Epoch 75/130: 100%|██████████| 26/26 [03:57<00:00,  9.14s/it, Loss=0.0052]
# Epoch [75/130], Loss: 0.0095
# Epoch 76/130: 100%|██████████| 26/26 [03:54<00:00,  9.03s/it, Loss=0.0107]
# Epoch [76/130], Loss: 0.0087
# Epoch 77/130: 100%|██████████| 26/26 [03:56<00:00,  9.10s/it, Loss=0.0075]
# Epoch [77/130], Loss: 0.0092
# Epoch 78/130: 100%|██████████| 26/26 [03:54<00:00,  9.01s/it, Loss=0.0106]
# Epoch [78/130], Loss: 0.0090
# Epoch 79/130: 100%|██████████| 26/26 [03:54<00:00,  9.02s/it, Loss=0.0054]
# Epoch [79/130], Loss: 0.0087
# Epoch 80/130: 100%|██████████| 26/26 [03:56<00:00,  9.08s/it, Loss=0.0076]
# Epoch [80/130], Loss: 0.0086
# Epoch 81/130: 100%|██████████| 26/26 [03:58<00:00,  9.17s/it, Loss=0.0055]
# Epoch [81/130], Loss: 0.0084
# Epoch 82/130: 100%|██████████| 26/26 [03:57<00:00,  9.13s/it, Loss=0.0062]
# Epoch [82/130], Loss: 0.0083
# Epoch 83/130: 100%|██████████| 26/26 [03:57<00:00,  9.14s/it, Loss=0.0062]
# Epoch [83/130], Loss: 0.0081
# Epoch 84/130: 100%|██████████| 26/26 [04:02<00:00,  9.32s/it, Loss=0.0060]
# Epoch [84/130], Loss: 0.0079
# Epoch 85/130: 100%|██████████| 26/26 [04:01<00:00,  9.28s/it, Loss=0.0068]
# Epoch [85/130], Loss: 0.0088
# Epoch 86/130: 100%|██████████| 26/26 [04:01<00:00,  9.29s/it, Loss=0.0072]
# Epoch [86/130], Loss: 0.0079
# Epoch 87/130: 100%|██████████| 26/26 [03:59<00:00,  9.20s/it, Loss=0.0060]
# Epoch [87/130], Loss: 0.0076
# Epoch 88/130: 100%|██████████| 26/26 [04:02<00:00,  9.34s/it, Loss=0.0054]
# Epoch [88/130], Loss: 0.0072
# Epoch 89/130: 100%|██████████| 26/26 [04:48<00:00, 11.10s/it, Loss=0.0084]
# Epoch [89/130], Loss: 0.0076
# Epoch 90/130: 100%|██████████| 26/26 [06:28<00:00, 14.93s/it, Loss=0.0060]
# Epoch [90/130], Loss: 0.0078
# Epoch 91/130: 100%|██████████| 26/26 [05:12<00:00, 12.00s/it, Loss=0.0064]
# Epoch [91/130], Loss: 0.0076
# Epoch 92/130: 100%|██████████| 26/26 [05:16<00:00, 12.17s/it, Loss=0.0142]
# Epoch [92/130], Loss: 0.0076
# Epoch 93/130: 100%|██████████| 26/26 [05:21<00:00, 12.35s/it, Loss=0.0141]
# Epoch [93/130], Loss: 0.0084
# Epoch 94/130: 100%|██████████| 26/26 [05:20<00:00, 12.31s/it, Loss=0.0061]
# Epoch [94/130], Loss: 0.0080
# Epoch 95/130: 100%|██████████| 26/26 [05:17<00:00, 12.21s/it, Loss=0.0022]
# Epoch [95/130], Loss: 0.0076
# Epoch 96/130: 100%|██████████| 26/26 [04:40<00:00, 10.78s/it, Loss=0.0070]
# Epoch [96/130], Loss: 0.0070
# Epoch 97/130: 100%|██████████| 26/26 [04:02<00:00,  9.34s/it, Loss=0.0102]
# Epoch [97/130], Loss: 0.0068
# Epoch 98/130: 100%|██████████| 26/26 [04:06<00:00,  9.49s/it, Loss=0.0066]
# Epoch [98/130], Loss: 0.0072
# Epoch 99/130: 100%|██████████| 26/26 [04:01<00:00,  9.28s/it, Loss=0.0064]
# Epoch [99/130], Loss: 0.0068
# Epoch 100/130: 100%|██████████| 26/26 [04:01<00:00,  9.27s/it, Loss=0.0063]
# Epoch [100/130], Loss: 0.0066
# Epoch 101/130: 100%|██████████| 26/26 [04:02<00:00,  9.31s/it, Loss=0.0046]
# Epoch [101/130], Loss: 0.0065
# Epoch 102/130: 100%|██████████| 26/26 [04:00<00:00,  9.26s/it, Loss=0.0053]
# Epoch [102/130], Loss: 0.0064
# Epoch 103/130: 100%|██████████| 26/26 [04:01<00:00,  9.27s/it, Loss=0.0066]
# Epoch [103/130], Loss: 0.0061
# Epoch 104/130: 100%|██████████| 26/26 [04:02<00:00,  9.34s/it, Loss=0.0069]
# Epoch [104/130], Loss: 0.0059
# Epoch 105/130: 100%|██████████| 26/26 [04:01<00:00,  9.29s/it, Loss=0.0062]
# Epoch [105/130], Loss: 0.0063
# Epoch 106/130: 100%|██████████| 26/26 [04:02<00:00,  9.34s/it, Loss=0.0069]
# Epoch [106/130], Loss: 0.0064
# Epoch 107/130: 100%|██████████| 26/26 [03:58<00:00,  9.16s/it, Loss=0.0061]
# Epoch [107/130], Loss: 0.0065
# Epoch 108/130: 100%|██████████| 26/26 [03:59<00:00,  9.20s/it, Loss=0.0074]
# Epoch [108/130], Loss: 0.0062
# Epoch 109/130: 100%|██████████| 26/26 [04:08<00:00,  9.55s/it, Loss=0.0060]
# Epoch [109/130], Loss: 0.0060
# Epoch 110/130: 100%|██████████| 26/26 [03:54<00:00,  9.03s/it, Loss=0.0104]
# Epoch [110/130], Loss: 0.0066
# Epoch 111/130: 100%|██████████| 26/26 [04:27<00:00, 10.29s/it, Loss=0.0065]
# Epoch [111/130], Loss: 0.0062
# Epoch 112/130: 100%|██████████| 26/26 [04:56<00:00, 11.40s/it, Loss=0.0044]
# Epoch [112/130], Loss: 0.0059
# Epoch 113/130: 100%|██████████| 26/26 [04:30<00:00, 10.42s/it, Loss=0.0037]
# Epoch [113/130], Loss: 0.0056
# Epoch 114/130: 100%|██████████| 26/26 [04:24<00:00, 10.17s/it, Loss=0.0028]
# Epoch [114/130], Loss: 0.0056
# Epoch 115/130: 100%|██████████| 26/26 [04:51<00:00, 11.21s/it, Loss=0.0058]
# Epoch [115/130], Loss: 0.0061
# Epoch 116/130: 100%|██████████| 26/26 [05:09<00:00, 11.90s/it, Loss=0.0048]
# Epoch [116/130], Loss: 0.0061
# Epoch 117/130: 100%|██████████| 26/26 [05:12<00:00, 12.03s/it, Loss=0.0051]
# Epoch [117/130], Loss: 0.0064
# Epoch 118/130: 100%|██████████| 26/26 [04:52<00:00, 11.25s/it, Loss=0.0058]
# Epoch [118/130], Loss: 0.0057
# Epoch 119/130: 100%|██████████| 26/26 [03:54<00:00,  9.04s/it, Loss=0.0046]
# Epoch [119/130], Loss: 0.0056
# Epoch 120/130: 100%|██████████| 26/26 [03:53<00:00,  8.99s/it, Loss=0.0029]
# Epoch [120/130], Loss: 0.0054
# Epoch 121/130: 100%|██████████| 26/26 [04:05<00:00,  9.46s/it, Loss=0.0069]
# Epoch [121/130], Loss: 0.0054
# Epoch 122/130: 100%|██████████| 26/26 [04:10<00:00,  9.63s/it, Loss=0.0047]
# Epoch [122/130], Loss: 0.0058
# Epoch 123/130: 100%|██████████| 26/26 [04:00<00:00,  9.23s/it, Loss=0.0071]
# Epoch [123/130], Loss: 0.0056
# Epoch 124/130: 100%|██████████| 26/26 [04:02<00:00,  9.34s/it, Loss=0.0075]
# Epoch [124/130], Loss: 0.0066
# Epoch 125/130: 100%|██████████| 26/26 [04:32<00:00, 10.48s/it, Loss=0.0121]
# Epoch [125/130], Loss: 0.0068
# Epoch 126/130: 100%|██████████| 26/26 [05:01<00:00, 11.58s/it, Loss=0.0078]
# Epoch [126/130], Loss: 0.0057
# Epoch 127/130: 100%|██████████| 26/26 [05:21<00:00, 12.35s/it, Loss=0.0047]
# Epoch [127/130], Loss: 0.0055
# Epoch 128/130: 100%|██████████| 26/26 [05:03<00:00, 11.66s/it, Loss=0.0034]
# Epoch [128/130], Loss: 0.0056
# Epoch 129/130: 100%|██████████| 26/26 [05:07<00:00, 11.82s/it, Loss=0.0030]
# Epoch [129/130], Loss: 0.0051
# Epoch 130/130: 100%|██████████| 26/26 [05:20<00:00, 12.32s/it, Loss=0.0048]
# Epoch [130/130], Loss: 0.0052
# 完整模型已保存到 D:/2024/paper2/model/Model/yinxing\segformer_full_model.pth
# 模型权重已保存到 D:/2024/paper2/model/Model/yinxing\segformer_weights.pth
# 配置文件已保存到 D:/2024/paper2/model/Model/yinxing\config.json
# 检查点文件已保存到 D:/2024/paper2/model/Model/yinxing\checkpoint.pth
# 训练完成并保存所有文件！

# %%
import torch
import os
from PIL import Image
from torchvision import transforms
from transformers import SegformerForSemanticSegmentation
import numpy as np

# 设置路径
image_dir = "D:/2024/paper2/model/test/yinxing"  # 验证图像文件夹
output_mask_dir = "D:/2024/paper2/model/test_masks/yinxing"  # 输出掩码文件夹
model_dir = "D:/2024/paper2/model/Model/yinxing"  # 模型文件夹

# 加载完整模型
model_path = os.path.join(model_dir, "segformer_full_model.pth")
model = torch.load(model_path)  # 直接加载完整模型
model.eval()  # 设置为评估模式

# 数据预处理（与训练时相同）
transform = transforms.Compose([
    transforms.ToTensor(),  # 转换为 Tensor
])

# 创建输出文件夹（如果不存在）
os.makedirs(output_mask_dir, exist_ok=True)

# 验证集图像文件名
image_filenames = [f for f in os.listdir(image_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# 推理过程
with torch.no_grad():  # 在推理时不需要计算梯度
    for filename in image_filenames:
        img_path = os.path.join(image_dir, filename)
        
        # 读取图像
        image = Image.open(img_path).convert("RGB")
        
        # 保存原始尺寸
        original_size = image.size
        
        # 统一尺寸（假设训练时输入尺寸是1024x1024）
        target_size = (1024, 1024)  # 如果你的验证图像不是1024x1024，可能需要调整此处
        image_resized = image.resize(target_size)

        # 进行预处理
        image_tensor = transform(image_resized).unsqueeze(0).to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))

        # 模型推理
        outputs = model(image_tensor).logits

        # 获取预测的类别标签（背景=0, 树干=1）
        predicted_mask = torch.argmax(outputs, dim=1).squeeze(0).cpu().numpy().astype(np.uint8)

        # 将输出的掩码转换为 0 和 255（黑色背景，白色树干）
        predicted_mask = predicted_mask * 255  # 0 -> 0, 1 -> 255

        # 将预测掩码调整回原始输入图像的大小
        predicted_mask_resized = Image.fromarray(predicted_mask)
        predicted_mask_resized = predicted_mask_resized.resize(original_size, Image.NEAREST)

        # 保存掩码图像
        mask_filename = os.path.join(output_mask_dir, filename.replace(".jpg", ".png").replace(".jpeg", ".png").replace(".png", ".png"))
        predicted_mask_resized.save(mask_filename)

        print(f"Saved mask for {filename} to {mask_filename}")

print("推理完成，所有掩码已保存！")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20724\607719347.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path)  # 直接加载完整模型
# Saved mask for 01141080016000_02.jpg to D:/2024/paper2/model/test_masks/yinxing\01141080016000_02.png
# Saved mask for 01141080016000_03.jpg to D:/2024/paper2/model/test_masks/yinxing\01141080016000_03.png
# Saved mask for 01161050043000_01.jpg to D:/2024/paper2/model/test_masks/yinxing\01161050043000_01.png
# Saved mask for 01161050043000_03.jpg to D:/2024/paper2/model/test_masks/yinxing\01161050043000_03.png
# Saved mask for 01161050044000_01.jpg to D:/2024/paper2/model/test_masks/yinxing\01161050044000_01.png
# Saved mask for 01161050044000_02.jpg to D:/2024/paper2/model/test_masks/yinxing\01161050044000_02.png
# Saved mask for 01161050044000_04.jpg to D:/2024/paper2/model/test_masks/yinxing\01161050044000_04.png
# Saved mask for 01161050044000_05.jpg to D:/2024/paper2/model/test_masks/yinxing\01161050044000_05.png
# Saved mask for 01169980023000_01.jpg to D:/2024/paper2/model/test_masks/yinxing\01169980023000_01.png
# Saved mask for 01169980023000_02.jpg to D:/2024/paper2/model/test_masks/yinxing\01169980023000_02.png
# Saved mask for 01169980023000_03.jpg to D:/2024/paper2/model/test_masks/yinxing\01169980023000_03.png
# Saved mask for 01169980023000_04.jpg to D:/2024/paper2/model/test_masks/yinxing\01169980023000_04.png
# Saved mask for 01169980023000_05.jpg to D:/2024/paper2/model/test_masks/yinxing\01169980023000_05.png
# Saved mask for 01169980025000_01.jpg to D:/2024/paper2/model/test_masks/yinxing\01169980025000_01.png
# Saved mask for 01169980025000_02.jpg to D:/2024/paper2/model/test_masks/yinxing\01169980025000_02.png
# Saved mask for 01169980025000_04.jpg to D:/2024/paper2/model/test_masks/yinxing\01169980025000_04.png
# Saved mask for 01169980025000_05.jpg to D:/2024/paper2/model/test_masks/yinxing\01169980025000_05.png
# Saved mask for 05442080097000_02.jpg to D:/2024/paper2/model/test_masks/yinxing\05442080097000_02.png
# Saved mask for 05442080097000_03.jpg to D:/2024/paper2/model/test_masks/yinxing\05442080097000_03.png
# Saved mask for 05492020013000_03.jpg to D:/2024/paper2/model/test_masks/yinxing\05492020013000_03.png
# Saved mask for 05492020013000_04.jpg to D:/2024/paper2/model/test_masks/yinxing\05492020013000_04.png
# Saved mask for 05492020013000_05.jpg to D:/2024/paper2/model/test_masks/yinxing\05492020013000_05.png
# Saved mask for 07050080033002_01.jpg to D:/2024/paper2/model/test_masks/yinxing\07050080033002_01.png
# Saved mask for 07050080033002_02.jpg to D:/2024/paper2/model/test_masks/yinxing\07050080033002_02.png
# Saved mask for 07050080033002_03.jpg to D:/2024/paper2/model/test_masks/yinxing\07050080033002_03.png
# Saved mask for 07050080033002_04.jpg to D:/2024/paper2/model/test_masks/yinxing\07050080033002_04.png
# Saved mask for 07050080033002_05.jpg to D:/2024/paper2/model/test_masks/yinxing\07050080033002_05.png
# Saved mask for 11140050030000_01.jpg to D:/2024/paper2/model/test_masks/yinxing\11140050030000_01.png
# Saved mask for 11140050030000_02.jpg to D:/2024/paper2/model/test_masks/yinxing\11140050030000_02.png
# Saved mask for 11140050030000_03.jpg to D:/2024/paper2/model/test_masks/yinxing\11140050030000_03.png
# Saved mask for 11140050030000_04.jpg to D:/2024/paper2/model/test_masks/yinxing\11140050030000_04.png
# Saved mask for 11140050030000_05.jpg to D:/2024/paper2/model/test_masks/yinxing\11140050030000_05.png
# Saved mask for 11200030068000_02.jpg to D:/2024/paper2/model/test_masks/yinxing\11200030068000_02.png
# Saved mask for 11200030105000_01.jpg to D:/2024/paper2/model/test_masks/yinxing\11200030105000_01.png
# Saved mask for 11200030105000_03.jpg to D:/2024/paper2/model/test_masks/yinxing\11200030105000_03.png
# Saved mask for 11220240042000_01.jpg to D:/2024/paper2/model/test_masks/yinxing\11220240042000_01.png
# Saved mask for 12082110035000_03.jpg to D:/2024/paper2/model/test_masks/yinxing\12082110035000_03.png
# Saved mask for 12082440007000_01.jpg to D:/2024/paper2/model/test_masks/yinxing\12082440007000_01.png
# Saved mask for 12082440007000_03.jpg to D:/2024/paper2/model/test_masks/yinxing\12082440007000_03.png
# Saved mask for 12082440007000_04.jpg to D:/2024/paper2/model/test_masks/yinxing\12082440007000_04.png
# Saved mask for 12082440007000_05.jpg to D:/2024/paper2/model/test_masks/yinxing\12082440007000_05.png
# Saved mask for 12142370299000_04.jpg to D:/2024/paper2/model/test_masks/yinxing\12142370299000_04.png
# Saved mask for 13110220066000_01.jpg to D:/2024/paper2/model/test_masks/yinxing\13110220066000_01.png
# Saved mask for 13110220066000_03.jpg to D:/2024/paper2/model/test_masks/yinxing\13110220066000_03.png
# Saved mask for 13110220066000_04.jpg to D:/2024/paper2/model/test_masks/yinxing\13110220066000_04.png
# Saved mask for 13110220257000_01.jpg to D:/2024/paper2/model/test_masks/yinxing\13110220257000_01.png
# Saved mask for 13110220257000_02.jpg to D:/2024/paper2/model/test_masks/yinxing\13110220257000_02.png
# Saved mask for 13110250106000_02.jpg to D:/2024/paper2/model/test_masks/yinxing\13110250106000_02.png
# Saved mask for 13110250106000_03.jpg to D:/2024/paper2/model/test_masks/yinxing\13110250106000_03.png
# Saved mask for 13110250106000_04.jpg to D:/2024/paper2/model/test_masks/yinxing\13110250106000_04.png
# Saved mask for 13110250106000_05.jpg to D:/2024/paper2/model/test_masks/yinxing\13110250106000_05.png
# Saved mask for 14010080034004_01.jpg to D:/2024/paper2/model/test_masks/yinxing\14010080034004_01.png
# Saved mask for 14010080034004_03.jpg to D:/2024/paper2/model/test_masks/yinxing\14010080034004_03.png
# Saved mask for 14010080034004_04.jpg to D:/2024/paper2/model/test_masks/yinxing\14010080034004_04.png
# Saved mask for 14010080034004_05.jpg to D:/2024/paper2/model/test_masks/yinxing\14010080034004_05.png
# Saved mask for 14010080034010_01.jpg to D:/2024/paper2/model/test_masks/yinxing\14010080034010_01.png
# Saved mask for 14010080034010_02.jpg to D:/2024/paper2/model/test_masks/yinxing\14010080034010_02.png
# Saved mask for 14010080034010_03.jpg to D:/2024/paper2/model/test_masks/yinxing\14010080034010_03.png
# Saved mask for 14010080034010_04.jpg to D:/2024/paper2/model/test_masks/yinxing\14010080034010_04.png
# Saved mask for 14010080034010_05.jpg to D:/2024/paper2/model/test_masks/yinxing\14010080034010_05.png
# Saved mask for 14040180056000_01.jpg to D:/2024/paper2/model/test_masks/yinxing\14040180056000_01.png
# Saved mask for 14040180056000_02.jpg to D:/2024/paper2/model/test_masks/yinxing\14040180056000_02.png
# Saved mask for 14040180056000_05.jpg to D:/2024/paper2/model/test_masks/yinxing\14040180056000_05.png
# Saved mask for 14040270101001_01.jpg to D:/2024/paper2/model/test_masks/yinxing\14040270101001_01.png
# Saved mask for 14040270101001_02.jpg to D:/2024/paper2/model/test_masks/yinxing\14040270101001_02.png
# Saved mask for 14040270101001_04.jpg to D:/2024/paper2/model/test_masks/yinxing\14040270101001_04.png
# Saved mask for 14040270101001_05.jpg to D:/2024/paper2/model/test_masks/yinxing\14040270101001_05.png
# Saved mask for 14040270114002_01.jpg to D:/2024/paper2/model/test_masks/yinxing\14040270114002_01.png
# Saved mask for 14040270114002_02.jpg to D:/2024/paper2/model/test_masks/yinxing\14040270114002_02.png
# Saved mask for 14040270114002_03.jpg to D:/2024/paper2/model/test_masks/yinxing\14040270114002_03.png
# Saved mask for 14040270114002_04.jpg to D:/2024/paper2/model/test_masks/yinxing\14040270114002_04.png
# Saved mask for 14040270114002_05.jpg to D:/2024/paper2/model/test_masks/yinxing\14040270114002_05.png
# Saved mask for 14040280064001_01.jpg to D:/2024/paper2/model/test_masks/yinxing\14040280064001_01.png
# Saved mask for 14040280064001_02.jpg to D:/2024/paper2/model/test_masks/yinxing\14040280064001_02.png
# Saved mask for 14040280064001_04.jpg to D:/2024/paper2/model/test_masks/yinxing\14040280064001_04.png
# Saved mask for 14040280064001_05.jpg to D:/2024/paper2/model/test_masks/yinxing\14040280064001_05.png
# Saved mask for 14050040006001_01.jpg to D:/2024/paper2/model/test_masks/yinxing\14050040006001_01.png
# Saved mask for 14050040006001_02.jpg to D:/2024/paper2/model/test_masks/yinxing\14050040006001_02.png
# Saved mask for 14050040006001_03.jpg to D:/2024/paper2/model/test_masks/yinxing\14050040006001_03.png
# Saved mask for 14050040006001_04.jpg to D:/2024/paper2/model/test_masks/yinxing\14050040006001_04.png
# Saved mask for 14050040006001_05.jpg to D:/2024/paper2/model/test_masks/yinxing\14050040006001_05.png
# Saved mask for 14090180092000_03.jpg to D:/2024/paper2/model/test_masks/yinxing\14090180092000_03.png
# Saved mask for 14100090033003_01.jpg to D:/2024/paper2/model/test_masks/yinxing\14100090033003_01.png
# Saved mask for 14100090033003_02.jpg to D:/2024/paper2/model/test_masks/yinxing\14100090033003_02.png
# Saved mask for 14100090033003_03.jpg to D:/2024/paper2/model/test_masks/yinxing\14100090033003_03.png
# Saved mask for 14100090033003_04.jpg to D:/2024/paper2/model/test_masks/yinxing\14100090033003_04.png
# Saved mask for 14100090033003_05.jpg to D:/2024/paper2/model/test_masks/yinxing\14100090033003_05.png
# Saved mask for 14170050098001_01.jpg to D:/2024/paper2/model/test_masks/yinxing\14170050098001_01.png
# Saved mask for 14170050098001_02.jpg to D:/2024/paper2/model/test_masks/yinxing\14170050098001_02.png
# Saved mask for 14170050098001_03.jpg to D:/2024/paper2/model/test_masks/yinxing\14170050098001_03.png
# Saved mask for 14170050098001_04.jpg to D:/2024/paper2/model/test_masks/yinxing\14170050098001_04.png
# Saved mask for 14170050098001_05.jpg to D:/2024/paper2/model/test_masks/yinxing\14170050098001_05.png
# Saved mask for 14170180018003_03.jpg to D:/2024/paper2/model/test_masks/yinxing\14170180018003_03.png
# Saved mask for 15070140078000_01.jpg to D:/2024/paper2/model/test_masks/yinxing\15070140078000_01.png
# Saved mask for 15070140078000_02.jpg to D:/2024/paper2/model/test_masks/yinxing\15070140078000_02.png
# Saved mask for 15070140078000_03.jpg to D:/2024/paper2/model/test_masks/yinxing\15070140078000_03.png
# Saved mask for 15070140078000_04.jpg to D:/2024/paper2/model/test_masks/yinxing\15070140078000_04.png
# Saved mask for 15070140078000_05.jpg to D:/2024/paper2/model/test_masks/yinxing\15070140078000_05.png
# Saved mask for 15110270213000_01.jpg to D:/2024/paper2/model/test_masks/yinxing\15110270213000_01.png
# Saved mask for 15110270216000_04.jpg to D:/2024/paper2/model/test_masks/yinxing\15110270216000_04.png
# Saved mask for 15110270216000_05.jpg to D:/2024/paper2/model/test_masks/yinxing\15110270216000_05.png
# Saved mask for 17090080007001_03.jpg to D:/2024/paper2/model/test_masks/yinxing\17090080007001_03.png
# Saved mask for 17130100021008_01.jpg to D:/2024/paper2/model/test_masks/yinxing\17130100021008_01.png
# Saved mask for 17130100021008_02.jpg to D:/2024/paper2/model/test_masks/yinxing\17130100021008_02.png
# Saved mask for 17130100021008_03.jpg to D:/2024/paper2/model/test_masks/yinxing\17130100021008_03.png
# Saved mask for 17130100021008_04.jpg to D:/2024/paper2/model/test_masks/yinxing\17130100021008_04.png
# Saved mask for 17130100021008_05.jpg to D:/2024/paper2/model/test_masks/yinxing\17130100021008_05.png
# Saved mask for 28080180243003_01.jpg to D:/2024/paper2/model/test_masks/yinxing\28080180243003_01.png
# Saved mask for 28080180243003_02.jpg to D:/2024/paper2/model/test_masks/yinxing\28080180243003_02.png
# Saved mask for 28080180243003_03.jpg to D:/2024/paper2/model/test_masks/yinxing\28080180243003_03.png
# Saved mask for 28080180243003_04.jpg to D:/2024/paper2/model/test_masks/yinxing\28080180243003_04.png
# Saved mask for 28080180243003_05.jpg to D:/2024/paper2/model/test_masks/yinxing\28080180243003_05.png
# Saved mask for 28080180245001_01.jpg to D:/2024/paper2/model/test_masks/yinxing\28080180245001_01.png
# Saved mask for 28080180245001_02.jpg to D:/2024/paper2/model/test_masks/yinxing\28080180245001_02.png
# Saved mask for 28080180245001_03.jpg to D:/2024/paper2/model/test_masks/yinxing\28080180245001_03.png
# Saved mask for 28080180245001_04.jpg to D:/2024/paper2/model/test_masks/yinxing\28080180245001_04.png
# Saved mask for 28080180245001_05.jpg to D:/2024/paper2/model/test_masks/yinxing\28080180245001_05.png
# Saved mask for 28080190042001_01.jpg to D:/2024/paper2/model/test_masks/yinxing\28080190042001_01.png
# Saved mask for 28080190042001_02.jpg to D:/2024/paper2/model/test_masks/yinxing\28080190042001_02.png
# Saved mask for 28080190042001_03.jpg to D:/2024/paper2/model/test_masks/yinxing\28080190042001_03.png
# Saved mask for 28080190042001_04.jpg to D:/2024/paper2/model/test_masks/yinxing\28080190042001_04.png
# Saved mask for 28080190042001_05.jpg to D:/2024/paper2/model/test_masks/yinxing\28080190042001_05.png
# Saved mask for 28080190073008_01.jpg to D:/2024/paper2/model/test_masks/yinxing\28080190073008_01.png
# Saved mask for 28080190073008_02.jpg to D:/2024/paper2/model/test_masks/yinxing\28080190073008_02.png
# Saved mask for 28080190073008_03.jpg to D:/2024/paper2/model/test_masks/yinxing\28080190073008_03.png
# Saved mask for 28080190073008_04.jpg to D:/2024/paper2/model/test_masks/yinxing\28080190073008_04.png
# Saved mask for 28080190073008_05.jpg to D:/2024/paper2/model/test_masks/yinxing\28080190073008_05.png
# Saved mask for 28080320116000_01.jpg to D:/2024/paper2/model/test_masks/yinxing\28080320116000_01.png
# Saved mask for 28080320116000_02.jpg to D:/2024/paper2/model/test_masks/yinxing\28080320116000_02.png
# Saved mask for 28080320116000_03.jpg to D:/2024/paper2/model/test_masks/yinxing\28080320116000_03.png
# Saved mask for 28080320116000_04.jpg to D:/2024/paper2/model/test_masks/yinxing\28080320116000_04.png
# Saved mask for 28080320116000_05.jpg to D:/2024/paper2/model/test_masks/yinxing\28080320116000_05.png
# Saved mask for A024_01.jpg to D:/2024/paper2/model/test_masks/yinxing\A024_01.png
# Saved mask for A024_02.jpg to D:/2024/paper2/model/test_masks/yinxing\A024_02.png
# Saved mask for A024_03.jpg to D:/2024/paper2/model/test_masks/yinxing\A024_03.png
# Saved mask for A024_04.jpg to D:/2024/paper2/model/test_masks/yinxing\A024_04.png
# Saved mask for A024_05.jpg to D:/2024/paper2/model/test_masks/yinxing\A024_05.png
# Saved mask for A025_01.jpg to D:/2024/paper2/model/test_masks/yinxing\A025_01.png
# Saved mask for A025_02.jpg to D:/2024/paper2/model/test_masks/yinxing\A025_02.png
# Saved mask for A025_03.jpg to D:/2024/paper2/model/test_masks/yinxing\A025_03.png
# Saved mask for A025_04.jpg to D:/2024/paper2/model/test_masks/yinxing\A025_04.png
# Saved mask for A025_05.jpg to D:/2024/paper2/model/test_masks/yinxing\A025_05.png
# Saved mask for A026_02.jpg to D:/2024/paper2/model/test_masks/yinxing\A026_02.png
# Saved mask for A027_01.jpg to D:/2024/paper2/model/test_masks/yinxing\A027_01.png
# Saved mask for A027_02.jpg to D:/2024/paper2/model/test_masks/yinxing\A027_02.png
# Saved mask for A027_04.jpg to D:/2024/paper2/model/test_masks/yinxing\A027_04.png
# Saved mask for A027_05.jpg to D:/2024/paper2/model/test_masks/yinxing\A027_05.png
# Saved mask for A028_01.jpg to D:/2024/paper2/model/test_masks/yinxing\A028_01.png
# Saved mask for A028_02.jpg to D:/2024/paper2/model/test_masks/yinxing\A028_02.png
# Saved mask for A028_03.jpg to D:/2024/paper2/model/test_masks/yinxing\A028_03.png
# Saved mask for A028_04.jpg to D:/2024/paper2/model/test_masks/yinxing\A028_04.png
# Saved mask for A028_05.jpg to D:/2024/paper2/model/test_masks/yinxing\A028_05.png
# Saved mask for A031_01.jpg to D:/2024/paper2/model/test_masks/yinxing\A031_01.png
# Saved mask for A031_04.jpg to D:/2024/paper2/model/test_masks/yinxing\A031_04.png
# Saved mask for A032_03.jpg to D:/2024/paper2/model/test_masks/yinxing\A032_03.png
# Saved mask for A033_03.jpg to D:/2024/paper2/model/test_masks/yinxing\A033_03.png
# Saved mask for A033_04.jpg to D:/2024/paper2/model/test_masks/yinxing\A033_04.png
# Saved mask for A033_05.jpg to D:/2024/paper2/model/test_masks/yinxing\A033_05.png
# Saved mask for A039_01.jpg to D:/2024/paper2/model/test_masks/yinxing\A039_01.png
# Saved mask for A039_02.jpg to D:/2024/paper2/model/test_masks/yinxing\A039_02.png
# Saved mask for A039_03.jpg to D:/2024/paper2/model/test_masks/yinxing\A039_03.png
# Saved mask for A039_04.jpg to D:/2024/paper2/model/test_masks/yinxing\A039_04.png
# Saved mask for A039_05.jpg to D:/2024/paper2/model/test_masks/yinxing\A039_05.png
# Saved mask for A040_01.jpg to D:/2024/paper2/model/test_masks/yinxing\A040_01.png
# Saved mask for A040_02.jpg to D:/2024/paper2/model/test_masks/yinxing\A040_02.png
# Saved mask for A040_03.jpg to D:/2024/paper2/model/test_masks/yinxing\A040_03.png
# Saved mask for A040_04.jpg to D:/2024/paper2/model/test_masks/yinxing\A040_04.png
# Saved mask for A041_01.jpg to D:/2024/paper2/model/test_masks/yinxing\A041_01.png
# Saved mask for A041_02.jpg to D:/2024/paper2/model/test_masks/yinxing\A041_02.png
# Saved mask for A041_03.jpg to D:/2024/paper2/model/test_masks/yinxing\A041_03.png
# Saved mask for A041_04.jpg to D:/2024/paper2/model/test_masks/yinxing\A041_04.png
# Saved mask for A041_05.jpg to D:/2024/paper2/model/test_masks/yinxing\A041_05.png
# Saved mask for A042_01.jpg to D:/2024/paper2/model/test_masks/yinxing\A042_01.png
# Saved mask for A042_02.jpg to D:/2024/paper2/model/test_masks/yinxing\A042_02.png
# Saved mask for A042_03.jpg to D:/2024/paper2/model/test_masks/yinxing\A042_03.png
# Saved mask for A042_04.jpg to D:/2024/paper2/model/test_masks/yinxing\A042_04.png
# Saved mask for A042_05.jpg to D:/2024/paper2/model/test_masks/yinxing\A042_05.png
# Saved mask for A043_03.jpg to D:/2024/paper2/model/test_masks/yinxing\A043_03.png
# Saved mask for A043_05.jpg to D:/2024/paper2/model/test_masks/yinxing\A043_05.png
# Saved mask for C062_02.jpg to D:/2024/paper2/model/test_masks/yinxing\C062_02.png
# Saved mask for DC22_01.jpg to D:/2024/paper2/model/test_masks/yinxing\DC22_01.png
# Saved mask for DC22_02.jpg to D:/2024/paper2/model/test_masks/yinxing\DC22_02.png
# Saved mask for DC22_03.jpg to D:/2024/paper2/model/test_masks/yinxing\DC22_03.png
# Saved mask for DC22_04.jpg to D:/2024/paper2/model/test_masks/yinxing\DC22_04.png
# Saved mask for G017_01.jpg to D:/2024/paper2/model/test_masks/yinxing\G017_01.png
# Saved mask for G017_02.jpg to D:/2024/paper2/model/test_masks/yinxing\G017_02.png
# Saved mask for G017_03.jpg to D:/2024/paper2/model/test_masks/yinxing\G017_03.png
# Saved mask for G017_04.jpg to D:/2024/paper2/model/test_masks/yinxing\G017_04.png
# 推理完成，所有掩码已保存！

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# 设置路径
image_dir = "D:/2024/paper2/model/test/yinxing"  # 验证图像文件夹
mask_dir = "D:/2024/paper2/model/test_masks/yinxing"  # 单通道掩码文件夹
output_dir = "D:/2024/paper2/model/test_comparison/yinxing"  # 输出图片文件夹

# 创建输出文件夹（如果不存在）
os.makedirs(output_dir, exist_ok=True)

# 获取图像文件名
image_filenames = [f for f in os.listdir(image_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# 处理每个图像
for filename in image_filenames:
    # 构造图像路径和掩码路径
    img_path = os.path.join(image_dir, filename)
    mask_path = os.path.join(mask_dir, filename.replace(".jpg", ".png").replace(".jpeg", ".png").replace(".png", ".png"))

    # 读取验证图像和掩码图像
    image = Image.open(img_path).convert("RGB")  # 读取并转换为 RGB 图像
    mask = Image.open(mask_path).convert("L")  # 读取掩码并转换为灰度图像（L 模式）

    # 将掩码图像转换为 numpy 数组（0 表示背景，255 表示树干）
    mask_array = np.array(mask)

    # 将掩码值转换为 0 或 1（0 -> 背景，1 -> 树干）
    mask_binary = (mask_array > 127).astype(int)  # 将大于127的像素值转为 1，小于等于127的为 0

    # 将原始图像和掩码图像叠加
    image_array = np.array(image)

    # 使用掩码区域将原始图像覆盖成不同的颜色（比如将树干区域用红色标出）
    # 红色区域表示模型预测的树干区域
    image_with_mask = image_array.copy()
    image_with_mask[mask_binary == 1] = [255, 0, 0]  # 将树干区域标记为红色 [255, 0, 0]

    # 将原始图像与掩码图像并排显示
    # 设置高分辨率图像
    fig, axes = plt.subplots(1, 2, figsize=(16, 8), dpi=200)  # 设置更大的图像大小和更高的 DPI

    # 显示原始图像
    axes[0].imshow(image)
    axes[0].set_title("Original Image")
    axes[0].axis("off")

    # 显示叠加图像
    axes[1].imshow(image_with_mask)
    axes[1].set_title("Image with Predicted Mask")
    axes[1].axis("off")

    # 保存结果图像
    comparison_filename = os.path.join(output_dir, filename.replace(".jpg", "_comparison.png").replace(".jpeg", "_comparison.png").replace(".png", "_comparison.png"))
    plt.savefig(comparison_filename, dpi=200)  # 保存为高分辨率图像
    plt.close()

    print(f"Saved comparison image for {filename} to {comparison_filename}")

print("所有比较图像已保存！")
# Out:
# Saved comparison image for 01141080016000_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\01141080016000_02_comparison_comparison.png
# Saved comparison image for 01141080016000_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\01141080016000_03_comparison_comparison.png
# Saved comparison image for 01161050043000_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\01161050043000_01_comparison_comparison.png
# Saved comparison image for 01161050043000_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\01161050043000_03_comparison_comparison.png
# Saved comparison image for 01161050044000_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\01161050044000_01_comparison_comparison.png
# Saved comparison image for 01161050044000_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\01161050044000_02_comparison_comparison.png
# Saved comparison image for 01161050044000_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\01161050044000_04_comparison_comparison.png
# Saved comparison image for 01161050044000_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\01161050044000_05_comparison_comparison.png
# Saved comparison image for 01169980023000_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\01169980023000_01_comparison_comparison.png
# Saved comparison image for 01169980023000_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\01169980023000_02_comparison_comparison.png
# Saved comparison image for 01169980023000_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\01169980023000_03_comparison_comparison.png
# Saved comparison image for 01169980023000_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\01169980023000_04_comparison_comparison.png
# Saved comparison image for 01169980023000_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\01169980023000_05_comparison_comparison.png
# Saved comparison image for 01169980025000_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\01169980025000_01_comparison_comparison.png
# Saved comparison image for 01169980025000_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\01169980025000_02_comparison_comparison.png
# Saved comparison image for 01169980025000_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\01169980025000_04_comparison_comparison.png
# Saved comparison image for 01169980025000_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\01169980025000_05_comparison_comparison.png
# Saved comparison image for 05442080097000_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\05442080097000_02_comparison_comparison.png
# Saved comparison image for 05442080097000_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\05442080097000_03_comparison_comparison.png
# Saved comparison image for 05492020013000_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\05492020013000_03_comparison_comparison.png
# Saved comparison image for 05492020013000_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\05492020013000_04_comparison_comparison.png
# Saved comparison image for 05492020013000_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\05492020013000_05_comparison_comparison.png
# Saved comparison image for 07050080033002_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\07050080033002_01_comparison_comparison.png
# Saved comparison image for 07050080033002_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\07050080033002_02_comparison_comparison.png
# Saved comparison image for 07050080033002_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\07050080033002_03_comparison_comparison.png
# Saved comparison image for 07050080033002_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\07050080033002_04_comparison_comparison.png
# Saved comparison image for 07050080033002_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\07050080033002_05_comparison_comparison.png
# Saved comparison image for 11140050030000_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\11140050030000_01_comparison_comparison.png
# Saved comparison image for 11140050030000_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\11140050030000_02_comparison_comparison.png
# Saved comparison image for 11140050030000_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\11140050030000_03_comparison_comparison.png
# Saved comparison image for 11140050030000_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\11140050030000_04_comparison_comparison.png
# Saved comparison image for 11140050030000_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\11140050030000_05_comparison_comparison.png
# Saved comparison image for 11200030068000_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\11200030068000_02_comparison_comparison.png
# Saved comparison image for 11200030105000_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\11200030105000_01_comparison_comparison.png
# Saved comparison image for 11200030105000_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\11200030105000_03_comparison_comparison.png
# Saved comparison image for 11220240042000_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\11220240042000_01_comparison_comparison.png
# Saved comparison image for 12082110035000_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\12082110035000_03_comparison_comparison.png
# Saved comparison image for 12082440007000_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\12082440007000_01_comparison_comparison.png
# Saved comparison image for 12082440007000_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\12082440007000_03_comparison_comparison.png
# Saved comparison image for 12082440007000_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\12082440007000_04_comparison_comparison.png
# Saved comparison image for 12082440007000_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\12082440007000_05_comparison_comparison.png
# Saved comparison image for 12142370299000_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\12142370299000_04_comparison_comparison.png
# Saved comparison image for 13110220066000_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\13110220066000_01_comparison_comparison.png
# Saved comparison image for 13110220066000_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\13110220066000_03_comparison_comparison.png
# Saved comparison image for 13110220066000_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\13110220066000_04_comparison_comparison.png
# Saved comparison image for 13110220257000_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\13110220257000_01_comparison_comparison.png
# Saved comparison image for 13110220257000_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\13110220257000_02_comparison_comparison.png
# Saved comparison image for 13110250106000_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\13110250106000_02_comparison_comparison.png
# Saved comparison image for 13110250106000_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\13110250106000_03_comparison_comparison.png
# Saved comparison image for 13110250106000_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\13110250106000_04_comparison_comparison.png
# Saved comparison image for 13110250106000_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\13110250106000_05_comparison_comparison.png
# Saved comparison image for 14010080034004_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\14010080034004_01_comparison_comparison.png
# Saved comparison image for 14010080034004_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\14010080034004_03_comparison_comparison.png
# Saved comparison image for 14010080034004_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\14010080034004_04_comparison_comparison.png
# Saved comparison image for 14010080034004_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\14010080034004_05_comparison_comparison.png
# Saved comparison image for 14010080034010_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\14010080034010_01_comparison_comparison.png
# Saved comparison image for 14010080034010_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\14010080034010_02_comparison_comparison.png
# Saved comparison image for 14010080034010_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\14010080034010_03_comparison_comparison.png
# Saved comparison image for 14010080034010_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\14010080034010_04_comparison_comparison.png
# Saved comparison image for 14010080034010_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\14010080034010_05_comparison_comparison.png
# Saved comparison image for 14040180056000_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040180056000_01_comparison_comparison.png
# Saved comparison image for 14040180056000_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040180056000_02_comparison_comparison.png
# Saved comparison image for 14040180056000_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040180056000_05_comparison_comparison.png
# Saved comparison image for 14040270101001_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040270101001_01_comparison_comparison.png
# Saved comparison image for 14040270101001_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040270101001_02_comparison_comparison.png
# Saved comparison image for 14040270101001_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040270101001_04_comparison_comparison.png
# Saved comparison image for 14040270101001_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040270101001_05_comparison_comparison.png
# Saved comparison image for 14040270114002_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040270114002_01_comparison_comparison.png
# Saved comparison image for 14040270114002_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040270114002_02_comparison_comparison.png
# Saved comparison image for 14040270114002_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040270114002_03_comparison_comparison.png
# Saved comparison image for 14040270114002_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040270114002_04_comparison_comparison.png
# Saved comparison image for 14040270114002_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040270114002_05_comparison_comparison.png
# Saved comparison image for 14040280064001_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040280064001_01_comparison_comparison.png
# Saved comparison image for 14040280064001_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040280064001_02_comparison_comparison.png
# Saved comparison image for 14040280064001_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040280064001_04_comparison_comparison.png
# Saved comparison image for 14040280064001_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\14040280064001_05_comparison_comparison.png
# Saved comparison image for 14050040006001_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\14050040006001_01_comparison_comparison.png
# Saved comparison image for 14050040006001_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\14050040006001_02_comparison_comparison.png
# Saved comparison image for 14050040006001_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\14050040006001_03_comparison_comparison.png
# Saved comparison image for 14050040006001_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\14050040006001_04_comparison_comparison.png
# Saved comparison image for 14050040006001_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\14050040006001_05_comparison_comparison.png
# Saved comparison image for 14090180092000_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\14090180092000_03_comparison_comparison.png
# Saved comparison image for 14100090033003_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\14100090033003_01_comparison_comparison.png
# Saved comparison image for 14100090033003_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\14100090033003_02_comparison_comparison.png
# Saved comparison image for 14100090033003_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\14100090033003_03_comparison_comparison.png
# Saved comparison image for 14100090033003_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\14100090033003_04_comparison_comparison.png
# Saved comparison image for 14100090033003_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\14100090033003_05_comparison_comparison.png
# Saved comparison image for 14170050098001_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\14170050098001_01_comparison_comparison.png
# Saved comparison image for 14170050098001_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\14170050098001_02_comparison_comparison.png
# Saved comparison image for 14170050098001_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\14170050098001_03_comparison_comparison.png
# Saved comparison image for 14170050098001_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\14170050098001_04_comparison_comparison.png
# Saved comparison image for 14170050098001_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\14170050098001_05_comparison_comparison.png
# Saved comparison image for 14170180018003_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\14170180018003_03_comparison_comparison.png
# Saved comparison image for 15070140078000_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\15070140078000_01_comparison_comparison.png
# Saved comparison image for 15070140078000_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\15070140078000_02_comparison_comparison.png
# Saved comparison image for 15070140078000_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\15070140078000_03_comparison_comparison.png
# Saved comparison image for 15070140078000_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\15070140078000_04_comparison_comparison.png
# Saved comparison image for 15070140078000_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\15070140078000_05_comparison_comparison.png
# Saved comparison image for 15110270213000_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\15110270213000_01_comparison_comparison.png
# Saved comparison image for 15110270216000_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\15110270216000_04_comparison_comparison.png
# Saved comparison image for 15110270216000_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\15110270216000_05_comparison_comparison.png
# Saved comparison image for 17090080007001_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\17090080007001_03_comparison_comparison.png
# Saved comparison image for 17130100021008_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\17130100021008_01_comparison_comparison.png
# Saved comparison image for 17130100021008_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\17130100021008_02_comparison_comparison.png
# Saved comparison image for 17130100021008_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\17130100021008_03_comparison_comparison.png
# Saved comparison image for 17130100021008_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\17130100021008_04_comparison_comparison.png
# Saved comparison image for 17130100021008_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\17130100021008_05_comparison_comparison.png
# Saved comparison image for 28080180243003_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080180243003_01_comparison_comparison.png
# Saved comparison image for 28080180243003_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080180243003_02_comparison_comparison.png
# Saved comparison image for 28080180243003_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080180243003_03_comparison_comparison.png
# Saved comparison image for 28080180243003_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080180243003_04_comparison_comparison.png
# Saved comparison image for 28080180243003_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080180243003_05_comparison_comparison.png
# Saved comparison image for 28080180245001_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080180245001_01_comparison_comparison.png
# Saved comparison image for 28080180245001_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080180245001_02_comparison_comparison.png
# Saved comparison image for 28080180245001_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080180245001_03_comparison_comparison.png
# Saved comparison image for 28080180245001_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080180245001_04_comparison_comparison.png
# Saved comparison image for 28080180245001_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080180245001_05_comparison_comparison.png
# Saved comparison image for 28080190042001_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080190042001_01_comparison_comparison.png
# Saved comparison image for 28080190042001_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080190042001_02_comparison_comparison.png
# Saved comparison image for 28080190042001_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080190042001_03_comparison_comparison.png
# Saved comparison image for 28080190042001_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080190042001_04_comparison_comparison.png
# Saved comparison image for 28080190042001_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080190042001_05_comparison_comparison.png
# Saved comparison image for 28080190073008_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080190073008_01_comparison_comparison.png
# Saved comparison image for 28080190073008_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080190073008_02_comparison_comparison.png
# Saved comparison image for 28080190073008_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080190073008_03_comparison_comparison.png
# Saved comparison image for 28080190073008_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080190073008_04_comparison_comparison.png
# Saved comparison image for 28080190073008_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080190073008_05_comparison_comparison.png
# Saved comparison image for 28080320116000_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080320116000_01_comparison_comparison.png
# Saved comparison image for 28080320116000_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080320116000_02_comparison_comparison.png
# Saved comparison image for 28080320116000_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080320116000_03_comparison_comparison.png
# Saved comparison image for 28080320116000_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080320116000_04_comparison_comparison.png
# Saved comparison image for 28080320116000_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\28080320116000_05_comparison_comparison.png
# Saved comparison image for A024_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\A024_01_comparison_comparison.png
# Saved comparison image for A024_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\A024_02_comparison_comparison.png
# Saved comparison image for A024_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\A024_03_comparison_comparison.png
# Saved comparison image for A024_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\A024_04_comparison_comparison.png
# Saved comparison image for A024_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\A024_05_comparison_comparison.png
# Saved comparison image for A025_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\A025_01_comparison_comparison.png
# Saved comparison image for A025_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\A025_02_comparison_comparison.png
# Saved comparison image for A025_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\A025_03_comparison_comparison.png
# Saved comparison image for A025_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\A025_04_comparison_comparison.png
# Saved comparison image for A025_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\A025_05_comparison_comparison.png
# Saved comparison image for A026_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\A026_02_comparison_comparison.png
# Saved comparison image for A027_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\A027_01_comparison_comparison.png
# Saved comparison image for A027_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\A027_02_comparison_comparison.png
# Saved comparison image for A027_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\A027_04_comparison_comparison.png
# Saved comparison image for A027_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\A027_05_comparison_comparison.png
# Saved comparison image for A028_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\A028_01_comparison_comparison.png
# Saved comparison image for A028_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\A028_02_comparison_comparison.png
# Saved comparison image for A028_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\A028_03_comparison_comparison.png
# Saved comparison image for A028_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\A028_04_comparison_comparison.png
# Saved comparison image for A028_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\A028_05_comparison_comparison.png
# Saved comparison image for A031_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\A031_01_comparison_comparison.png
# Saved comparison image for A031_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\A031_04_comparison_comparison.png
# Saved comparison image for A032_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\A032_03_comparison_comparison.png
# Saved comparison image for A033_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\A033_03_comparison_comparison.png
# Saved comparison image for A033_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\A033_04_comparison_comparison.png
# Saved comparison image for A033_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\A033_05_comparison_comparison.png
# Saved comparison image for A039_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\A039_01_comparison_comparison.png
# Saved comparison image for A039_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\A039_02_comparison_comparison.png
# Saved comparison image for A039_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\A039_03_comparison_comparison.png
# Saved comparison image for A039_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\A039_04_comparison_comparison.png
# Saved comparison image for A039_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\A039_05_comparison_comparison.png
# Saved comparison image for A040_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\A040_01_comparison_comparison.png
# Saved comparison image for A040_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\A040_02_comparison_comparison.png
# Saved comparison image for A040_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\A040_03_comparison_comparison.png
# Saved comparison image for A040_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\A040_04_comparison_comparison.png
# Saved comparison image for A041_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\A041_01_comparison_comparison.png
# Saved comparison image for A041_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\A041_02_comparison_comparison.png
# Saved comparison image for A041_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\A041_03_comparison_comparison.png
# Saved comparison image for A041_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\A041_04_comparison_comparison.png
# Saved comparison image for A041_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\A041_05_comparison_comparison.png
# Saved comparison image for A042_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\A042_01_comparison_comparison.png
# Saved comparison image for A042_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\A042_02_comparison_comparison.png
# Saved comparison image for A042_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\A042_03_comparison_comparison.png
# Saved comparison image for A042_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\A042_04_comparison_comparison.png
# Saved comparison image for A042_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\A042_05_comparison_comparison.png
# Saved comparison image for A043_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\A043_03_comparison_comparison.png
# Saved comparison image for A043_05.jpg to D:/2024/paper2/model/test_comparison/yinxing\A043_05_comparison_comparison.png
# Saved comparison image for C062_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\C062_02_comparison_comparison.png
# Saved comparison image for DC22_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\DC22_01_comparison_comparison.png
# Saved comparison image for DC22_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\DC22_02_comparison_comparison.png
# Saved comparison image for DC22_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\DC22_03_comparison_comparison.png
# Saved comparison image for DC22_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\DC22_04_comparison_comparison.png
# Saved comparison image for G017_01.jpg to D:/2024/paper2/model/test_comparison/yinxing\G017_01_comparison_comparison.png
# Saved comparison image for G017_02.jpg to D:/2024/paper2/model/test_comparison/yinxing\G017_02_comparison_comparison.png
# Saved comparison image for G017_03.jpg to D:/2024/paper2/model/test_comparison/yinxing\G017_03_comparison_comparison.png
# Saved comparison image for G017_04.jpg to D:/2024/paper2/model/test_comparison/yinxing\G017_04_comparison_comparison.png
# 所有比较图像已保存！
