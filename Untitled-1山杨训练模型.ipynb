# %%
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from transformers import SegformerForSemanticSegmentation, SegformerConfig
import os
import numpy as np
from tqdm import tqdm
import json

# 数据集类
class TreeTrunkDataset(Dataset):
    def __init__(self, image_dir, mask_dir, json_dir, transform=None, target_size=(1024, 1024)):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.json_dir = json_dir
        self.transform = transform
        self.target_size = target_size  # 目标尺寸
        self.images = [img for img in os.listdir(image_dir) if img.lower().endswith(('.jpg', '.jpeg', '.png'))]
        self.images = [img for img in self.images if os.path.exists(os.path.join(mask_dir, img.replace(".JPG", ".png").replace(".jpg", ".png").replace(".jpeg", ".png")))]
        self.images = [img for img in self.images if os.path.exists(os.path.join(json_dir, img.replace(".JPG", ".json").replace(".jpg", ".json").replace(".jpeg", ".json")))]

        # 添加调试信息
        if len(self.images) == 0:
            print("未找到匹配的图像、掩码或 JSON 文件，请检查目录和文件扩展名。")
        else:
            print(f"找到 {len(self.images)} 个匹配的图像、掩码和 JSON 文件。")

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.images[idx])
        mask_path = os.path.join(self.mask_dir, self.images[idx].replace(".JPG", ".png").replace(".jpg", ".png").replace(".jpeg", ".png"))
        json_path = os.path.join(self.json_dir, self.images[idx].replace(".JPG", ".json").replace(".jpg", ".json").replace(".jpeg", ".json"))
        
        # 读取图像
        image = Image.open(img_path).convert("RGB")  # 使用 Pillow 打开图像
        mask = Image.open(mask_path).convert('L')  # 转换为灰度图像
        mask = np.array(mask)  # 转换为numpy数组
        
        # 读取 JSON 文件
        with open(json_path, 'r') as f:
            json_data = json.load(f)

        # 统一图像和掩码的大小
        image = image.resize(self.target_size)
        mask = Image.fromarray(mask).resize(self.target_size, Image.NEAREST)
        
        # 转换为 Tensor
        if self.transform:
            image = self.transform(image)

        # 确保掩码值在0和1之间
        mask = np.clip(mask, 0, 1)
        mask = torch.tensor(mask, dtype=torch.long)
        
        return image, mask, json_data  # 返回 image, mask 和 json_data

# 自定义 collate_fn，确保每个批次中的数据大小一致
def collate_fn(batch):
    images, masks, json_data = zip(*batch)

    # 将所有图像堆叠成一个批次
    images = torch.stack(images, dim=0)
    
    # 将所有掩码堆叠成一个批次
    masks = torch.stack(masks, dim=0)

    return images, masks

# 设置路径
image_dir = "D:/2024/paper2/model/input_images2/shanyang"
mask_dir = "D:/2024/paper2/model/output_masks/shanyang"
json_dir = "D:/2024/paper2/model/sorted_JSON/shanyang"

# 数据增强与预处理
transform = transforms.Compose([
    transforms.ToTensor(),  # 转换为 Tensor
])

# 数据集和数据加载器
dataset = TreeTrunkDataset(image_dir=image_dir, mask_dir=mask_dir, json_dir=json_dir, transform=transform)

# 检查数据集是否为空
if len(dataset) == 0:
    raise ValueError("数据集为空，请检查图像和掩码文件是否匹配且存在。")

# 使用自定义的 collate_fn 确保每个批次的大小一致
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=collate_fn)

# 初始化模型
config = SegformerConfig()
config.num_labels = 2  # 假设只有背景和前景两类
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SegformerForSemanticSegmentation(config).to(device)

# 定义损失函数和优化器
optimizer = optim.AdamW(model.parameters(), lr=0.0001)

# 自定义中心加权损失
class WeightedCrossEntropyLoss(nn.Module):
    def __init__(self, weight_center=2.0):
        super(WeightedCrossEntropyLoss, self).__init__()
        self.weight_center = weight_center
        self.ce_loss = nn.CrossEntropyLoss(reduction='none')

    def forward(self, inputs, targets):
        # 确保 inputs 和 targets 的维度一致
        if inputs.shape[2:] != targets.shape:
            targets = targets.unsqueeze(1)
            targets = torch.nn.functional.interpolate(targets.float(), size=inputs.shape[2:], mode='nearest').squeeze(1).long()
        
        # 计算基本交叉熵损失
        loss = self.ce_loss(inputs, targets)

        # 中心区域权重：仅对纵向范围中心加权，横向不变
        _, _, h, w = inputs.shape
        y_center, x_center = h // 2, w // 2
        weight_mask = torch.ones_like(targets, dtype=torch.float32)
        weight_mask[y_center - h // 4:y_center + h // 4, :] = self.weight_center  # 仅纵向范围

        # 应用权重
        weighted_loss = loss * weight_mask.to(inputs.device)
        return weighted_loss.mean()

criterion = WeightedCrossEntropyLoss(weight_center=5.0)

# 训练循环
epochs = 150
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    with tqdm(total=len(dataloader), desc=f"Epoch {epoch+1}/{epochs}") as pbar:
        for images, masks in dataloader:  # 加载图像和掩码
            images, masks = images.to(device), masks.to(device)

            # 前向传播
            outputs = model(images).logits
            # 调整输出大小以匹配掩码大小
            outputs = torch.nn.functional.interpolate(outputs, size=(masks.shape[1], masks.shape[2]), mode='bilinear', align_corners=False)

            # 计算损失
            loss = criterion(outputs, masks)

            # 反向传播和优化
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            pbar.update(1)  # 更新 tqdm 进度条
            pbar.set_postfix({"Loss": f"{loss.item():.4f}"})  # 显示当前损失

    print(f"Epoch [{epoch+1}/{epochs}], Loss: {running_loss/len(dataloader):.4f}")

# 保存模型
save_dir = "D:/2024/paper2/model/Model/shanyang"
os.makedirs(save_dir, exist_ok=True)

# 保存完整模型
model_save_path = os.path.join(save_dir, "segformer_full_model.pth")
torch.save(model, model_save_path)
print(f"完整模型已保存到 {model_save_path}")

# 保存模型权重
weights_save_path = os.path.join(save_dir, "segformer_weights.pth")
torch.save(model.state_dict(), weights_save_path)
print(f"模型权重已保存到 {weights_save_path}")


# 保存配置文件
config_save_path = os.path.join(save_dir, "config.json")
config.save_pretrained(save_dir)
print(f"配置文件已保存到 {config_save_path}")

# 保存检查点文件
checkpoint_save_path = os.path.join(save_dir, "checkpoint.pth")
torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "config": config.to_dict(),
    "epoch": epochs,
}, checkpoint_save_path)
print(f"检查点文件已保存到 {checkpoint_save_path}")

print("训练完成并保存所有文件！")
# Out:
# 找到 43 个匹配的图像、掩码和 JSON 文件。
# Epoch 1/150: 100%|██████████| 11/11 [02:12<00:00, 12.06s/it, Loss=0.3677]
# Epoch [1/150], Loss: 0.4608
# Epoch 2/150: 100%|██████████| 11/11 [01:48<00:00,  9.91s/it, Loss=0.3135]
# Epoch [2/150], Loss: 0.3352
# Epoch 3/150: 100%|██████████| 11/11 [01:48<00:00,  9.85s/it, Loss=0.2677]
# Epoch [3/150], Loss: 0.2874
# Epoch 4/150: 100%|██████████| 11/11 [01:38<00:00,  8.94s/it, Loss=0.2524]
# Epoch [4/150], Loss: 0.2561
# Epoch 5/150: 100%|██████████| 11/11 [01:46<00:00,  9.72s/it, Loss=0.2014]
# Epoch [5/150], Loss: 0.2257
# Epoch 6/150: 100%|██████████| 11/11 [01:38<00:00,  8.92s/it, Loss=0.2114]
# Epoch [6/150], Loss: 0.2070
# Epoch 7/150: 100%|██████████| 11/11 [01:46<00:00,  9.67s/it, Loss=0.1750]
# Epoch [7/150], Loss: 0.1812
# Epoch 8/150: 100%|██████████| 11/11 [01:39<00:00,  9.05s/it, Loss=0.1525]
# Epoch [8/150], Loss: 0.1665
# Epoch 9/150: 100%|██████████| 11/11 [01:48<00:00,  9.86s/it, Loss=0.1342]
# Epoch [9/150], Loss: 0.1504
# Epoch 10/150: 100%|██████████| 11/11 [01:40<00:00,  9.13s/it, Loss=0.1299]
# Epoch [10/150], Loss: 0.1328
# Epoch 11/150: 100%|██████████| 11/11 [01:48<00:00,  9.86s/it, Loss=0.1222]
# Epoch [11/150], Loss: 0.1233
# Epoch 12/150: 100%|██████████| 11/11 [01:42<00:00,  9.29s/it, Loss=0.1078]
# Epoch [12/150], Loss: 0.1151
# Epoch 13/150: 100%|██████████| 11/11 [01:48<00:00,  9.88s/it, Loss=0.1132]
# Epoch [13/150], Loss: 0.1096
# Epoch 14/150: 100%|██████████| 11/11 [01:40<00:00,  9.13s/it, Loss=0.1101]
# Epoch [14/150], Loss: 0.1070
# Epoch 15/150: 100%|██████████| 11/11 [01:48<00:00,  9.82s/it, Loss=0.1215]
# Epoch [15/150], Loss: 0.1039
# Epoch 16/150: 100%|██████████| 11/11 [01:40<00:00,  9.09s/it, Loss=0.0968]
# Epoch [16/150], Loss: 0.0987
# Epoch 17/150: 100%|██████████| 11/11 [01:49<00:00,  9.91s/it, Loss=0.0982]
# Epoch [17/150], Loss: 0.0969
# Epoch 18/150: 100%|██████████| 11/11 [01:39<00:00,  9.04s/it, Loss=0.0921]
# Epoch [18/150], Loss: 0.0967
# Epoch 19/150: 100%|██████████| 11/11 [01:47<00:00,  9.73s/it, Loss=0.0938]
# Epoch [19/150], Loss: 0.0985
# Epoch 20/150: 100%|██████████| 11/11 [01:39<00:00,  9.09s/it, Loss=0.0810]
# Epoch [20/150], Loss: 0.0926
# Epoch 21/150: 100%|██████████| 11/11 [01:47<00:00,  9.82s/it, Loss=0.0909]
# Epoch [21/150], Loss: 0.0909
# Epoch 22/150: 100%|██████████| 11/11 [01:37<00:00,  8.88s/it, Loss=0.0754]
# Epoch [22/150], Loss: 0.0891
# Epoch [131/150], Loss: 0.0134
# Epoch 132/150: 100%|██████████| 11/11 [01:36<00:00,  8.75s/it, Loss=0.0141]
# Epoch [132/150], Loss: 0.0136
# Epoch 133/150: 100%|██████████| 11/11 [01:45<00:00,  9.63s/it, Loss=0.0129]
# Epoch [133/150], Loss: 0.0132
# Epoch 134/150: 100%|██████████| 11/11 [01:37<00:00,  8.89s/it, Loss=0.0118]
# Epoch [134/150], Loss: 0.0144
# Epoch 135/150: 100%|██████████| 11/11 [01:44<00:00,  9.54s/it, Loss=0.0125]
# Epoch [135/150], Loss: 0.0147
# Epoch 136/150: 100%|██████████| 11/11 [01:36<00:00,  8.79s/it, Loss=0.0124]
# Epoch [136/150], Loss: 0.0138
# Epoch 137/150: 100%|██████████| 11/11 [01:46<00:00,  9.66s/it, Loss=0.0174]
# Epoch [137/150], Loss: 0.0129
# Epoch 138/150: 100%|██████████| 11/11 [01:37<00:00,  8.88s/it, Loss=0.0146]
# Epoch [138/150], Loss: 0.0138
# Epoch 139/150: 100%|██████████| 11/11 [01:46<00:00,  9.65s/it, Loss=0.0129]
# Epoch [139/150], Loss: 0.0124
# Epoch 140/150: 100%|██████████| 11/11 [01:37<00:00,  8.87s/it, Loss=0.0104]
# Epoch [140/150], Loss: 0.0117
# Epoch 141/150: 100%|██████████| 11/11 [01:46<00:00,  9.66s/it, Loss=0.0105]
# Epoch [141/150], Loss: 0.0116
# Epoch 142/150: 100%|██████████| 11/11 [01:36<00:00,  8.76s/it, Loss=0.0112]
# Epoch [142/150], Loss: 0.0122
# Epoch 143/150: 100%|██████████| 11/11 [01:44<00:00,  9.53s/it, Loss=0.0096]
# Epoch [143/150], Loss: 0.0119
# Epoch 144/150: 100%|██████████| 11/11 [01:38<00:00,  8.93s/it, Loss=0.0126]
# Epoch [144/150], Loss: 0.0117
# Epoch 145/150: 100%|██████████| 11/11 [01:46<00:00,  9.69s/it, Loss=0.0135]
# Epoch [145/150], Loss: 0.0120
# Epoch 146/150: 100%|██████████| 11/11 [01:36<00:00,  8.76s/it, Loss=0.0097]
# Epoch [146/150], Loss: 0.0115
# Epoch 147/150: 100%|██████████| 11/11 [01:43<00:00,  9.45s/it, Loss=0.0112]
# Epoch [147/150], Loss: 0.0112
# Epoch 148/150: 100%|██████████| 11/11 [01:37<00:00,  8.89s/it, Loss=0.0091]
# Epoch [148/150], Loss: 0.0110
# Epoch 149/150: 100%|██████████| 11/11 [01:46<00:00,  9.66s/it, Loss=0.0117]
# Epoch [149/150], Loss: 0.0106
# Epoch 150/150: 100%|██████████| 11/11 [01:36<00:00,  8.74s/it, Loss=0.0133]
# Epoch [150/150], Loss: 0.0113
# 完整模型已保存到 D:/2024/paper2/model/Model/shanyang\segformer_full_model.pth
# 模型权重已保存到 D:/2024/paper2/model/Model/shanyang\segformer_weights.pth
# 配置文件已保存到 D:/2024/paper2/model/Model/shanyang\config.json
# 检查点文件已保存到 D:/2024/paper2/model/Model/shanyang\checkpoint.pth
# 训练完成并保存所有文件！

# %%
import torch
import os
from PIL import Image
from torchvision import transforms
from transformers import SegformerForSemanticSegmentation
import numpy as np

# 设置路径
image_dir = "D:/2024/paper2/model/test/shanyang"  # 验证图像文件夹
output_mask_dir = "D:/2024/paper2/model/test_masks/shanyang"  # 输出掩码文件夹
model_dir = "D:/2024/paper2/model/Model/shanyang"  # 模型文件夹

# 加载完整模型
model_path = os.path.join(model_dir, "segformer_full_model.pth")
model = torch.load(model_path)  # 直接加载完整模型
model.eval()  # 设置为评估模式

# 数据预处理（与训练时相同）
transform = transforms.Compose([
    transforms.ToTensor(),  # 转换为 Tensor
])

# 创建输出文件夹（如果不存在）
os.makedirs(output_mask_dir, exist_ok=True)

# 验证集图像文件名
image_filenames = [f for f in os.listdir(image_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# 推理过程
with torch.no_grad():  # 在推理时不需要计算梯度
    for filename in image_filenames:
        img_path = os.path.join(image_dir, filename)
        
        # 读取图像
        image = Image.open(img_path).convert("RGB")
        
        # 保存原始尺寸
        original_size = image.size
        
        # 统一尺寸（假设训练时输入尺寸是1024x1024）
        target_size = (1024, 1024)  # 如果你的验证图像不是1024x1024，可能需要调整此处
        image_resized = image.resize(target_size)

        # 进行预处理
        image_tensor = transform(image_resized).unsqueeze(0).to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))

        # 模型推理
        outputs = model(image_tensor).logits

        # 获取预测的类别标签（背景=0, 树干=1）
        predicted_mask = torch.argmax(outputs, dim=1).squeeze(0).cpu().numpy().astype(np.uint8)

        # 将输出的掩码转换为 0 和 255（黑色背景，白色树干）
        predicted_mask = predicted_mask * 255  # 0 -> 0, 1 -> 255

        # 将预测掩码调整回原始输入图像的大小
        predicted_mask_resized = Image.fromarray(predicted_mask)
        predicted_mask_resized = predicted_mask_resized.resize(original_size, Image.NEAREST)

        # 保存掩码图像
        mask_filename = os.path.join(output_mask_dir, filename.replace(".jpg", ".png").replace(".jpeg", ".png").replace(".png", ".png"))
        predicted_mask_resized.save(mask_filename)

        print(f"Saved mask for {filename} to {mask_filename}")

print("推理完成，所有掩码已保存！")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_33736\3024457028.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(model_path)  # 直接加载完整模型
# Saved mask for 09010090012000_04.JPG to D:/2024/paper2/model/test_masks/shanyang\09010090012000_04.JPG
# Saved mask for 09010090037000_02.JPG to D:/2024/paper2/model/test_masks/shanyang\09010090037000_02.JPG
# Saved mask for 09010090037000_03.JPG to D:/2024/paper2/model/test_masks/shanyang\09010090037000_03.JPG
# Saved mask for 09010090073000_02.JPG to D:/2024/paper2/model/test_masks/shanyang\09010090073000_02.JPG
# Saved mask for 09010090073000_03.JPG to D:/2024/paper2/model/test_masks/shanyang\09010090073000_03.JPG
# Saved mask for 09010090073000_04.JPG to D:/2024/paper2/model/test_masks/shanyang\09010090073000_04.JPG
# Saved mask for 09040100146000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\09040100146000_01.png
# Saved mask for 16010020204000_05.jpg to D:/2024/paper2/model/test_masks/shanyang\16010020204000_05.png
# Saved mask for 16011610014000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\16011610014000_01.png
# Saved mask for 16011610014000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\16011610014000_02.png
# Saved mask for 16011610069001_01.jpg to D:/2024/paper2/model/test_masks/shanyang\16011610069001_01.png
# Saved mask for 16011610069001_03.jpg to D:/2024/paper2/model/test_masks/shanyang\16011610069001_03.png
# Saved mask for 16011610069001_04.jpg to D:/2024/paper2/model/test_masks/shanyang\16011610069001_04.png
# Saved mask for 16011610069001_05.jpg to D:/2024/paper2/model/test_masks/shanyang\16011610069001_05.png
# Saved mask for 16011610102000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\16011610102000_01.png
# Saved mask for 16011610102000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\16011610102000_02.png
# Saved mask for 16011610102000_03.jpg to D:/2024/paper2/model/test_masks/shanyang\16011610102000_03.png
# Saved mask for 16011610102000_04.jpg to D:/2024/paper2/model/test_masks/shanyang\16011610102000_04.png
# Saved mask for 16011610102000_05.jpg to D:/2024/paper2/model/test_masks/shanyang\16011610102000_05.png
# Saved mask for 16011620030001_01.jpg to D:/2024/paper2/model/test_masks/shanyang\16011620030001_01.png
# Saved mask for 16011620030001_02.jpg to D:/2024/paper2/model/test_masks/shanyang\16011620030001_02.png
# Saved mask for 16011620030001_04.jpg to D:/2024/paper2/model/test_masks/shanyang\16011620030001_04.png
# Saved mask for 16080010065000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\16080010065000_01.png
# Saved mask for 16080010065000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\16080010065000_02.png
# Saved mask for 16080010065000_03.jpg to D:/2024/paper2/model/test_masks/shanyang\16080010065000_03.png
# Saved mask for 16080010065000_05.jpg to D:/2024/paper2/model/test_masks/shanyang\16080010065000_05.png
# Saved mask for 16080010109000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\16080010109000_01.png
# Saved mask for 16080010109000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\16080010109000_02.png
# Saved mask for 16080010109000_03.jpg to D:/2024/paper2/model/test_masks/shanyang\16080010109000_03.png
# Saved mask for 16080010109000_04.jpg to D:/2024/paper2/model/test_masks/shanyang\16080010109000_04.png
# Saved mask for 16080010109000_05.jpg to D:/2024/paper2/model/test_masks/shanyang\16080010109000_05.png
# Saved mask for 16080020057000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\16080020057000_01.png
# Saved mask for 16080020057000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\16080020057000_02.png
# Saved mask for 16080020057000_03.jpg to D:/2024/paper2/model/test_masks/shanyang\16080020057000_03.png
# Saved mask for 16080020057000_04.jpg to D:/2024/paper2/model/test_masks/shanyang\16080020057000_04.png
# Saved mask for 16080020057000_05.jpg to D:/2024/paper2/model/test_masks/shanyang\16080020057000_05.png
# Saved mask for 29030110078000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\29030110078000_02.png
# Saved mask for 29030110078000_03.jpg to D:/2024/paper2/model/test_masks/shanyang\29030110078000_03.png
# Saved mask for 29030110078000_04.jpg to D:/2024/paper2/model/test_masks/shanyang\29030110078000_04.png
# Saved mask for 29030110078000_05.jpg to D:/2024/paper2/model/test_masks/shanyang\29030110078000_05.png
# Saved mask for 29030120014000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\29030120014000_01.png
# Saved mask for 29030120014000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\29030120014000_02.png
# Saved mask for 29030120014000_03.jpg to D:/2024/paper2/model/test_masks/shanyang\29030120014000_03.png
# Saved mask for 29030120014000_04.jpg to D:/2024/paper2/model/test_masks/shanyang\29030120014000_04.png
# Saved mask for 29030120014000_05.jpg to D:/2024/paper2/model/test_masks/shanyang\29030120014000_05.png
# Saved mask for 29030120042002_01.jpg to D:/2024/paper2/model/test_masks/shanyang\29030120042002_01.png
# Saved mask for 29030120042002_02.jpg to D:/2024/paper2/model/test_masks/shanyang\29030120042002_02.png
# Saved mask for 29030120042002_03.jpg to D:/2024/paper2/model/test_masks/shanyang\29030120042002_03.png
# Saved mask for 29030260007000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\29030260007000_01.png
# Saved mask for 29030260007000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\29030260007000_02.png
# Saved mask for 29030260007000_03.jpg to D:/2024/paper2/model/test_masks/shanyang\29030260007000_03.png
# Saved mask for 29030260007000_04.jpg to D:/2024/paper2/model/test_masks/shanyang\29030260007000_04.png
# Saved mask for 29030260007000_05.jpg to D:/2024/paper2/model/test_masks/shanyang\29030260007000_05.png
# Saved mask for 29030260026000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\29030260026000_01.png
# Saved mask for 29030260026000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\29030260026000_02.png
# Saved mask for 29030260026000_03.jpg to D:/2024/paper2/model/test_masks/shanyang\29030260026000_03.png
# Saved mask for 29030260026000_04.jpg to D:/2024/paper2/model/test_masks/shanyang\29030260026000_04.png
# Saved mask for 29030260026000_05.jpg to D:/2024/paper2/model/test_masks/shanyang\29030260026000_05.png
# Saved mask for 29030270004000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\29030270004000_01.png
# Saved mask for 29030270004000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\29030270004000_02.png
# Saved mask for 29030270004000_03.jpg to D:/2024/paper2/model/test_masks/shanyang\29030270004000_03.png
# Saved mask for 29030270004000_05.jpg to D:/2024/paper2/model/test_masks/shanyang\29030270004000_05.png
# Saved mask for 29030270011000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\29030270011000_01.png
# Saved mask for 29030270011000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\29030270011000_02.png
# Saved mask for 29030270011000_03.jpg to D:/2024/paper2/model/test_masks/shanyang\29030270011000_03.png
# Saved mask for 29030270022000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\29030270022000_02.png
# Saved mask for 29030270022000_03.jpg to D:/2024/paper2/model/test_masks/shanyang\29030270022000_03.png
# Saved mask for 29030270022000_04.jpg to D:/2024/paper2/model/test_masks/shanyang\29030270022000_04.png
# Saved mask for 29030270022000_05.jpg to D:/2024/paper2/model/test_masks/shanyang\29030270022000_05.png
# Saved mask for 29030300038000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\29030300038000_02.png
# Saved mask for 29070130026000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\29070130026000_02.png
# Saved mask for 29070130026000_04.jpg to D:/2024/paper2/model/test_masks/shanyang\29070130026000_04.png
# Saved mask for 29070130026000_05.jpg to D:/2024/paper2/model/test_masks/shanyang\29070130026000_05.png
# Saved mask for 29080200005000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\29080200005000_01.png
# Saved mask for 29090120049000_03.jpg to D:/2024/paper2/model/test_masks/shanyang\29090120049000_03.png
# Saved mask for 29090120049000_05.jpg to D:/2024/paper2/model/test_masks/shanyang\29090120049000_05.png
# Saved mask for 29090120177002_01.jpg to D:/2024/paper2/model/test_masks/shanyang\29090120177002_01.png
# Saved mask for 29090120177004_05.jpg to D:/2024/paper2/model/test_masks/shanyang\29090120177004_05.png
# Saved mask for 29090130001000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\29090130001000_01.png
# Saved mask for 29090130001000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\29090130001000_02.png
# Saved mask for 29090130001000_03.jpg to D:/2024/paper2/model/test_masks/shanyang\29090130001000_03.png
# Saved mask for 29090130001000_04.jpg to D:/2024/paper2/model/test_masks/shanyang\29090130001000_04.png
# Saved mask for 29090130001000_05.jpg to D:/2024/paper2/model/test_masks/shanyang\29090130001000_05.png
# Saved mask for 29090130004000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\29090130004000_01.png
# Saved mask for 29090130004000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\29090130004000_02.png
# Saved mask for 29090130022000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\29090130022000_01.png
# Saved mask for 29090140162000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\29090140162000_02.png
# Saved mask for 29090150030000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\29090150030000_01.png
# Saved mask for 29090150030000_03.jpg to D:/2024/paper2/model/test_masks/shanyang\29090150030000_03.png
# Saved mask for 29090150030000_04.jpg to D:/2024/paper2/model/test_masks/shanyang\29090150030000_04.png
# Saved mask for 29090150033000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\29090150033000_02.png
# Saved mask for 29090150041000_01.jpg to D:/2024/paper2/model/test_masks/shanyang\29090150041000_01.png
# Saved mask for 29090150041000_02.jpg to D:/2024/paper2/model/test_masks/shanyang\29090150041000_02.png
# Saved mask for 29090150041000_03.jpg to D:/2024/paper2/model/test_masks/shanyang\29090150041000_03.png
# Saved mask for A013_04.jpg to D:/2024/paper2/model/test_masks/shanyang\A013_04.png
# Saved mask for A013_05.jpg to D:/2024/paper2/model/test_masks/shanyang\A013_05.png
# Saved mask for A49_05.jpg to D:/2024/paper2/model/test_masks/shanyang\A49_05.png
# Saved mask for B001_03.jpg to D:/2024/paper2/model/test_masks/shanyang\B001_03.png
# Saved mask for B001_04.jpg to D:/2024/paper2/model/test_masks/shanyang\B001_04.png
# Saved mask for B001_05.jpg to D:/2024/paper2/model/test_masks/shanyang\B001_05.png
# Saved mask for B002_01.jpg to D:/2024/paper2/model/test_masks/shanyang\B002_01.png
# Saved mask for C006_04.jpg to D:/2024/paper2/model/test_masks/shanyang\C006_04.png
# Saved mask for C017_01.jpg to D:/2024/paper2/model/test_masks/shanyang\C017_01.png
# Saved mask for C017_02.jpg to D:/2024/paper2/model/test_masks/shanyang\C017_02.png
# Saved mask for C017_03.jpg to D:/2024/paper2/model/test_masks/shanyang\C017_03.png
# Saved mask for C017_04.jpg to D:/2024/paper2/model/test_masks/shanyang\C017_04.png
# Saved mask for C017_05.jpg to D:/2024/paper2/model/test_masks/shanyang\C017_05.png
# Saved mask for C018_02.jpg to D:/2024/paper2/model/test_masks/shanyang\C018_02.png
# Saved mask for C018_03.jpg to D:/2024/paper2/model/test_masks/shanyang\C018_03.png
# Saved mask for C018_04.jpg to D:/2024/paper2/model/test_masks/shanyang\C018_04.png
# Saved mask for c021_02.JPG to D:/2024/paper2/model/test_masks/shanyang\c021_02.JPG
# Saved mask for c021_03.JPG to D:/2024/paper2/model/test_masks/shanyang\c021_03.JPG
# Saved mask for c021_04.JPG to D:/2024/paper2/model/test_masks/shanyang\c021_04.JPG
# Saved mask for c021_05.JPG to D:/2024/paper2/model/test_masks/shanyang\c021_05.JPG
# Saved mask for c024_02.JPG to D:/2024/paper2/model/test_masks/shanyang\c024_02.JPG
# Saved mask for c024_03.JPG to D:/2024/paper2/model/test_masks/shanyang\c024_03.JPG
# Saved mask for c024_04.JPG to D:/2024/paper2/model/test_masks/shanyang\c024_04.JPG
# Saved mask for c024_05.JPG to D:/2024/paper2/model/test_masks/shanyang\c024_05.JPG
# Saved mask for c025_03.JPG to D:/2024/paper2/model/test_masks/shanyang\c025_03.JPG
# Saved mask for C037_03.jpg to D:/2024/paper2/model/test_masks/shanyang\C037_03.png
# Saved mask for C037_04.jpg to D:/2024/paper2/model/test_masks/shanyang\C037_04.png
# Saved mask for C038_02.jpg to D:/2024/paper2/model/test_masks/shanyang\C038_02.png
# Saved mask for D009_01.jpg to D:/2024/paper2/model/test_masks/shanyang\D009_01.png
# Saved mask for D009_03.jpg to D:/2024/paper2/model/test_masks/shanyang\D009_03.png
# Saved mask for D009_04.jpg to D:/2024/paper2/model/test_masks/shanyang\D009_04.png
# Saved mask for D010_01.jpg to D:/2024/paper2/model/test_masks/shanyang\D010_01.png
# Saved mask for D010_03.jpg to D:/2024/paper2/model/test_masks/shanyang\D010_03.png
# Saved mask for D010_04.jpg to D:/2024/paper2/model/test_masks/shanyang\D010_04.png
# Saved mask for D010_05.jpg to D:/2024/paper2/model/test_masks/shanyang\D010_05.png
# Saved mask for D011_02.jpg to D:/2024/paper2/model/test_masks/shanyang\D011_02.png
# Saved mask for D012_03.jpg to D:/2024/paper2/model/test_masks/shanyang\D012_03.png
# Saved mask for D012_04.jpg to D:/2024/paper2/model/test_masks/shanyang\D012_04.png
# Saved mask for D012_05.jpg to D:/2024/paper2/model/test_masks/shanyang\D012_05.png
# Saved mask for D013_01.jpg to D:/2024/paper2/model/test_masks/shanyang\D013_01.png
# Saved mask for D013_03.jpg to D:/2024/paper2/model/test_masks/shanyang\D013_03.png
# Saved mask for D014_03.jpg to D:/2024/paper2/model/test_masks/shanyang\D014_03.png
# Saved mask for D014_04.jpg to D:/2024/paper2/model/test_masks/shanyang\D014_04.png
# Saved mask for D014_05.jpg to D:/2024/paper2/model/test_masks/shanyang\D014_05.png
# Saved mask for D015_02.jpg to D:/2024/paper2/model/test_masks/shanyang\D015_02.png
# Saved mask for D015_03.jpg to D:/2024/paper2/model/test_masks/shanyang\D015_03.png
# Saved mask for D015_04.jpg to D:/2024/paper2/model/test_masks/shanyang\D015_04.png
# Saved mask for D015_05.jpg to D:/2024/paper2/model/test_masks/shanyang\D015_05.png
# Saved mask for D016_02.jpg to D:/2024/paper2/model/test_masks/shanyang\D016_02.png
# Saved mask for D016_03.jpg to D:/2024/paper2/model/test_masks/shanyang\D016_03.png
# Saved mask for D016_05.jpg to D:/2024/paper2/model/test_masks/shanyang\D016_05.png
# Saved mask for D017_02.jpg to D:/2024/paper2/model/test_masks/shanyang\D017_02.png
# Saved mask for D018_01.jpg to D:/2024/paper2/model/test_masks/shanyang\D018_01.png
# Saved mask for D018_02.jpg to D:/2024/paper2/model/test_masks/shanyang\D018_02.png
# Saved mask for D018_03.jpg to D:/2024/paper2/model/test_masks/shanyang\D018_03.png
# Saved mask for D018_04.jpg to D:/2024/paper2/model/test_masks/shanyang\D018_04.png
# 推理完成，所有掩码已保存！

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# 设置路径
image_dir = "D:/2024/paper2/model/test/shanyang"  # 验证图像文件夹
mask_dir = "D:/2024/paper2/model/test_masks/shanyang"  # 单通道掩码文件夹
output_dir = "D:/2024/paper2/model/test_comparison/shanyang"  # 输出图片文件夹

# 创建输出文件夹（如果不存在）
os.makedirs(output_dir, exist_ok=True)

# 获取图像文件名
image_filenames = [f for f in os.listdir(image_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# 处理每个图像
for filename in image_filenames:
    # 构造图像路径和掩码路径
    img_path = os.path.join(image_dir, filename)
    mask_path = os.path.join(mask_dir, filename.replace(".jpg", ".png").replace(".jpeg", ".png").replace(".png", ".png"))

    # 读取验证图像和掩码图像
    image = Image.open(img_path).convert("RGB")  # 读取并转换为 RGB 图像
    mask = Image.open(mask_path).convert("L")  # 读取掩码并转换为灰度图像（L 模式）

    # 将掩码图像转换为 numpy 数组（0 表示背景，255 表示树干）
    mask_array = np.array(mask)

    # 将掩码值转换为 0 或 1（0 -> 背景，1 -> 树干）
    mask_binary = (mask_array > 127).astype(int)  # 将大于127的像素值转为 1，小于等于127的为 0

    # 将原始图像和掩码图像叠加
    image_array = np.array(image)

    # 使用掩码区域将原始图像覆盖成不同的颜色（比如将树干区域用红色标出）
    # 红色区域表示模型预测的树干区域
    image_with_mask = image_array.copy()
    image_with_mask[mask_binary == 1] = [255, 0, 0]  # 将树干区域标记为红色 [255, 0, 0]

    # 将原始图像与掩码图像并排显示
    # 设置高分辨率图像
    fig, axes = plt.subplots(1, 2, figsize=(16, 8), dpi=200)  # 设置更大的图像大小和更高的 DPI

    # 显示原始图像
    axes[0].imshow(image)
    axes[0].set_title("Original Image")
    axes[0].axis("off")

    # 显示叠加图像
    axes[1].imshow(image_with_mask)
    axes[1].set_title("Image with Predicted Mask")
    axes[1].axis("off")

    # 保存结果图像
    comparison_filename = os.path.join(output_dir, filename.replace(".jpg", "_comparison.png").replace(".jpeg", "_comparison.png").replace(".png", "_comparison.png"))
    plt.savefig(comparison_filename, dpi=200)  # 保存为高分辨率图像
    plt.close()

    print(f"Saved comparison image for {filename} to {comparison_filename}")

print("所有比较图像已保存！")
# Out:
# Saved comparison image for 09010090012000_04.JPG to D:/2024/paper2/model/test_comparison/shanyang\09010090012000_04.JPG
# Saved comparison image for 09010090037000_02.JPG to D:/2024/paper2/model/test_comparison/shanyang\09010090037000_02.JPG
# Saved comparison image for 09010090037000_03.JPG to D:/2024/paper2/model/test_comparison/shanyang\09010090037000_03.JPG
# Saved comparison image for 09010090073000_02.JPG to D:/2024/paper2/model/test_comparison/shanyang\09010090073000_02.JPG
# Saved comparison image for 09010090073000_03.JPG to D:/2024/paper2/model/test_comparison/shanyang\09010090073000_03.JPG
# Saved comparison image for 09010090073000_04.JPG to D:/2024/paper2/model/test_comparison/shanyang\09010090073000_04.JPG
# Saved comparison image for 09040100146000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\09040100146000_01_comparison_comparison.png
# Saved comparison image for 09040100146000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\09040100146000_02_comparison_comparison.png
# Saved comparison image for 09040100146000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\09040100146000_03_comparison_comparison.png
# Saved comparison image for 09040100146000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\09040100146000_04_comparison_comparison.png
# Saved comparison image for 09040100146000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\09040100146000_05_comparison_comparison.png
# Saved comparison image for 09080140047000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\09080140047000_04_comparison_comparison.png
# Saved comparison image for 09080140047000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\09080140047000_05_comparison_comparison.png
# Saved comparison image for 16010020077001_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020077001_01_comparison_comparison.png
# Saved comparison image for 16010020077001_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020077001_02_comparison_comparison.png
# Saved comparison image for 16010020077001_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020077001_03_comparison_comparison.png
# Saved comparison image for 16010020077001_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020077001_04_comparison_comparison.png
# Saved comparison image for 16010020077001_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020077001_05_comparison_comparison.png
# Saved comparison image for 16010020107000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020107000_01_comparison_comparison.png
# Saved comparison image for 16010020107000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020107000_02_comparison_comparison.png
# Saved comparison image for 16010020107000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020107000_03_comparison_comparison.png
# Saved comparison image for 16010020107000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020107000_04_comparison_comparison.png
# Saved comparison image for 16010020107000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020107000_05_comparison_comparison.png
# Saved comparison image for 16010020120000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020120000_01_comparison_comparison.png
# Saved comparison image for 16010020120000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020120000_02_comparison_comparison.png
# Saved comparison image for 16010020120000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020120000_03_comparison_comparison.png
# Saved comparison image for 16010020120000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020120000_04_comparison_comparison.png
# Saved comparison image for 16010020176002_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020176002_01_comparison_comparison.png
# Saved comparison image for 16010020176002_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020176002_03_comparison_comparison.png
# Saved comparison image for 16010020176002_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020176002_05_comparison_comparison.png
# Saved comparison image for 16010020199004_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020199004_01_comparison_comparison.png
# Saved comparison image for 16010020199004_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020199004_02_comparison_comparison.png
# Saved comparison image for 16010020199004_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020199004_03_comparison_comparison.png
# Saved comparison image for 16010020199004_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020199004_04_comparison_comparison.png
# Saved comparison image for 16010020199004_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020199004_05_comparison_comparison.png
# Saved comparison image for 16010020204000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020204000_01_comparison_comparison.png
# Saved comparison image for 16010020204000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020204000_04_comparison_comparison.png
# Saved comparison image for 16010020204000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\16010020204000_05_comparison_comparison.png
# Saved comparison image for 16011610014000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\16011610014000_01_comparison_comparison.png
# Saved comparison image for 16011610014000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\16011610014000_02_comparison_comparison.png
# Saved comparison image for 16011610069001_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\16011610069001_01_comparison_comparison.png
# Saved comparison image for 16011610069001_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\16011610069001_03_comparison_comparison.png
# Saved comparison image for 16011610069001_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\16011610069001_04_comparison_comparison.png
# Saved comparison image for 16011610069001_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\16011610069001_05_comparison_comparison.png
# Saved comparison image for 16011610102000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\16011610102000_01_comparison_comparison.png
# Saved comparison image for 16011610102000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\16011610102000_02_comparison_comparison.png
# Saved comparison image for 16011610102000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\16011610102000_03_comparison_comparison.png
# Saved comparison image for 16011610102000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\16011610102000_04_comparison_comparison.png
# Saved comparison image for 16011610102000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\16011610102000_05_comparison_comparison.png
# Saved comparison image for 16011620030001_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\16011620030001_01_comparison_comparison.png
# Saved comparison image for 16011620030001_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\16011620030001_02_comparison_comparison.png
# Saved comparison image for 16011620030001_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\16011620030001_04_comparison_comparison.png
# Saved comparison image for 16080010065000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080010065000_01_comparison_comparison.png
# Saved comparison image for 16080010065000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080010065000_02_comparison_comparison.png
# Saved comparison image for 16080010065000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080010065000_03_comparison_comparison.png
# Saved comparison image for 16080010065000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080010065000_05_comparison_comparison.png
# Saved comparison image for 16080010109000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080010109000_01_comparison_comparison.png
# Saved comparison image for 16080010109000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080010109000_02_comparison_comparison.png
# Saved comparison image for 16080010109000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080010109000_03_comparison_comparison.png
# Saved comparison image for 16080010109000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080010109000_04_comparison_comparison.png
# Saved comparison image for 16080010109000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080010109000_05_comparison_comparison.png
# Saved comparison image for 16080020057000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080020057000_01_comparison_comparison.png
# Saved comparison image for 16080020057000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080020057000_02_comparison_comparison.png
# Saved comparison image for 16080020057000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080020057000_03_comparison_comparison.png
# Saved comparison image for 16080020057000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080020057000_04_comparison_comparison.png
# Saved comparison image for 16080020057000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080020057000_05_comparison_comparison.png
# Saved comparison image for 16080030025000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080030025000_01_comparison_comparison.png
# Saved comparison image for 16080030025000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080030025000_02_comparison_comparison.png
# Saved comparison image for 16080030025000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080030025000_03_comparison_comparison.png
# Saved comparison image for 16080030025000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080030025000_04_comparison_comparison.png
# Saved comparison image for 16080030025000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\16080030025000_05_comparison_comparison.png
# Saved comparison image for 28010010285000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\28010010285000_01_comparison_comparison.png
# Saved comparison image for 28010010285000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\28010010285000_02_comparison_comparison.png
# Saved comparison image for 28010010285000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\28010010285000_03_comparison_comparison.png
# Saved comparison image for 28010010285000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\28010010285000_04_comparison_comparison.png
# Saved comparison image for 28010010285000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\28010010285000_05_comparison_comparison.png
# Saved comparison image for 28150180022001_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\28150180022001_02_comparison_comparison.png
# Saved comparison image for 28150180022001_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\28150180022001_03_comparison_comparison.png
# Saved comparison image for 28200110010000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\28200110010000_01_comparison_comparison.png
# Saved comparison image for 28200110010000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\28200110010000_02_comparison_comparison.png
# Saved comparison image for 28200110010000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\28200110010000_05_comparison_comparison.png
# Saved comparison image for 29030100007000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030100007000_02_comparison_comparison.png
# Saved comparison image for 29030100007000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030100007000_03_comparison_comparison.png
# Saved comparison image for 29030100007000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030100007000_04_comparison_comparison.png
# Saved comparison image for 29030100007000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030100007000_05_comparison_comparison.png
# Saved comparison image for 29030100022000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030100022000_01_comparison_comparison.png
# Saved comparison image for 29030100022000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030100022000_02_comparison_comparison.png
# Saved comparison image for 29030100022000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030100022000_03_comparison_comparison.png
# Saved comparison image for 29030100022000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030100022000_05_comparison_comparison.png
# Saved comparison image for 29030110016000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030110016000_01_comparison_comparison.png
# Saved comparison image for 29030110016000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030110016000_02_comparison_comparison.png
# Saved comparison image for 29030110016000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030110016000_03_comparison_comparison.png
# Saved comparison image for 29030110016000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030110016000_04_comparison_comparison.png
# Saved comparison image for 29030110016000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030110016000_05_comparison_comparison.png
# Saved comparison image for 29030110078000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030110078000_01_comparison_comparison.png
# Saved comparison image for 29030110078000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030110078000_02_comparison_comparison.png
# Saved comparison image for 29030110078000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030110078000_03_comparison_comparison.png
# Saved comparison image for 29030110078000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030110078000_04_comparison_comparison.png
# Saved comparison image for 29030110078000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030110078000_05_comparison_comparison.png
# Saved comparison image for 29030120014000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030120014000_01_comparison_comparison.png
# Saved comparison image for 29030120014000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030120014000_02_comparison_comparison.png
# Saved comparison image for 29030120014000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030120014000_03_comparison_comparison.png
# Saved comparison image for 29030120014000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030120014000_04_comparison_comparison.png
# Saved comparison image for 29030120014000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030120014000_05_comparison_comparison.png
# Saved comparison image for 29030120042002_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030120042002_01_comparison_comparison.png
# Saved comparison image for 29030120042002_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030120042002_02_comparison_comparison.png
# Saved comparison image for 29030120042002_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030120042002_03_comparison_comparison.png
# Saved comparison image for 29030260007000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030260007000_01_comparison_comparison.png
# Saved comparison image for 29030260007000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030260007000_02_comparison_comparison.png
# Saved comparison image for 29030260007000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030260007000_03_comparison_comparison.png
# Saved comparison image for 29030260007000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030260007000_04_comparison_comparison.png
# Saved comparison image for 29030260007000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030260007000_05_comparison_comparison.png
# Saved comparison image for 29030260026000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030260026000_01_comparison_comparison.png
# Saved comparison image for 29030260026000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030260026000_02_comparison_comparison.png
# Saved comparison image for 29030260026000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030260026000_03_comparison_comparison.png
# Saved comparison image for 29030260026000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030260026000_04_comparison_comparison.png
# Saved comparison image for 29030260026000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030260026000_05_comparison_comparison.png
# Saved comparison image for 29030270004000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030270004000_01_comparison_comparison.png
# Saved comparison image for 29030270004000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030270004000_02_comparison_comparison.png
# Saved comparison image for 29030270004000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030270004000_03_comparison_comparison.png
# Saved comparison image for 29030270004000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030270004000_05_comparison_comparison.png
# Saved comparison image for 29030270011000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030270011000_01_comparison_comparison.png
# Saved comparison image for 29030270011000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030270011000_02_comparison_comparison.png
# Saved comparison image for 29030270011000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030270011000_03_comparison_comparison.png
# Saved comparison image for 29030270022000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030270022000_02_comparison_comparison.png
# Saved comparison image for 29030270022000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030270022000_03_comparison_comparison.png
# Saved comparison image for 29030270022000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030270022000_04_comparison_comparison.png
# Saved comparison image for 29030270022000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030270022000_05_comparison_comparison.png
# Saved comparison image for 29030300038000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29030300038000_02_comparison_comparison.png
# Saved comparison image for 29070130026000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29070130026000_02_comparison_comparison.png
# Saved comparison image for 29070130026000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29070130026000_04_comparison_comparison.png
# Saved comparison image for 29070130026000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29070130026000_05_comparison_comparison.png
# Saved comparison image for 29080200005000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29080200005000_01_comparison_comparison.png
# Saved comparison image for 29090120049000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090120049000_03_comparison_comparison.png
# Saved comparison image for 29090120049000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090120049000_05_comparison_comparison.png
# Saved comparison image for 29090120177002_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090120177002_01_comparison_comparison.png
# Saved comparison image for 29090120177004_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090120177004_05_comparison_comparison.png
# Saved comparison image for 29090130001000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090130001000_01_comparison_comparison.png
# Saved comparison image for 29090130001000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090130001000_02_comparison_comparison.png
# Saved comparison image for 29090130001000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090130001000_03_comparison_comparison.png
# Saved comparison image for 29090130001000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090130001000_04_comparison_comparison.png
# Saved comparison image for 29090130001000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090130001000_05_comparison_comparison.png
# Saved comparison image for 29090130004000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090130004000_01_comparison_comparison.png
# Saved comparison image for 29090130004000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090130004000_02_comparison_comparison.png
# Saved comparison image for 29090130022000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090130022000_01_comparison_comparison.png
# Saved comparison image for 29090140162000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090140162000_02_comparison_comparison.png
# Saved comparison image for 29090150030000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090150030000_01_comparison_comparison.png
# Saved comparison image for 29090150030000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090150030000_03_comparison_comparison.png
# Saved comparison image for 29090150030000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090150030000_04_comparison_comparison.png
# Saved comparison image for 29090150033000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090150033000_02_comparison_comparison.png
# Saved comparison image for 29090150041000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090150041000_01_comparison_comparison.png
# Saved comparison image for 29090150041000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090150041000_02_comparison_comparison.png
# Saved comparison image for 29090150041000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090150041000_03_comparison_comparison.png
# Saved comparison image for 29090150046000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090150046000_04_comparison_comparison.png
# Saved comparison image for 29090150046000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090150046000_05_comparison_comparison.png
# Saved comparison image for 29090150050000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090150050000_02_comparison_comparison.png
# Saved comparison image for 29090150050000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090150050000_05_comparison_comparison.png
# Saved comparison image for 29090180017000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29090180017000_04_comparison_comparison.png
# Saved comparison image for 29100100059000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100100059000_02_comparison_comparison.png
# Saved comparison image for 29100100059000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100100059000_03_comparison_comparison.png
# Saved comparison image for 29100100059000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100100059000_04_comparison_comparison.png
# Saved comparison image for 29100100059000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100100059000_05_comparison_comparison.png
# Saved comparison image for 29100130052000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100130052000_01_comparison_comparison.png
# Saved comparison image for 29100130052000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100130052000_02_comparison_comparison.png
# Saved comparison image for 29100130052000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100130052000_03_comparison_comparison.png
# Saved comparison image for 29100130052000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100130052000_04_comparison_comparison.png
# Saved comparison image for 29100130052000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100130052000_05_comparison_comparison.png
# Saved comparison image for 29100140053000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100140053000_01_comparison_comparison.png
# Saved comparison image for 29100140053000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100140053000_02_comparison_comparison.png
# Saved comparison image for 29100140053000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100140053000_03_comparison_comparison.png
# Saved comparison image for 29100140053000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100140053000_04_comparison_comparison.png
# Saved comparison image for 29100140053000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100140053000_05_comparison_comparison.png
# Saved comparison image for 29100180027000_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100180027000_01_comparison_comparison.png
# Saved comparison image for 29100180027000_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100180027000_02_comparison_comparison.png
# Saved comparison image for 29100180027000_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100180027000_03_comparison_comparison.png
# Saved comparison image for 29100180027000_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100180027000_04_comparison_comparison.png
# Saved comparison image for 29100180027000_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\29100180027000_05_comparison_comparison.png
# Saved comparison image for A012_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\A012_01_comparison_comparison.png
# Saved comparison image for A012_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\A012_02_comparison_comparison.png
# Saved comparison image for A012_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\A012_03_comparison_comparison.png
# Saved comparison image for A012_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\A012_04_comparison_comparison.png
# Saved comparison image for A012_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\A012_05_comparison_comparison.png
# Saved comparison image for A013_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\A013_02_comparison_comparison.png
# Saved comparison image for A013_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\A013_04_comparison_comparison.png
# Saved comparison image for A013_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\A013_05_comparison_comparison.png
# Saved comparison image for A49_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\A49_05_comparison_comparison.png
# Saved comparison image for B001_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\B001_03_comparison_comparison.png
# Saved comparison image for B001_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\B001_04_comparison_comparison.png
# Saved comparison image for B001_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\B001_05_comparison_comparison.png
# Saved comparison image for B002_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\B002_01_comparison_comparison.png
# Saved comparison image for C006_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\C006_04_comparison_comparison.png
# Saved comparison image for C017_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\C017_01_comparison_comparison.png
# Saved comparison image for C017_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\C017_02_comparison_comparison.png
# Saved comparison image for C017_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\C017_03_comparison_comparison.png
# Saved comparison image for C017_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\C017_04_comparison_comparison.png
# Saved comparison image for C017_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\C017_05_comparison_comparison.png
# Saved comparison image for C018_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\C018_02_comparison_comparison.png
# Saved comparison image for C018_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\C018_03_comparison_comparison.png
# Saved comparison image for C018_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\C018_04_comparison_comparison.png
# Saved comparison image for c021_02.JPG to D:/2024/paper2/model/test_comparison/shanyang\c021_02.JPG
# Saved comparison image for c021_03.JPG to D:/2024/paper2/model/test_comparison/shanyang\c021_03.JPG
# Saved comparison image for c021_04.JPG to D:/2024/paper2/model/test_comparison/shanyang\c021_04.JPG
# Saved comparison image for c021_05.JPG to D:/2024/paper2/model/test_comparison/shanyang\c021_05.JPG
# Saved comparison image for c024_02.JPG to D:/2024/paper2/model/test_comparison/shanyang\c024_02.JPG
# Saved comparison image for c024_03.JPG to D:/2024/paper2/model/test_comparison/shanyang\c024_03.JPG
# Saved comparison image for c024_04.JPG to D:/2024/paper2/model/test_comparison/shanyang\c024_04.JPG
# Saved comparison image for c024_05.JPG to D:/2024/paper2/model/test_comparison/shanyang\c024_05.JPG
# Saved comparison image for c025_03.JPG to D:/2024/paper2/model/test_comparison/shanyang\c025_03.JPG
# Saved comparison image for C037_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\C037_03_comparison_comparison.png
# Saved comparison image for C037_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\C037_04_comparison_comparison.png
# Saved comparison image for C038_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\C038_02_comparison_comparison.png
# Saved comparison image for D009_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\D009_01_comparison_comparison.png
# Saved comparison image for D009_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\D009_03_comparison_comparison.png
# Saved comparison image for D009_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\D009_04_comparison_comparison.png
# Saved comparison image for D010_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\D010_01_comparison_comparison.png
# Saved comparison image for D010_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\D010_03_comparison_comparison.png
# Saved comparison image for D010_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\D010_04_comparison_comparison.png
# Saved comparison image for D010_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\D010_05_comparison_comparison.png
# Saved comparison image for D011_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\D011_02_comparison_comparison.png
# Saved comparison image for D012_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\D012_03_comparison_comparison.png
# Saved comparison image for D012_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\D012_04_comparison_comparison.png
# Saved comparison image for D012_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\D012_05_comparison_comparison.png
# Saved comparison image for D013_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\D013_01_comparison_comparison.png
# Saved comparison image for D013_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\D013_03_comparison_comparison.png
# Saved comparison image for D014_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\D014_03_comparison_comparison.png
# Saved comparison image for D014_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\D014_04_comparison_comparison.png
# Saved comparison image for D014_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\D014_05_comparison_comparison.png
# Saved comparison image for D015_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\D015_02_comparison_comparison.png
# Saved comparison image for D015_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\D015_03_comparison_comparison.png
# Saved comparison image for D015_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\D015_04_comparison_comparison.png
# Saved comparison image for D015_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\D015_05_comparison_comparison.png
# Saved comparison image for D016_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\D016_02_comparison_comparison.png
# Saved comparison image for D016_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\D016_03_comparison_comparison.png
# Saved comparison image for D016_05.jpg to D:/2024/paper2/model/test_comparison/shanyang\D016_05_comparison_comparison.png
# Saved comparison image for D017_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\D017_02_comparison_comparison.png
# Saved comparison image for D018_01.jpg to D:/2024/paper2/model/test_comparison/shanyang\D018_01_comparison_comparison.png
# Saved comparison image for D018_02.jpg to D:/2024/paper2/model/test_comparison/shanyang\D018_02_comparison_comparison.png
# Saved comparison image for D018_03.jpg to D:/2024/paper2/model/test_comparison/shanyang\D018_03_comparison_comparison.png
# Saved comparison image for D018_04.jpg to D:/2024/paper2/model/test_comparison/shanyang\D018_04_comparison_comparison.png
# 所有比较图像已保存！
